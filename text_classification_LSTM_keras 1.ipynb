# %%
import pandas as pd
import numpy as np

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Emotion_classify_Data.csv')

# %%
df.head()
# Out:
#                                              Comment Emotion
# 0  i seriously hate one subject to death but now ...    fear
# 1                 im so full of life i feel appalled   anger
# 2  i sit here to write i start to dig out my feel...    fear
# 3  ive been really angry with r and i feel like a...     joy
# 4  i feel suspicious if there is no one outside l...    fear

# %%
df.shape
# Out:
# (5937, 3)

# %%
df['Emotion'].value_counts()
# Out:
# Emotion
# 0    2000
# 1    2000
# 2    1937
# Name: count, dtype: int64

# %%
#Binary Encoding Categorical to Numeric of Gender and Ever_Married
label_encode={"Emotion": {"anger":0,"joy" :1,"fear":2}}
df=df.replace(label_encode)

# %%
df.head()
# Out:
#                                              Comment  Emotion  \
# 0  i seriously hate one subject to death but now ...        2
# 1                 im so full of life i feel appalled        0
# 2  i sit here to write i start to dig out my feel...        2
# 3  ive been really angry with r and i feel like a...        1
# 4  i feel suspicious if there is no one outside l...        2
#
#                                           clean_text
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...

# %%
def cleansing(df):
    df_clean=df.str.lower()
    df_clean=[re.sub(r"\d+","",i )for i in df_clean]
    df_clean=[re.sub(r'[^\w]', ' ', i)for i in df_clean]
    df_clean=[re.sub(r'\s+',' ',i)for i in df_clean]
    return df_clean

# %%
df['clean_text']=cleansing(df['Comment'])

# %%
df.head()
# Out:
#                                              Comment  Emotion  \
# 0  i seriously hate one subject to death but now ...        2
# 1                 im so full of life i feel appalled        0
# 2  i sit here to write i start to dig out my feel...        2
# 3  ive been really angry with r and i feel like a...        1
# 4  i feel suspicious if there is no one outside l...        2
#
#                                           clean_text
# 0  i seriously hate one subject to death but now ...
# 1                 im so full of life i feel appalled
# 2  i sit here to write i start to dig out my feel...
# 3  ive been really angry with r and i feel like a...
# 4  i feel suspicious if there is no one outside l...

# %%
#check maximum length of word in sentence 
max_sen = df['clean_text'].str.split().str.len().max()

# %%
max_sen
# Out:
# 64

# %% [markdown]
# **Split the Data**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from sklearn.metrics import classification_report, confusion_matrix

# %%
x_train, x_test, y_train, y_test = train_test_split(df['clean_text'], df['Emotion'], test_size = 0.2, random_state = 42,stratify=df['Emotion'])

# %%
len(x_train)
# Out:
# 4749

# %%
 x_train.str.split().str.len().max()
# Out:
# 64

# %% [markdown]
# **Remove Stopword and Tokenization**

# %%
#Define Stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
# Get a list of stop words in the English language
stop_words = set(stopwords.words('english'))

# Display the top 20 stop words
list(stop_words)[:20]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/liliayu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['most',
#  'very',
#  "aren't",
#  "wouldn't",
#  'have',
#  "she's",
#  'needn',
#  "wasn't",
#  'on',
#  'been',
#  'few',
#  'of',
#  "don't",
#  'to',
#  "couldn't",
#  'had',
#  'm',
#  've',
#  'under',
#  'just']

# %%
#tokenization
word_token=[word_tokenize(i) for i in x_train]

# %%
word_token
# Out:
# [['i',
#   'fear',
#   'that',
#   'other',
#   'people',
#   'ask',
#   'me',
#   'about',
#   'my',
#   'feelings',
#   'i',
#   'am',
#   'most',
#   'reluctant',
#   'to',
#   'talk',
#   'about',
#   'things'],
#  ['ive',
#   'been',
#   'thinking',
#   'about',
#   'what',
#   'it',
#   'is',
#   'that',
#   'drives',
#   'me',
#   'not',
#   'only',
#   'with',
#   'fashion',
#   'as',
#   'pretentious',
#   'as',
#   'this',
#   'is',
#   'gon',
#   'na',
#   'make',
#   'me',
#   'sound',
#   'i',
#   'am',
#   'studying',
#   'fashion',
#   'design',
#   'so',
#   'i',
#   'do',
#   'feel',
#   'its',
#   'kinda',
#   'vital',
#   'to',
#   'understand',
#   'what',
#   'im',
#   'trying',
#   'to',
#   'do',
#   'there',
#   'but',
#   'in',
#   'life',
#   'as',
#   'a',
#   'whole'],
#  ['i', 'love', 'comments', 'so', 'feel', 'free'],
#  ['i',
#   'feel',
#   'irritable',
#   'like',
#   'no',
#   'other',
#   'and',
#   'running',
#   'will',
#   'def',
#   'cure',
#   'that'],
#  ['i',
#   'dont',
#   'have',
#   'a',
#   'yeast',
#   'infection',
#   'in',
#   'the',
#   'vagina',
#   'i',
#   'could',
#   'be',
#   'feeling',
#   'irritated',
#   'by',
#   'yeast',
#   'due',
#   'to',
#   'my',
#   'diet',
#   'so',
#   'i',
#   'should',
#   'stop',
#   'eating',
#   'lots',
#   'of',
#   'sugary',
#   'foods',
#   'if',
#   'i',
#   'can'],
#  ['i', 'just', 'feel', 'really', 'violent', 'right', 'now'],
#  ['i',
#   'can',
#   'get',
#   'away',
#   'these',
#   'days',
#   'with',
#   'the',
#   'gag',
#   'line',
#   'when',
#   'i',
#   'feel',
#   'like',
#   'being',
#   'sarcastic',
#   'that',
#   'i',
#   'feel',
#   'sorry',
#   'for',
#   'anyone',
#   'who',
#   'wasn',
#   't',
#   'fortunate',
#   'enough',
#   'to',
#   'be',
#   'born',
#   'mexican'],
#  ['i',
#   'am',
#   'feeling',
#   'very',
#   'anxious',
#   'about',
#   'going',
#   'to',
#   'therapy',
#   'w'],
#  ['i',
#   'feel',
#   'im',
#   'just',
#   'so',
#   'greedy',
#   'that',
#   'all',
#   'i',
#   'care',
#   'about',
#   'is',
#   'myself'],
#  ['i',
#   'feel',
#   'like',
#   'this',
#   'another',
#   'one',
#   'of',
#   'the',
#   'more',
#   'underrated',
#   'records',
#   'on',
#   'the',
#   'album',
#   'not',
#   'going',
#   'to',
#   'be',
#   'the',
#   'most',
#   'popular',
#   'but',
#   'an',
#   'amazing',
#   'record',
#   'nonetheless'],
#  ['i',
#   'feel',
#   'like',
#   'im',
#   'almost',
#   'uh',
#   'afraid',
#   'of',
#   'everything',
#   'so',
#   'to',
#   'speak'],
#  ['i',
#   'feel',
#   'tortured',
#   'the',
#   'one',
#   'thing',
#   'i',
#   'love',
#   'is',
#   'the',
#   'one',
#   'thing',
#   'that',
#   'wont',
#   'support',
#   'me',
#   'financially',
#   'but',
#   'i',
#   'cringe',
#   'when',
#   'i',
#   'think',
#   'of',
#   'spending',
#   'years',
#   'chained',
#   'to',
#   'a',
#   'desk',
#   'performing',
#   'a',
#   'job',
#   'by',
#   'wrote',
#   'with',
#   'little',
#   'or',
#   'no',
#   'room',
#   'for',
#   'creativity',
#   'or',
#   'for',
#   'anything',
#   'else',
#   'that',
#   'matters'],
#  ['i', 'was', 'feeling', 'quite', 'nervous'],
#  ['i',
#   'get',
#   'this',
#   'sudden',
#   'feeling',
#   'that',
#   'i',
#   'am',
#   'completely',
#   'annoyed',
#   'at',
#   'him'],
#  ['ive',
#   'been',
#   'feeling',
#   'really',
#   'spiteful',
#   'lately',
#   'so',
#   'i',
#   'think',
#   'ill',
#   'just',
#   'sit',
#   'here',
#   'and',
#   'listen',
#   'to',
#   'rammstein'],
#  ['i',
#   'feel',
#   'quite',
#   'uncertain',
#   'that',
#   'the',
#   'art',
#   'i',
#   'create',
#   'and',
#   'my',
#   'personal',
#   'brand',
#   'of',
#   'creative',
#   'living',
#   'are',
#   'what',
#   'im',
#   'here',
#   'to',
#   'contribute'],
#  ['i',
#   'only',
#   'have',
#   'to',
#   'think',
#   'about',
#   'a',
#   'high',
#   'school',
#   'experience',
#   'and',
#   'i',
#   'instantly',
#   'feel',
#   'like',
#   'that',
#   'shy',
#   'confused',
#   'and',
#   'terrorised',
#   'teenager',
#   'again'],
#  ['i',
#   'am',
#   'feeling',
#   'unsure',
#   'about',
#   'my',
#   'words',
#   'but',
#   'it',
#   'also',
#   'means',
#   'i',
#   'am',
#   'writing',
#   'which',
#   'is',
#   'good'],
#  ['i',
#   'feel',
#   'equally',
#   'morally',
#   'outraged',
#   'regardless',
#   'of',
#   'whether',
#   'its',
#   'michigans',
#   'or',
#   'new',
#   'yorks',
#   'governor',
#   'sleeping',
#   'with',
#   'prostitutes',
#   'behind',
#   'his',
#   'wifes',
#   'and',
#   'daughters',
#   'backs'],
#  ['i',
#   'didn',
#   't',
#   'have',
#   'feelings',
#   'for',
#   'them',
#   'but',
#   'seriously',
#   'after',
#   'a',
#   'while',
#   'how',
#   'do',
#   'you',
#   'feel',
#   'love',
#   'for',
#   'someone',
#   'who',
#   'treats',
#   'you',
#   'with',
#   'such',
#   'disregard',
#   'i',
#   'was',
#   'faithful',
#   'and',
#   'loyal'],
#  ['ive',
#   'found',
#   'it',
#   'has',
#   'made',
#   'a',
#   'huge',
#   'difference',
#   'especially',
#   'on',
#   'the',
#   'finger',
#   'with',
#   'my',
#   'ring',
#   'and',
#   'the',
#   'my',
#   'skin',
#   'feels',
#   'so',
#   'much',
#   'softer',
#   'and',
#   'less',
#   'irritated'],
#  ['i',
#   'feel',
#   'pleased',
#   'but',
#   'at',
#   'the',
#   'same',
#   'time',
#   'i',
#   'really',
#   'don',
#   't',
#   'understand',
#   'why',
#   'do',
#   'we',
#   'feel',
#   'this',
#   'patriotism',
#   'only',
#   'twice',
#   'every',
#   'year'],
#  ['i',
#   'am',
#   'really',
#   'not',
#   'expecting',
#   'it',
#   'somehow',
#   'it',
#   'made',
#   'me',
#   'feel',
#   'shy',
#   'but',
#   'then',
#   'it',
#   's',
#   'been',
#   'a',
#   'while',
#   'part'],
#  ['im',
#   'feeling',
#   'rather',
#   'bothered',
#   'because',
#   'my',
#   'physical',
#   'and',
#   'mental',
#   'clock',
#   'is',
#   'still',
#   'in',
#   'october'],
#  ['i',
#   'grin',
#   'and',
#   'kiss',
#   'my',
#   'way',
#   'down',
#   'his',
#   'body',
#   'the',
#   'same',
#   'way',
#   'he',
#   'd',
#   'done',
#   'to',
#   'me',
#   'except',
#   'with',
#   'less',
#   'teeth',
#   'because',
#   'i',
#   'm',
#   'feeling',
#   'rather',
#   'mellow',
#   'and',
#   'content',
#   'at',
#   'the',
#   'moment'],
#  ['i',
#   'feel',
#   'that',
#   'if',
#   'he',
#   'hadnt',
#   'appeared',
#   'out',
#   'of',
#   'nowhere',
#   'and',
#   'distracted',
#   'me',
#   'i',
#   'would',
#   'have',
#   'noticed',
#   'the',
#   'light',
#   'change',
#   'and',
#   'none',
#   'of',
#   'this',
#   'would',
#   'have',
#   'happened'],
#  ['i',
#   'feel',
#   'like',
#   'i',
#   'enter',
#   'his',
#   'class',
#   'petrified',
#   'that',
#   'im',
#   'going',
#   'to',
#   'do',
#   'or',
#   'say',
#   'something',
#   'that',
#   'will',
#   'make',
#   'him',
#   'think',
#   'less',
#   'of',
#   'me'],
#  ['i', 'feel', 'innocent', 'and', 'free', 'again'],
#  ['i',
#   'sympathize',
#   'with',
#   'this',
#   'person',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'a',
#   'bit',
#   'skeptical',
#   'the',
#   'theme',
#   'is',
#   'loss',
#   'because',
#   'everyone',
#   'looses'],
#  ['im',
#   'not',
#   'going',
#   'to',
#   'lie',
#   'sometimes',
#   'hearing',
#   'myself',
#   'say',
#   'some',
#   'of',
#   'the',
#   'things',
#   'on',
#   'my',
#   'recordings',
#   'makes',
#   'me',
#   'feel',
#   'weird',
#   'and',
#   'insecure',
#   'but',
#   'just',
#   'like',
#   'the',
#   'quote',
#   'states',
#   'above',
#   'its',
#   'a',
#   'good',
#   'thing'],
#  ['i',
#   'feel',
#   'i',
#   'wear',
#   'what',
#   'i',
#   'wear',
#   'to',
#   'show',
#   'other',
#   'girls',
#   'at',
#   'my',
#   'school',
#   'who',
#   'are',
#   'timid',
#   'when',
#   'it',
#   'comes',
#   'to',
#   'fashion',
#   'that',
#   'you',
#   'won',
#   't',
#   'look',
#   'weird',
#   'if',
#   'you',
#   'walk',
#   'around',
#   'with',
#   'your',
#   'head',
#   'held',
#   'high'],
#  ['i',
#   'think',
#   'a',
#   'lot',
#   'of',
#   'the',
#   'fun',
#   'there',
#   'is',
#   'in',
#   'meeting',
#   'the',
#   'players',
#   'expectation',
#   'and',
#   'making',
#   'the',
#   'player',
#   'feel',
#   'clever',
#   'making',
#   'it',
#   'seem',
#   'like',
#   'they',
#   're',
#   'not',
#   'just',
#   'clicking',
#   'on',
#   'an',
#   'option',
#   'you',
#   'know'],
#  ['i',
#   'try',
#   'to',
#   'approach',
#   'this',
#   'thing',
#   'called',
#   'nature',
#   'which',
#   'is',
#   'something',
#   'im',
#   'feeling',
#   'a',
#   'bit',
#   'envious',
#   'about'],
#  ['i',
#   'know',
#   'im',
#   'quite',
#   'selfish',
#   'but',
#   'sometimes',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'dont',
#   'want',
#   'to',
#   'throw',
#   'everything',
#   'just',
#   'for',
#   'something',
#   'that',
#   'is',
#   'uncertain'],
#  ['i',
#   'refuse',
#   'to',
#   'rate',
#   'the',
#   'book',
#   'but',
#   'if',
#   'she',
#   'and',
#   'her',
#   'publisher',
#   'feel',
#   'snobbish',
#   'then',
#   'take',
#   'it',
#   'from',
#   'me',
#   'when',
#   'i',
#   'say',
#   'jeanette',
#   'winterson',
#   'can',
#   'not',
#   'write',
#   'and',
#   'essentially',
#   'does',
#   'not',
#   'do',
#   'wish',
#   'to',
#   'do',
#   'anything',
#   'with',
#   'the',
#   'scope',
#   'to',
#   'explore'],
#  ['im',
#   'afraid',
#   'im',
#   'in',
#   'an',
#   'environment',
#   'that',
#   'makes',
#   'me',
#   'feel',
#   'more',
#   'relaxed',
#   'cause'],
#  ['i',
#   'wish',
#   'i',
#   'knew',
#   'how',
#   'he',
#   'was',
#   'really',
#   'feeling',
#   'aside',
#   'from',
#   'reading',
#   'the',
#   'nervous',
#   'twitches'],
#  ['i', 'this', 'feels', 'rebellious', 'to', 'me'],
#  ['i',
#   'still',
#   'think',
#   'it',
#   'is',
#   'worth',
#   'posting',
#   'here',
#   'as',
#   'a',
#   'reminder',
#   'for',
#   'the',
#   'next',
#   'time',
#   'i',
#   'feel',
#   'anxious'],
#  ['i',
#   'feel',
#   'completely',
#   'unsure',
#   'of',
#   'any',
#   'boundaries',
#   'or',
#   'normalcy'],
#  ['i', 'was', 'feeling', 'extremely', 'anxious'],
#  ['ill',
#   'write',
#   'a',
#   'bunch',
#   'youll',
#   'respond',
#   'and',
#   'then',
#   'ill',
#   'back',
#   'off',
#   'in',
#   'part',
#   'because',
#   'i',
#   'feel',
#   'shy'],
#  ['i',
#   'am',
#   'posting',
#   'about',
#   'a',
#   'past',
#   'event',
#   'where',
#   'i',
#   'am',
#   'feeling',
#   'like',
#   'i',
#   'should',
#   'be',
#   'insulted'],
#  ['i',
#   'suspect',
#   'i',
#   'was',
#   'also',
#   'dealing',
#   'with',
#   'caffeine',
#   'withdrawal',
#   'but',
#   'i',
#   'think',
#   'i',
#   'have',
#   'now',
#   'figured',
#   'out',
#   'a',
#   'system',
#   'of',
#   'eating',
#   'which',
#   'works',
#   'well',
#   'for',
#   'me',
#   'and',
#   'i',
#   'feel',
#   'fab'],
#  ['i',
#   'woke',
#   'up',
#   'feeling',
#   'shaky',
#   'and',
#   'nauseous',
#   'with',
#   'lots',
#   'of',
#   'cramping',
#   'and',
#   'pressure',
#   'in',
#   'my',
#   'abdomen',
#   'and',
#   'pelvis'],
#  ['i',
#   'feel',
#   'like',
#   'that',
#   'leaves',
#   'me',
#   'as',
#   'the',
#   'artistic',
#   'equivalent',
#   'of',
#   'the',
#   'crack',
#   'between',
#   'couch',
#   'cushions'],
#  ['i',
#   'will',
#   'say',
#   'that',
#   'a',
#   'little',
#   'piece',
#   'of',
#   'me',
#   'feels',
#   'agitated',
#   'when',
#   'i',
#   'watch',
#   'discussions',
#   'on',
#   'race',
#   'and',
#   'there',
#   'will',
#   'i',
#   'style',
#   'color',
#   'font',
#   'family',
#   'georgia',
#   'serif',
#   'font',
#   'size',
#   'px',
#   'line',
#   'height'],
#  ['i',
#   'left',
#   'feeling',
#   'helpless',
#   'and',
#   'more',
#   'than',
#   'a',
#   'little',
#   'sad'],
#  ['i',
#   'am',
#   'friendly',
#   'and',
#   'so',
#   'easy',
#   'to',
#   'talk',
#   'to',
#   'if',
#   'only',
#   'you',
#   'are',
#   'open',
#   'to',
#   'knowing',
#   'me',
#   'as',
#   'a',
#   'friend',
#   'and',
#   'not',
#   'from',
#   'a',
#   'top',
#   'down',
#   'approach',
#   'cos',
#   'i',
#   'feel',
#   'intimidated',
#   'and',
#   'when',
#   'i',
#   'only',
#   'know',
#   'i',
#   'do',
#   'not',
#   'want',
#   'to',
#   'offend',
#   'somebody',
#   'i',
#   'shut',
#   'up'],
#  ['realizing',
#   'that',
#   'a',
#   'friend',
#   'had',
#   'been',
#   'talked',
#   'into',
#   'signing',
#   'a',
#   'certain',
#   'contract'],
#  ['i',
#   'always',
#   'feel',
#   'i',
#   'always',
#   'understand',
#   'that',
#   'the',
#   'people',
#   'who',
#   'are',
#   'being',
#   'the',
#   'most',
#   'hateful',
#   'and',
#   'harmful',
#   'towards',
#   'me',
#   'are',
#   'hurting',
#   'themselves',
#   'and',
#   'taught',
#   'wrongly',
#   'and',
#   'i',
#   'hurt',
#   'for',
#   'them',
#   'because',
#   'i',
#   'want',
#   'to',
#   'go',
#   'back',
#   'and',
#   'undo',
#   'the',
#   'pain',
#   'and',
#   'childhood',
#   'bigotry',
#   'that',
#   'binds',
#   'their',
#   'lives',
#   'into',
#   'this',
#   'path'],
#  ['i',
#   'think',
#   'just',
#   'noticing',
#   'this',
#   'in',
#   'me',
#   'that',
#   'i',
#   'm',
#   'more',
#   'prone',
#   'to',
#   'feel',
#   'jealous',
#   'right',
#   'now',
#   'is',
#   'helping',
#   'me',
#   'show',
#   'up',
#   'with',
#   'a',
#   'bit',
#   'more',
#   'intentionality',
#   'than',
#   'at',
#   'other',
#   'times',
#   'in',
#   'my',
#   'life'],
#  ['i',
#   'wasn',
#   't',
#   'thinking',
#   'negatively',
#   'about',
#   'any',
#   'of',
#   'those',
#   'things',
#   'often',
#   'the',
#   'feeling',
#   'was',
#   'benign',
#   'or',
#   'actually',
#   'an',
#   'excited',
#   'anticipation'],
#  ['i', 'remember', 'feeling', 'frantic', 'at', 'this', 'point'],
#  ['i',
#   'feel',
#   'like',
#   'i',
#   'can',
#   'trust',
#   'them',
#   'though',
#   'seeing',
#   'how',
#   'they',
#   'can',
#   'understand',
#   'how',
#   'other',
#   'women',
#   'can',
#   'be',
#   'bitchy',
#   'and',
#   'neither',
#   'of',
#   'us',
#   'want',
#   'to',
#   'deal',
#   'with',
#   'that',
#   'shit'],
#  ['id',
#   'gotten',
#   'the',
#   'feeling',
#   'that',
#   'her',
#   'friend',
#   'hated',
#   'me',
#   'deeply',
#   'for',
#   'whatever',
#   'id',
#   'done',
#   'to',
#   'her'],
#  ['ive', 'been', 'feeling', 'immensely', 'overwhelmed'],
#  ['i',
#   'do',
#   'not',
#   'believe',
#   'guns',
#   'are',
#   'the',
#   'solution',
#   'to',
#   'feeling',
#   'afraid'],
#  ['i',
#   'feel',
#   'so',
#   'honored',
#   'that',
#   'students',
#   'come',
#   'to',
#   'my',
#   'classes'],
#  ['i', 'feel', 'fine', 'read', 'the', 'rest'],
#  ['i',
#   'hate',
#   'the',
#   'way',
#   'mom',
#   'and',
#   'dad',
#   'are',
#   'to',
#   'her',
#   'i',
#   'hate',
#   'the',
#   'neglect',
#   'of',
#   'her',
#   'feelings',
#   'and',
#   'her',
#   'needs',
#   'as',
#   'an',
#   'intelligent',
#   'child',
#   'that',
#   'are',
#   'rampant',
#   'in',
#   'their',
#   'parenting',
#   'style'],
#  ['i',
#   'was',
#   'feeling',
#   'pretty',
#   'grumpy',
#   'at',
#   'this',
#   'point',
#   'but',
#   'for',
#   'whatever',
#   'reason',
#   'seeing',
#   'this',
#   'flower',
#   'made',
#   'me',
#   'very',
#   'happy'],
#  ['i', 'go', 'to', 'bed', 'feeling', 'very', 'distraught', 'otherwise'],
#  ['i',
#   'suddenly',
#   'feel',
#   'anxious',
#   'im',
#   'crying',
#   'over',
#   'little',
#   'things'],
#  ['i', 'don', 't', 'feel', 'that', 'irritated'],
#  ['i',
#   'was',
#   'feeling',
#   'grouchy',
#   'and',
#   'the',
#   'old',
#   'man',
#   'has',
#   'mentioned',
#   'that',
#   'retail',
#   'therapy',
#   'is',
#   'great'],
#  ['im',
#   'going',
#   'to',
#   'sleep',
#   'now',
#   'while',
#   'i',
#   'still',
#   'feel',
#   'triumphant'],
#  ['im',
#   'looking',
#   'good',
#   'and',
#   'feeling',
#   'good',
#   'other',
#   'than',
#   'this',
#   'crappy',
#   'cold',
#   'im',
#   'dealing',
#   'with'],
#  ['i',
#   'am',
#   'feeling',
#   'a',
#   'bit',
#   'doubtful',
#   'of',
#   'myself',
#   'the',
#   'last',
#   'couple',
#   'of',
#   'weeks'],
#  ['i',
#   'didnt',
#   'feel',
#   'safe',
#   'in',
#   'my',
#   'room',
#   'because',
#   'the',
#   'argument',
#   'was',
#   'going',
#   'on',
#   'in',
#   'my',
#   'room',
#   'and',
#   'things',
#   'were',
#   'getting',
#   'rough'],
#  ['i',
#   'may',
#   'be',
#   'starting',
#   'to',
#   'feel',
#   'paranoid',
#   'or',
#   'maybe',
#   'insecure',
#   'but',
#   'im',
#   'just',
#   'a',
#   'mere',
#   'human',
#   'being',
#   'who',
#   'yearns',
#   'to',
#   'be',
#   'loved',
#   'to',
#   'be',
#   'cared',
#   'of',
#   'and',
#   'to',
#   'be',
#   'noticed'],
#  ['i',
#   'am',
#   'not',
#   'strong',
#   'that',
#   'i',
#   'feel',
#   'scared',
#   'lonely',
#   'lost',
#   'and',
#   'confused'],
#  ['im',
#   'happy',
#   'to',
#   'have',
#   'this',
#   'in',
#   'my',
#   'kitchen',
#   'but',
#   'it',
#   'feels',
#   'like',
#   'someone',
#   'rushed',
#   'this',
#   'out',
#   'and',
#   'cut',
#   'corners'],
#  ['during', 'the', 'weekend', 'at', 'home'],
#  ['im', 'feeling', 'so', 'so', 'insecure'],
#  ['i',
#   'feel',
#   'pressured',
#   'to',
#   'come',
#   'up',
#   'with',
#   'something',
#   'else',
#   'funny',
#   'to',
#   'write',
#   'about'],
#  ['i',
#   'really',
#   'like',
#   'the',
#   'job',
#   'so',
#   'far',
#   'and',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'am',
#   'genuinely',
#   'putting',
#   'some',
#   'good',
#   'out',
#   'into',
#   'the',
#   'world'],
#  ['i',
#   'drove',
#   'dannika',
#   'to',
#   'school',
#   'i',
#   'was',
#   'feeling',
#   'a',
#   'little',
#   'bit',
#   'rushed',
#   'and',
#   'this',
#   'is',
#   'what',
#   'greeted',
#   'me',
#   'as',
#   'i',
#   'turned',
#   'the',
#   'corner'],
#  ['i', 'feel', 'more', 'clever'],
#  ['i', 'usually', 'start', 'feeling', 'anxious'],
#  ['i', 'feel', 'pressured', 'to', 'talk', 'to', 'them'],
#  ['i',
#   'thinks',
#   'this',
#   'chiefs',
#   'ccw',
#   'should',
#   'be',
#   'yanked',
#   'by',
#   'the',
#   'state',
#   'as',
#   'i',
#   'feel',
#   'threatened'],
#  ['i', 'feel', 'petrified', 'about', 'his', 'future'],
#  ['i',
#   'get',
#   'the',
#   'feeling',
#   'that',
#   'nellie',
#   'is',
#   'satisfied',
#   'that',
#   'the',
#   'phone',
#   'rang',
#   'happy',
#   'that',
#   'leslie',
#   'is',
#   'out',
#   'of',
#   'the',
#   'room',
#   'now'],
#  ['i',
#   'feel',
#   'that',
#   'uncertain',
#   'should',
#   'be',
#   'a',
#   'better',
#   'communicator'],
#  ['i',
#   'feel',
#   'really',
#   'successful',
#   'for',
#   'the',
#   'fact',
#   'that',
#   'i',
#   'read',
#   'series',
#   'books',
#   'this',
#   'summer',
#   'that',
#   'actually',
#   'counted',
#   'for',
#   'the',
#   'challenge',
#   'finishing',
#   'six',
#   'total',
#   'series'],
#  ['i',
#   'see',
#   'other',
#   'people',
#   'writing',
#   'about',
#   'love',
#   'when',
#   'they',
#   'have',
#   'just',
#   'brokeup',
#   'and',
#   'finding',
#   'another',
#   'person',
#   'in',
#   'his',
#   'her',
#   'life',
#   'i',
#   'kinda',
#   'feel',
#   'so',
#   'disgusted'],
#  ['i',
#   'were',
#   'to',
#   'create',
#   'a',
#   'piece',
#   'similar',
#   'to',
#   'this',
#   'again',
#   'i',
#   'would',
#   'improve',
#   'on',
#   'it',
#   'by',
#   'spending',
#   'more',
#   'time',
#   'on',
#   'the',
#   'background',
#   'as',
#   'i',
#   'feel',
#   'i',
#   'rushed',
#   'this',
#   'and',
#   'it',
#   'could',
#   'have',
#   'been',
#   'more',
#   'detailed'],
#  ['i',
#   'was',
#   'feeling',
#   'stressed',
#   'or',
#   'run',
#   'down',
#   'to',
#   'support',
#   'the',
#   'immune',
#   'system'],
#  ['i', 'feel', 'a', 'bit', 'pissed', 'off', 'because', 'we', 'went', 'first'],
#  ['i',
#   'prayed',
#   'for',
#   'love',
#   'for',
#   'the',
#   'people',
#   'that',
#   'i',
#   'was',
#   'feeling',
#   'bitter',
#   'towards',
#   'and',
#   'that',
#   'they',
#   'would',
#   'find',
#   'what',
#   'was',
#   'best',
#   'for',
#   'them'],
#  ['i', 'feel', 'our', 'hearts', 'are', 'treading', 'dangerous', 'territory'],
#  ['i', 'feel', 'i', 'really', 'wronged', 'commodore'],
#  ['im',
#   'not',
#   'emo',
#   'ing',
#   'no',
#   'no',
#   'no',
#   'haha',
#   'i',
#   'am',
#   'feeling',
#   'happy',
#   'instead',
#   'for',
#   'being',
#   'able',
#   'to',
#   'meet',
#   'up',
#   'with',
#   'them'],
#  ['i',
#   'was',
#   'the',
#   'compere',
#   'at',
#   'a',
#   'party',
#   'and',
#   'all',
#   'my',
#   'efforts',
#   'to',
#   'get',
#   'the',
#   'show',
#   'rolling',
#   'were',
#   'thwarted',
#   'by',
#   'the',
#   'immobile'],
#  ['i',
#   'kinda',
#   'feel',
#   'like',
#   'being',
#   'rebellious',
#   'a',
#   'libertine',
#   'you',
#   'know'],
#  ['i',
#   'feel',
#   'that',
#   'educating',
#   'families',
#   'and',
#   'supporting',
#   'and',
#   'educationg',
#   'mamas',
#   'and',
#   'papas',
#   'is',
#   'key'],
#  ['i',
#   'wear',
#   'this',
#   'shirt',
#   'i',
#   'feel',
#   'artistic',
#   'you',
#   'are',
#   'artistic',
#   'but',
#   'now',
#   'i',
#   'look',
#   'artistic',
#   'yes',
#   'son',
#   'you',
#   'do'],
#  ['i',
#   'feel',
#   'like',
#   'having',
#   'that',
#   'sweet',
#   'carby',
#   'yet',
#   'low',
#   'glycemic',
#   'meal',
#   'not',
#   'just',
#   'at',
#   'breakfast',
#   'but',
#   'often',
#   'for',
#   'dessert'],
#  ['i',
#   'could',
#   'sense',
#   'that',
#   'he',
#   'was',
#   'uncomfortable',
#   'when',
#   'he',
#   'came',
#   'to',
#   'deliver',
#   'the',
#   'letter',
#   'but',
#   'i',
#   'was',
#   'willing',
#   'to',
#   'attribute',
#   'to',
#   'him',
#   'feeling',
#   'weird',
#   'about',
#   'being',
#   'so',
#   'romantic',
#   'and',
#   'vulnerable'],
#  ['i', 'feel', 'so', 'vulnerable'],
#  ['i',
#   'am',
#   'feeling',
#   'envious',
#   'of',
#   'other',
#   'nations',
#   'that',
#   'despite',
#   'the',
#   'very',
#   'small',
#   'land'],
#  ['i', 'woke', 'up', 'feeling', 'cranky', 'this', 'morning'],
#  ['i',
#   'will',
#   'close',
#   'my',
#   'eyes',
#   'and',
#   'recite',
#   'the',
#   'following',
#   'mantra',
#   'every',
#   'day',
#   'and',
#   'whenever',
#   'i',
#   'm',
#   'feeling',
#   'unsure',
#   'frustrated',
#   'or',
#   'shiftless',
#   'with',
#   'my',
#   'progress',
#   'towards',
#   'my',
#   'top',
#   'body'],
#  ['i',
#   'feel',
#   'reluctant',
#   'to',
#   'talk',
#   'about',
#   'an',
#   'issue',
#   'which',
#   'is',
#   'so',
#   'immediate',
#   'especially',
#   'as',
#   'one',
#   'can',
#   'not',
#   'make',
#   'too',
#   'much',
#   'of',
#   'a',
#   'difference',
#   'about',
#   'it',
#   'individually',
#   'but',
#   'what',
#   'i',
#   'can',
#   'do',
#   'is',
#   'to',
#   'spread',
#   'the',
#   'word'],
#  ['im',
#   'continually',
#   'feeling',
#   'triggered',
#   'im',
#   'not',
#   'sure',
#   'if',
#   'people',
#   'are',
#   'insensitive',
#   'or',
#   'if',
#   'im',
#   'selfish',
#   'most',
#   'likely',
#   'the',
#   'latter'],
#  ['i',
#   'am',
#   'baffled',
#   'hurt',
#   'that',
#   'i',
#   'feel',
#   'assaulted',
#   'and',
#   'unsafe'],
#  ['i',
#   'have',
#   'a',
#   'feeling',
#   'she',
#   'is',
#   'going',
#   'to',
#   'be',
#   'an',
#   'amazing',
#   'artist',
#   'like',
#   'her',
#   'daddy',
#   'and',
#   'uncles'],
#  ['i', 'still', 'feel', 'a', 'craving', 'for', 'sweet', 'food'],
#  ['i',
#   'couldn',
#   't',
#   'turn',
#   'my',
#   'head',
#   'away',
#   'even',
#   'when',
#   'i',
#   'feel',
#   'frightened'],
#  ['i',
#   'understand',
#   'but',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'hated',
#   'my',
#   'friends'],
#  ['when',
#   'in',
#   'a',
#   'car',
#   'accident',
#   'where',
#   'car',
#   'was',
#   'total',
#   'wipe',
#   'off',
#   'wipe',
#   'out'],
#  ['i', 'feel', 'stressed', 'he', 'gets', 'upset', 'for', 'that', 'too'],
#  ['i', 'feel', 'so', 'nervous', 'for', 'them'],
#  ['i',
#   'am',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'and',
#   'i',
#   'hear',
#   'the',
#   'squeak',
#   'of',
#   'a',
#   'baachan',
#   'trolley',
#   'i',
#   'feel',
#   'a',
#   'little',
#   'paranoid'],
#  ['id', 'feel', 'better'],
#  ['im',
#   'good',
#   'at',
#   'hiding',
#   'my',
#   'true',
#   'feelings',
#   'or',
#   'blurting',
#   'them',
#   'out',
#   'in',
#   'sarcastic',
#   'tones'],
#  ['i',
#   'got',
#   'upset',
#   'when',
#   'i',
#   'feel',
#   'that',
#   'the',
#   'only',
#   'person',
#   'whos',
#   'uptight',
#   'on',
#   'chatting',
#   'is',
#   'just',
#   'me'],
#  ['i',
#   'feel',
#   'that',
#   'there',
#   'is',
#   'a',
#   'clever',
#   'caption',
#   'in',
#   'the',
#   'making',
#   'here',
#   'but',
#   'im',
#   'not',
#   'quite',
#   'feeling',
#   'well',
#   'enough',
#   'to',
#   'provide',
#   'one',
#   'myself'],
#  ['i',
#   'first',
#   'held',
#   'my',
#   'scotty',
#   'i',
#   'knew',
#   'i',
#   'was',
#   'in',
#   'love',
#   'with',
#   'my',
#   'high',
#   'priced',
#   'bundle',
#   'of',
#   'joy',
#   'but',
#   'i',
#   'couldnt',
#   'help',
#   'feeling',
#   'apprehensive',
#   'about',
#   'what',
#   'the',
#   'time',
#   'to',
#   'come',
#   'holds'],
#  ['i',
#   'have',
#   'been',
#   'feeling',
#   'so',
#   'strange',
#   'and',
#   'frankly',
#   'bad',
#   'about',
#   'how',
#   'not',
#   'sad',
#   'i',
#   'am'],
#  ['i', 'feel', 'like', 'im', 'tortured', 'like', 'years', 'ago'],
#  ['i',
#   'am',
#   'for',
#   'the',
#   'first',
#   'time',
#   'this',
#   'year',
#   'feeling',
#   'the',
#   'cold'],
#  ['i',
#   'feel',
#   'tortured',
#   'because',
#   'i',
#   'am',
#   'not',
#   'allowed',
#   'to',
#   'enjoy',
#   'food',
#   'the',
#   'way',
#   'my',
#   'friend',
#   'can'],
#  ['i',
#   'used',
#   'to',
#   'feel',
#   'pretty',
#   'friendly',
#   'with',
#   'started',
#   'spouting',
#   'off',
#   'about',
#   'how',
#   'russia',
#   'is',
#   'running',
#   'a',
#   'muck',
#   'for',
#   'no',
#   'reason',
#   'that',
#   'they',
#   'dont',
#   'give',
#   'a',
#   'shit',
#   'about',
#   'their',
#   'citizens',
#   'and',
#   'that',
#   'they',
#   'cant',
#   'be',
#   'trusted'],
#  ['i',
#   'am',
#   'not',
#   'a',
#   'regular',
#   'member',
#   'of',
#   'this',
#   'group',
#   'meaning',
#   'that',
#   'i',
#   'do',
#   'not',
#   'follow',
#   'whats',
#   'going',
#   'on',
#   'very',
#   'often',
#   'and',
#   'also',
#   'i',
#   'feel',
#   'a',
#   'bit',
#   'shy',
#   'in',
#   'budding',
#   'in',
#   'when',
#   'i',
#   'do',
#   'not',
#   'have',
#   'much',
#   'to',
#   'say',
#   'but',
#   'today',
#   'i',
#   'have',
#   'a',
#   'request',
#   'for',
#   'you',
#   'people'],
#  ['im', 'frightened', 'and', 'feeling', 'paranoid'],
#  ['i',
#   'feel',
#   'very',
#   'distressed',
#   'because',
#   'i',
#   'm',
#   'supportive',
#   'of',
#   'this',
#   'campaign',
#   'and',
#   'with',
#   'the',
#   'senator',
#   'jackson',
#   'told',
#   'cnn'],
#  ['i',
#   'feel',
#   'helpless',
#   'about',
#   'not',
#   'being',
#   'able',
#   'to',
#   'help',
#   'him',
#   'in',
#   'feeling',
#   'better',
#   'but',
#   'do',
#   'my',
#   'best',
#   'to',
#   'encourage',
#   'him',
#   'and',
#   'think',
#   'positively',
#   'as',
#   'mom',
#   'is',
#   'doing'],
#  ['i',
#   'feel',
#   'as',
#   'though',
#   'i',
#   'don',
#   't',
#   'write',
#   'about',
#   'them',
#   'often',
#   'enough',
#   'but',
#   'they',
#   'are',
#   'just',
#   'cruising',
#   'through',
#   'life',
#   'in',
#   'their',
#   'own',
#   'equally',
#   'special',
#   'ways'],
#  ['im',
#   'a',
#   'firm',
#   'believer',
#   'that',
#   'nothing',
#   'makes',
#   'a',
#   'woman',
#   'feel',
#   'much',
#   'more',
#   'terrific',
#   'than',
#   'a',
#   'great',
#   'trip',
#   'to',
#   'the',
#   'salon',
#   'to',
#   'lift',
#   'her',
#   'spirits',
#   'a',
#   'bit'],
#  ['i',
#   'feel',
#   'shaken',
#   'open',
#   'as',
#   'though',
#   'my',
#   'heart',
#   'were',
#   'broken',
#   'into',
#   'and',
#   'there',
#   'are',
#   'no',
#   'words',
#   'to',
#   'speak'],
#  ['i',
#   'just',
#   'didnt',
#   'feel',
#   'they',
#   'got',
#   'me',
#   'which',
#   'meant',
#   'i',
#   'was',
#   'reluctant',
#   'to',
#   'open',
#   'up',
#   'and',
#   'really',
#   'share',
#   'what',
#   'was',
#   'going',
#   'on'],
#  ['i',
#   'wake',
#   'up',
#   'in',
#   'the',
#   'morning',
#   'and',
#   'have',
#   'my',
#   'voice',
#   'and',
#   'my',
#   'throat',
#   'feels',
#   'ok',
#   'but',
#   'by',
#   'the',
#   'afternoon',
#   'its',
#   'all',
#   'scratchy',
#   'again',
#   'and',
#   'i',
#   'sound',
#   'like',
#   'marge',
#   'simpson',
#   'until',
#   'the',
#   'night',
#   'when',
#   'its',
#   'so',
#   'bad',
#   'and',
#   'my',
#   'throat',
#   'is',
#   'so',
#   'sore',
#   'i',
#   'just',
#   'have',
#   'to',
#   'whisper'],
#  ['i',
#   'just',
#   'make',
#   'assumptions',
#   'based',
#   'on',
#   'what',
#   'i',
#   'see',
#   'think',
#   'feel',
#   'i',
#   've',
#   'wondered',
#   'this',
#   'before',
#   'with',
#   'strange',
#   'things'],
#  ['i', 'feel', 'pressured', 'to', 'say', 'something'],
#  ['i',
#   'was',
#   'a',
#   'smoker',
#   'for',
#   'years',
#   'and',
#   'quit',
#   'weeks',
#   'ago',
#   'right',
#   'after',
#   'i',
#   'finished',
#   'your',
#   'book',
#   'and',
#   'i',
#   'cant',
#   'believe',
#   'how',
#   'free',
#   'i',
#   'feel',
#   'i',
#   'knew',
#   'that',
#   'i',
#   'had',
#   'to',
#   'quit',
#   'but',
#   'i',
#   'was',
#   'terrified',
#   'of',
#   'my',
#   'life',
#   'without',
#   'cigarettes'],
#  ['i',
#   'have',
#   'read',
#   'and',
#   'experienced',
#   'going',
#   'vegetarian',
#   'to',
#   'vegan',
#   'from',
#   'a',
#   'meat',
#   'eater',
#   'how',
#   'the',
#   'toxins',
#   'leave',
#   'your',
#   'body',
#   'and',
#   'make',
#   'you',
#   'feel',
#   'irritable',
#   'and',
#   'grumpy'],
#  ['i',
#   'hated',
#   'that',
#   'i',
#   'hurt',
#   'him',
#   'with',
#   'my',
#   'feelings',
#   'i',
#   'hated',
#   'that',
#   'i',
#   'was',
#   'dating',
#   'somebody',
#   'i',
#   'didn',
#   't',
#   'love',
#   'i',
#   'hated',
#   'that',
#   'i',
#   'pretended',
#   'lied',
#   'to',
#   'a',
#   'friend',
#   'i',
#   'really',
#   'treassured'],
#  ['i',
#   'was',
#   'feeling',
#   'grouchy',
#   'and',
#   'upset',
#   'about',
#   'a',
#   'situation',
#   'with',
#   'a',
#   'girl',
#   'which',
#   'wasn',
#   't',
#   'going',
#   'how',
#   'i',
#   'd',
#   'hoped'],
#  ['i',
#   'feel',
#   'have',
#   'been',
#   'convinced',
#   'by',
#   'many',
#   'factors',
#   'in',
#   'our',
#   'culture',
#   'of',
#   'a',
#   'kind',
#   'of',
#   'cooking',
#   'mystique'],
#  ['i',
#   'dont',
#   'know',
#   'why',
#   'i',
#   'feel',
#   'so',
#   'unsure',
#   'aout',
#   'things',
#   'and',
#   'especially',
#   'people'],
#  ['i',
#   'call',
#   'someone',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'need',
#   'to',
#   'at',
#   'least',
#   'talk',
#   'a',
#   'few',
#   'minutes',
#   'to',
#   'not',
#   'be',
#   'rude'],
#  ['i',
#   'try',
#   'to',
#   'remember',
#   'that',
#   'quote',
#   'when',
#   'i',
#   'feel',
#   'i',
#   'may',
#   'be',
#   'hitting',
#   'a',
#   'wall',
#   'in',
#   'a',
#   'marathon',
#   'or',
#   'even',
#   'a',
#   'training',
#   'run',
#   'and',
#   'i',
#   'know',
#   'it',
#   'is',
#   'time',
#   'to',
#   'find',
#   'that',
#   'perfect',
#   'song',
#   'that',
#   'fuel'],
#  ['i',
#   'did',
#   'wake',
#   'up',
#   'this',
#   'morning',
#   'feeling',
#   'more',
#   'like',
#   'myself',
#   'so',
#   'after',
#   'days',
#   'of',
#   'sloth',
#   'i',
#   'was',
#   'keen',
#   'to',
#   'get',
#   'geared',
#   'up',
#   'and',
#   'head',
#   'to',
#   'higher',
#   'altitudes'],
#  ['i',
#   'throw',
#   'it',
#   'out',
#   'there',
#   'the',
#   'better',
#   'ill',
#   'feel',
#   'heck',
#   'im',
#   'paranoid',
#   'up',
#   'such',
#   'a',
#   'tree',
#   'brach',
#   'right',
#   'now',
#   'i',
#   'jumped',
#   'when',
#   'a',
#   'chipmunk',
#   'crossed',
#   'my',
#   'path',
#   'when',
#   'i',
#   'went',
#   'walking',
#   'today'],
#  ['i',
#   'can',
#   't',
#   'get',
#   'past',
#   'is',
#   'that',
#   'feeling',
#   'when',
#   'a',
#   'friend',
#   'walks',
#   'out',
#   'of',
#   'your',
#   'life',
#   'and',
#   'you',
#   're',
#   'unsure',
#   'why',
#   'that',
#   'feeling',
#   'of',
#   'not',
#   'being',
#   'valued',
#   'or',
#   'important',
#   'enough'],
#  ['i',
#   'can',
#   'feel',
#   'the',
#   'beginnings',
#   'of',
#   'a',
#   'cold',
#   'so',
#   'i',
#   'figured',
#   'i',
#   'deserve',
#   'a',
#   'heinously',
#   'hot',
#   'bath'],
#  ['i',
#   'feel',
#   'really',
#   'irritable',
#   'when',
#   'im',
#   'surrounded',
#   'with',
#   'it'],
#  ['i',
#   'need',
#   'that',
#   'warmth',
#   'to',
#   'remind',
#   'me',
#   'hes',
#   'there',
#   'when',
#   'life',
#   'feels',
#   'cold',
#   'and',
#   'empty'],
#  ['i',
#   'guess',
#   'ive',
#   'heard',
#   'enough',
#   'over',
#   'the',
#   'two',
#   'months',
#   'because',
#   'each',
#   'time',
#   'i',
#   'hear',
#   'such',
#   'comments',
#   'i',
#   'honestly',
#   'feel',
#   'offended'],
#  ['i',
#   'feel',
#   'more',
#   'superior',
#   'dead',
#   'chicken',
#   'or',
#   'grieving',
#   'child'],
#  ['i',
#   'am',
#   'so',
#   'very',
#   'tired',
#   'and',
#   'feeling',
#   'overwhelmed',
#   'with',
#   'my',
#   'everyday',
#   'responsibilities',
#   'which',
#   'brings',
#   'me',
#   'to',
#   'the',
#   'point',
#   'of',
#   'this',
#   'post'],
#  ['i', 'can', 'feel', 'she', 'still', 'angry', 'with', 'me'],
#  ['i', 'feel', 'like', 'im', 'being', 'petty', 'about', 'this'],
#  ['im',
#   'tired',
#   'of',
#   'crying',
#   'then',
#   'feeling',
#   'content',
#   'and',
#   'loved',
#   'then',
#   'going',
#   'back',
#   'to',
#   'crying',
#   'again'],
#  ['i',
#   'repeat',
#   'over',
#   'and',
#   'over',
#   'in',
#   'my',
#   'life',
#   'in',
#   'which',
#   'i',
#   'try',
#   'to',
#   'take',
#   'control',
#   'in',
#   'my',
#   'life',
#   'but',
#   'it',
#   'when',
#   'it',
#   'doesn',
#   't',
#   'work',
#   'i',
#   'feel',
#   'afraid',
#   'that',
#   'i',
#   'have',
#   'no',
#   'control'],
#  ['ive',
#   'had',
#   'where',
#   'i',
#   'feel',
#   'good',
#   'enough',
#   'to',
#   'work',
#   'the',
#   'whole',
#   'shift',
#   'possibly',
#   'the',
#   'whole',
#   'day'],
#  ['im',
#   'not',
#   'completely',
#   'sure',
#   'my',
#   'topic',
#   'is',
#   'narrow',
#   'enough',
#   'and',
#   'im',
#   'feeling',
#   'apprehensive',
#   'about',
#   'being',
#   'able',
#   'to',
#   'find',
#   'half',
#   'of',
#   'my',
#   'sources',
#   'in',
#   'print'],
#  ['i',
#   'feel',
#   'so',
#   'virtuous',
#   'having',
#   'made',
#   'this',
#   'for',
#   'dinner',
#   'tonight'],
#  ['i',
#   'am',
#   'feeling',
#   'rather',
#   'artistic',
#   'and',
#   'felt',
#   'like',
#   'sharing',
#   'some',
#   'of',
#   'my',
#   'artwork'],
#  ['i',
#   'feel',
#   'fearless',
#   'janelle',
#   'mon',
#   'e',
#   'elle',
#   'canada',
#   'february',
#   'img',
#   'width',
#   'height',
#   'src',
#   'http',
#   'www'],
#  ['i',
#   'have',
#   'begun',
#   'to',
#   'feel',
#   'irrationally',
#   'resentful',
#   'and',
#   'angry',
#   'towards',
#   'people'],
#  ['i',
#   'asked',
#   'myself',
#   'why',
#   'do',
#   'you',
#   'feel',
#   'frightened',
#   'of',
#   'being'],
#  ['i',
#   'came',
#   'away',
#   'filled',
#   'with',
#   'admiration',
#   'inspired',
#   'by',
#   'amy',
#   's',
#   'friends',
#   'feeling',
#   'honoured',
#   'to',
#   'have',
#   'been',
#   'there',
#   'to',
#   'share',
#   'a',
#   'tiny',
#   'part',
#   'of',
#   'their',
#   'lives'],
#  ['i',
#   'feel',
#   'very',
#   'distressed',
#   'because',
#   'i',
#   'm',
#   'supportive',
#   'of',
#   'this',
#   'campaign',
#   'and',
#   'with',
#   'the',
#   'senator'],
#  ['im',
#   'a',
#   'marketer',
#   'and',
#   'i',
#   'couldnt',
#   'be',
#   'bothered',
#   'to',
#   'investigate',
#   'further',
#   'which',
#   'makes',
#   'me',
#   'feel',
#   'that',
#   'consumers',
#   'probably',
#   'cant',
#   'be',
#   'bothered',
#   'either'],
#  ['i',
#   'have',
#   'had',
#   'my',
#   'first',
#   'visitor',
#   'to',
#   'my',
#   'live',
#   'journal',
#   'and',
#   'that',
#   'makes',
#   'me',
#   'feel',
#   'very',
#   'pleasant'],
#  ['i',
#   'feel',
#   'pretty',
#   'weird',
#   'about',
#   'that',
#   'considering',
#   'what',
#   'my',
#   'friends',
#   'and',
#   'colleagues',
#   'in',
#   'nyc',
#   'and',
#   'new',
#   'jersey',
#   'are',
#   'going',
#   'through',
#   'but',
#   'it',
#   's',
#   'just',
#   'the',
#   'reality'],
#  ['i', 'am', 'feeling', 'very', 'unsure', 'of', 'my', 'future'],
#  ['i',
#   'remind',
#   'myself',
#   'or',
#   'am',
#   'reminded',
#   'of',
#   'my',
#   'passions',
#   'and',
#   'opinions',
#   'i',
#   'just',
#   'feel',
#   'incredibly',
#   'agitated',
#   'and',
#   'frustrated',
#   'there',
#   'is',
#   'this',
#   'ball',
#   'of',
#   'energy',
#   'with',
#   'no',
#   'channel',
#   'to',
#   'travel'],
#  ['i', 'stopped', 'feeling', 'cold', 'and', 'began', 'feeling', 'hot'],
#  ['i',
#   'used',
#   'to',
#   'always',
#   'feel',
#   'jealous',
#   'about',
#   'most',
#   'things',
#   'they',
#   'received',
#   'from',
#   'compliments',
#   'to',
#   'some',
#   'valuable',
#   'stuffs'],
#  ['i',
#   'feel',
#   'quite',
#   'scared',
#   'about',
#   'my',
#   'work',
#   'life',
#   'balance',
#   'if',
#   'i',
#   'start',
#   'to',
#   'work',
#   'for',
#   'ken',
#   'again'],
#  ['i',
#   'feel',
#   'when',
#   'they',
#   'are',
#   'distressed',
#   'in',
#   'the',
#   'night',
#   'is',
#   'perhaps',
#   'more',
#   'than',
#   'empathy'],
#  ['i',
#   'listen',
#   'to',
#   'dubstep',
#   'when',
#   'im',
#   'feeling',
#   'damn',
#   'irritated'],
#  ['i',
#   'am',
#   'feeling',
#   'very',
#   'fearful',
#   'that',
#   'things',
#   'arent',
#   'going',
#   'to',
#   'go',
#   'the',
#   'way',
#   'i',
#   'want',
#   'them',
#   'to',
#   'with',
#   'my',
#   'ex'],
#  ['ive', 'been', 'feeling', 'very', 'indecisive', 'lately'],
#  ['i',
#   'can',
#   't',
#   'show',
#   'my',
#   'feelings',
#   'well',
#   'to',
#   'my',
#   'family',
#   'and',
#   'to',
#   'the',
#   'fans',
#   'either'],
#  ['i',
#   'get',
#   'the',
#   'feeling',
#   'people',
#   'think',
#   'im',
#   'indecisive',
#   'and',
#   'childish',
#   'which',
#   'isnt',
#   'entirely',
#   'true',
#   'not',
#   'to',
#   'the',
#   'degree',
#   'that',
#   'i',
#   'show',
#   'it',
#   'anyway'],
#  ['im',
#   'listening',
#   'to',
#   'right',
#   'now',
#   'because',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'need',
#   'it',
#   'and',
#   'i',
#   'want',
#   'to',
#   'share',
#   'it',
#   'with',
#   'you',
#   'little',
#   'ones',
#   'despite',
#   'my',
#   'convinced',
#   'atheism',
#   'somehow',
#   'it',
#   'never',
#   'fails',
#   'to',
#   'make',
#   'me',
#   'feel',
#   'better'],
#  ['i',
#   'did',
#   'feel',
#   'a',
#   'bit',
#   'like',
#   'i',
#   'was',
#   'being',
#   'mircowaved',
#   'which',
#   'wasnt',
#   'an',
#   'entirely',
#   'pleasant',
#   'feeling'],
#  ['i',
#   'wonder',
#   'does',
#   'anyone',
#   'ever',
#   'feel',
#   'particularly',
#   'inspired',
#   'or',
#   'moved',
#   'watching',
#   'question',
#   'time',
#   'these',
#   'days'],
#  ['i', 'write', 'when', 'i', 'am', 'feeling', 'happy', 'and', 'childish'],
#  ['i',
#   'forgive',
#   'myself',
#   'that',
#   'i',
#   'have',
#   'accepted',
#   'adn',
#   'allowed',
#   'myself',
#   'to',
#   'feel',
#   'uncertain',
#   'and',
#   'inferior',
#   'the',
#   'moment',
#   'someobdy',
#   'is',
#   'looking',
#   'at',
#   'me',
#   'as',
#   'i',
#   'do',
#   'physical',
#   'labour'],
#  ['i',
#   'alight',
#   'in',
#   'front',
#   'of',
#   'the',
#   'hotel',
#   'i',
#   'can',
#   'feel',
#   'the',
#   'bellmen',
#   's',
#   'appreciative',
#   'glances'],
#  ['i',
#   'p',
#   'i',
#   'could',
#   'sit',
#   'here',
#   'and',
#   'beat',
#   'myself',
#   'up',
#   'over',
#   'it',
#   'all',
#   'but',
#   'im',
#   'feeling',
#   'far',
#   'to',
#   'rebellious',
#   'for',
#   'that',
#   'today',
#   'basically',
#   'im',
#   'feeling',
#   'angry',
#   'at',
#   'the',
#   'world',
#   'and',
#   'at',
#   'myself',
#   'all',
#   'at',
#   'the',
#   'same',
#   'time'],
#  ['ive',
#   'been',
#   'feelin',
#   'cranky',
#   'about',
#   'my',
#   'blog',
#   'im',
#   'feeling',
#   'its',
#   'still',
#   'a',
#   'bit',
#   'childish',
#   'for',
#   'me',
#   'already',
#   'i',
#   'dont',
#   'know',
#   'if',
#   'its',
#   'the',
#   'blog',
#   'itself',
#   'the',
#   'address',
#   'or',
#   'something',
#   'else'],
#  ['im',
#   'feeling',
#   'a',
#   'little',
#   'more',
#   'hopeful',
#   'about',
#   'my',
#   'future',
#   'and',
#   'like',
#   'matty',
#   'always',
#   'says',
#   'i',
#   'want',
#   'my',
#   'world',
#   'to',
#   'get',
#   'bigger'],
#  ['i',
#   'viewed',
#   'all',
#   'that',
#   'stuff',
#   'at',
#   'the',
#   'bottom',
#   'and',
#   'deciding',
#   'i',
#   'was',
#   'going',
#   'to',
#   'come',
#   'back',
#   'when',
#   'i',
#   'am',
#   'feeling',
#   'bitchy',
#   'just',
#   'so',
#   'i',
#   'could',
#   'list',
#   'that',
#   'as',
#   'my',
#   'mood',
#   'i',
#   'felt',
#   'like',
#   'an',
#   'ice',
#   'cream',
#   'sandwich'],
#  ['i',
#   'know',
#   'both',
#   'of',
#   'them',
#   'feel',
#   'threatened',
#   'by',
#   'the',
#   'job',
#   'i',
#   'do',
#   'even',
#   'after',
#   'long',
#   'years',
#   'but',
#   'i',
#   'get',
#   'really',
#   'tired',
#   'of',
#   'the',
#   'ganging',
#   'up',
#   'i',
#   'get',
#   'from',
#   'them'],
#  ['i',
#   'truly',
#   'feel',
#   'that',
#   'they',
#   'do',
#   'a',
#   'lot',
#   'of',
#   'positive',
#   'things',
#   'to',
#   'help',
#   'the',
#   'conditions',
#   'for',
#   'the',
#   'workers',
#   'and',
#   'their',
#   'families',
#   'kids'],
#  ['i',
#   'love',
#   'the',
#   'most',
#   'about',
#   'them',
#   'is',
#   'the',
#   'slight',
#   'cat',
#   'eye',
#   'shape',
#   'of',
#   'the',
#   'lenses',
#   'they',
#   'instantly',
#   'make',
#   'me',
#   'feel',
#   'likeaudrey',
#   'hepburn',
#   'in',
#   'breakfast',
#   'at',
#   'tiffanys',
#   'so',
#   'glamorous',
#   'and',
#   'of',
#   'course',
#   'that',
#   'gorgeous',
#   'case',
#   'doesnt',
#   'hurt',
#   'either'],
#  ['i', 'feel', 'have', 'wronged', 'me'],
#  ['i',
#   'don',
#   't',
#   'know',
#   'how',
#   'it',
#   'works',
#   'but',
#   'asking',
#   'for',
#   'divine',
#   'assistance',
#   'certainly',
#   'makes',
#   'us',
#   'feel',
#   'more',
#   'graceful',
#   'even',
#   'when',
#   'our',
#   'situation',
#   'remains',
#   'the',
#   'same'],
#  ['i',
#   'must',
#   'find',
#   'a',
#   'way',
#   'to',
#   'accept',
#   'these',
#   'limitations',
#   'until',
#   'they',
#   'are',
#   'older',
#   'without',
#   'feeling',
#   'held',
#   'back',
#   'or',
#   'resentful'],
#  ['i',
#   'feel',
#   'i',
#   'hate',
#   'him',
#   'like',
#   'i',
#   'have',
#   'never',
#   'ever',
#   'hated',
#   'anyone',
#   'like',
#   'that',
#   'but',
#   'i',
#   'cant',
#   'stop',
#   'looking',
#   'at',
#   'his',
#   'existing',
#   'symbol'],
#  ['i',
#   'want',
#   'him',
#   'to',
#   'feel',
#   'uncertain',
#   'and',
#   'unsettled',
#   'because',
#   'he',
#   'deserves',
#   'it',
#   'and',
#   'maybe',
#   'itll',
#   'teach',
#   'him',
#   'a',
#   'lesson'],
#  ['im',
#   'feeling',
#   'every',
#   'bit',
#   'the',
#   'spiteful',
#   'vindictive',
#   'bitch',
#   'i',
#   'can',
#   'be',
#   'at',
#   'times'],
#  ['i', 'feel', 'is', 'glamorous', 'will', 'be', 'shared', 'there'],
#  ['i',
#   'read',
#   'which',
#   'i',
#   'feel',
#   'i',
#   'didn',
#   't',
#   'need',
#   'to',
#   'read',
#   'makes',
#   'me',
#   'a',
#   'little',
#   'grumpy'],
#  ['i',
#   'slough',
#   'off',
#   'the',
#   'carapace',
#   'of',
#   'crud',
#   'that',
#   'has',
#   'enveloped',
#   'me',
#   'for',
#   'the',
#   'past',
#   'thirty',
#   'odd',
#   'hours',
#   'i',
#   'feel',
#   'invigorated',
#   'and',
#   'finally',
#   'ready',
#   'to',
#   'face',
#   'the',
#   'day'],
#  ['i',
#   'started',
#   'the',
#   'dew',
#   'beyond',
#   'having',
#   'a',
#   'positive',
#   'showing',
#   'of',
#   'the',
#   'south',
#   'to',
#   'encourage',
#   'writers',
#   'from',
#   'all',
#   'experiences',
#   'and',
#   'levels',
#   'of',
#   'advancement',
#   'to',
#   'feel',
#   'comfortable',
#   'sharing',
#   'their',
#   'work'],
#  ['i',
#   'secretly',
#   'well',
#   'i',
#   'guess',
#   'not',
#   'secretly',
#   'anymore',
#   'feel',
#   'insecure',
#   'about',
#   'this',
#   'but',
#   'at',
#   'the',
#   'same',
#   'time',
#   'want',
#   'them',
#   'to',
#   'learn',
#   'how',
#   'to',
#   'come',
#   'up',
#   'with',
#   'common',
#   'ground',
#   'by',
#   'themselves'],
#  ['i',
#   'began',
#   'to',
#   'feel',
#   'distressed',
#   'and',
#   'a',
#   'feeling',
#   'of',
#   'sadness',
#   'and',
#   'a',
#   'desire',
#   'to',
#   'kill',
#   'myself'],
#  ['im',
#   'feeling',
#   'the',
#   'need',
#   'to',
#   'mellow',
#   'out',
#   'i',
#   'find',
#   'something',
#   'on',
#   'the',
#   'ipod',
#   'that',
#   'suits',
#   'me',
#   'or',
#   'when',
#   'im',
#   'ready',
#   'to',
#   'pump',
#   'it',
#   'up',
#   'ive',
#   'always',
#   'got',
#   'a',
#   'go',
#   'to',
#   'tune',
#   'or',
#   'two',
#   'to',
#   'get',
#   'me',
#   'reved',
#   'up'],
#  ['i',
#   'also',
#   'love',
#   'seeing',
#   'a',
#   'star',
#   'emerge',
#   'and',
#   'i',
#   'feel',
#   'like',
#   'in',
#   'a',
#   'few',
#   'years',
#   'everyone',
#   'is',
#   'gon',
#   'na',
#   'know',
#   'and',
#   'i',
#   'can',
#   'be',
#   'one',
#   'of',
#   'those',
#   'people',
#   'who',
#   'says',
#   'obnoxious',
#   'things',
#   'like',
#   'bah'],
#  ['i', 'dont', 'like', 'the', 'way', 'i', 'feel', 'when', 'i', 'am', 'angry'],
#  ['im', 'feeling', 'a', 'combination', 'of', 'terrified', 'and', 'relieved'],
#  ['i',
#   'came',
#   'home',
#   'one',
#   'day',
#   'and',
#   'discovered',
#   'that',
#   'my',
#   'sister',
#   'had',
#   'borrowed',
#   'my',
#   'car',
#   'and',
#   'had',
#   'gotten',
#   'into',
#   'an',
#   'accident',
#   'with',
#   'it',
#   'my',
#   'entire',
#   'front',
#   'bumper',
#   'was',
#   'destroyed'],
#  ['i',
#   'don',
#   't',
#   'feel',
#   'greedy',
#   'of',
#   'worldly',
#   'things',
#   'so',
#   'it',
#   's',
#   'not',
#   'a',
#   'big',
#   'deal'],
#  ['i',
#   'feel',
#   'like',
#   'im',
#   'the',
#   'only',
#   'one',
#   'there',
#   'with',
#   'a',
#   'brain',
#   'not',
#   'to',
#   'be',
#   'rude',
#   'but',
#   'i',
#   'refuse',
#   'to',
#   'sit',
#   'with',
#   'loud',
#   'and',
#   'rude',
#   'people',
#   'so',
#   'i',
#   'sit',
#   'alone',
#   'with',
#   'just',
#   'myself',
#   'and',
#   'a',
#   'good',
#   'book'],
#  ['i',
#   'become',
#   'more',
#   'comfortable',
#   'in',
#   'this',
#   'remodeled',
#   'office',
#   'i',
#   'am',
#   'feeling',
#   'much',
#   'gratitude',
#   'for',
#   'its',
#   'wonderful',
#   'amenities'],
#  ['im',
#   'feeling',
#   'very',
#   'bitter',
#   'against',
#   'knight',
#   'in',
#   'shining',
#   'denim',
#   'because',
#   'i',
#   'asked',
#   'him',
#   'a',
#   'year',
#   'ago',
#   'to',
#   'go',
#   'to',
#   'the',
#   'gym',
#   'with',
#   'me',
#   'and',
#   'he',
#   'wouldnt',
#   'spend',
#   'the',
#   'money'],
#  ['i', 'feel', 'just', 'insulted'],
#  ['i',
#   'did',
#   'the',
#   'yelling',
#   'the',
#   'feeling',
#   'of',
#   'being',
#   'extremely',
#   'mad'],
#  ['i',
#   'could',
#   'feel',
#   'my',
#   'body',
#   'start',
#   'to',
#   'shake',
#   'with',
#   'nervous',
#   'anticipation'],
#  ['i',
#   'find',
#   'every',
#   'body',
#   'beautiful',
#   'and',
#   'only',
#   'want',
#   'people',
#   'to',
#   'feel',
#   'vital',
#   'in',
#   'their',
#   'bodies'],
#  ['i',
#   'feel',
#   'like',
#   'im',
#   'a',
#   'shy',
#   'enormous',
#   'pink',
#   'flamingo',
#   'man'],
#  ['i',
#   'guess',
#   'these',
#   'expectations',
#   'of',
#   'me',
#   'being',
#   'so',
#   'goddamn',
#   'perfect',
#   'have',
#   'made',
#   'me',
#   'feel',
#   'afraid',
#   'to',
#   'change'],
#  ['i', 'feel', 'confused', 'too'],
#  ['i',
#   'feel',
#   'very',
#   'confused',
#   'and',
#   'cant',
#   'stop',
#   'myself',
#   'from',
#   'digging',
#   'in',
#   'a',
#   'bit',
#   'more'],
#  ['i',
#   'put',
#   'forward',
#   'to',
#   'all',
#   'their',
#   'social',
#   'diktats',
#   'make',
#   'them',
#   'feel',
#   'i',
#   'am',
#   'rebellious',
#   'towards',
#   'their',
#   'authority'],
#  ['im', 'feeling', 'a', 'little', 'uptight', 'and', 'pinched', 'today'],
#  ['i',
#   'like',
#   'that',
#   'i',
#   'don',
#   't',
#   'feel',
#   'pressured',
#   'yet',
#   'i',
#   'like',
#   'spending',
#   'time',
#   'with',
#   'him'],
#  ['i', 'feel', 'reluctant', 'to', 'sell', 'but', 'hey'],
#  ['im',
#   'feeling',
#   'pressured',
#   'because',
#   'it',
#   'is',
#   'crunch',
#   'time',
#   'with',
#   'looming',
#   'deadlines',
#   'once',
#   'i',
#   'hit',
#   'the',
#   'airport',
#   'thursday',
#   'i',
#   'know',
#   'ill',
#   'be',
#   'too',
#   'busy',
#   'to',
#   'worry',
#   'with',
#   'the',
#   'other',
#   'items',
#   'for',
#   'a',
#   'few',
#   'days'],
#  ['i',
#   'plan',
#   'to',
#   'share',
#   'my',
#   'everyday',
#   'life',
#   'stories',
#   'traveling',
#   'adventures',
#   'inspirations',
#   'and',
#   'handmade',
#   'creations',
#   'with',
#   'you',
#   'and',
#   'hope',
#   'you',
#   'will',
#   'also',
#   'feel',
#   'inspired'],
#  ['i',
#   'hadnt',
#   'been',
#   'feeling',
#   'well',
#   'all',
#   'week',
#   'in',
#   'calgary',
#   'so',
#   'with',
#   'this',
#   'added',
#   'relaxation',
#   'in',
#   'the',
#   'first',
#   'run',
#   'of',
#   'the',
#   'second',
#   'race',
#   'i',
#   'set',
#   'another',
#   'pb',
#   'time',
#   'by',
#   'almost'],
#  ['i',
#   'tend',
#   'to',
#   'think',
#   'that',
#   'it',
#   'kinda',
#   'contributed',
#   'to',
#   'my',
#   'medium',
#   'intelligence',
#   'and',
#   'made',
#   'me',
#   'understand',
#   'and',
#   'feel',
#   'things',
#   'in',
#   'a',
#   'clever',
#   'and',
#   'sensible',
#   'way',
#   'in',
#   'the',
#   'visual',
#   'arts',
#   'field',
#   'especially',
#   'but',
#   'i',
#   'm',
#   'always',
#   'feeling',
#   'that',
#   'i',
#   'm',
#   'losing',
#   'that',
#   'more',
#   'and',
#   'more'],
#  ['im',
#   'feeling',
#   'generous',
#   'again',
#   'here',
#   'it',
#   'is',
#   'in',
#   'its',
#   'entirety',
#   'for',
#   'free',
#   'consumption'],
#  ['i',
#   'happened',
#   'to',
#   'see',
#   'the',
#   'videotape',
#   'movie',
#   'this',
#   'is',
#   'america',
#   'part',
#   'one',
#   'at',
#   'my',
#   'friends',
#   'place'],
#  ['i',
#   'think',
#   'most',
#   'people',
#   'have',
#   'little',
#   'problem',
#   'expressing',
#   'but',
#   'once',
#   'in',
#   'a',
#   'while',
#   'i',
#   'can',
#   't',
#   'help',
#   'but',
#   'feel',
#   'that',
#   'we',
#   'shouldn',
#   't',
#   'be',
#   'afraid',
#   'to',
#   'let',
#   'it',
#   'all',
#   'hang',
#   'out',
#   'there',
#   'and',
#   'express',
#   'the',
#   'other',
#   'emotions',
#   'that',
#   'don',
#   't',
#   'get',
#   'nearly',
#   'as',
#   'much',
#   'airtime'],
#  ['i', 'picked', 'up', 'feeling', 'a', 'little', 'apprehensive'],
#  ['im', 'feeling', 'particularly', 'generous'],
#  ['im', 'feeling', 'so', 'pissed', 'off', 'now'],
#  ['i',
#   'might',
#   'also',
#   'write',
#   'a',
#   'bit',
#   'about',
#   'science',
#   'if',
#   'im',
#   'feeling',
#   'particularly',
#   'energetic'],
#  ['i',
#   'remember',
#   'feeling',
#   'more',
#   'amused',
#   'than',
#   'sensing',
#   'that',
#   'i',
#   'was',
#   'in',
#   'any',
#   'real',
#   'danger',
#   'however',
#   'i',
#   'must',
#   'have',
#   'been',
#   'experiencing',
#   'a',
#   'little',
#   'bit',
#   'of',
#   'shock'],
#  ['i',
#   'feel',
#   'there',
#   'are',
#   'other',
#   'options',
#   'that',
#   'not',
#   'as',
#   'violent',
#   'probably',
#   'more',
#   'costly',
#   'yet',
#   'equally',
#   'futile',
#   'so',
#   'whats',
#   'the',
#   'problem',
#   'with',
#   'keeping',
#   'our',
#   'men',
#   'and',
#   'women',
#   'out',
#   'of',
#   'harms',
#   'way'],
#  ['i',
#   'always',
#   'get',
#   'questions',
#   'about',
#   'blocking',
#   'in',
#   'my',
#   'classes',
#   'and',
#   'its',
#   'a',
#   'topic',
#   'i',
#   'feel',
#   'pretty',
#   'passionately',
#   'about',
#   'as',
#   'a',
#   'knitter',
#   'and',
#   'as',
#   'a',
#   'teacher'],
#  ['i',
#   'start',
#   'to',
#   'feel',
#   'frantic',
#   'where',
#   'are',
#   'the',
#   'candles',
#   'the',
#   'matches',
#   'the',
#   'one',
#   'flashlight',
#   'thats',
#   'actually',
#   'ashers',
#   'bug',
#   'light',
#   'no',
#   'fans',
#   'in',
#   'the',
#   'house',
#   'move',
#   'beds',
#   'outside',
#   'boys',
#   'in',
#   'the',
#   'bath',
#   'dont',
#   'touch',
#   'the',
#   'candles',
#   'goodbye',
#   'meat',
#   'in',
#   'the',
#   'fridge'],
#  ['i',
#   'feel',
#   'terrific',
#   'and',
#   'i',
#   'm',
#   'starting',
#   'to',
#   'put',
#   'weight',
#   'on'],
#  ['i', 'feel', 'so', 'welcomed'],
#  ['i',
#   'feel',
#   'i',
#   'cant',
#   'talk',
#   'move',
#   'sometimes',
#   'even',
#   'breath',
#   'with',
#   'the',
#   'fear',
#   'of',
#   'some',
#   'kind',
#   'of',
#   'rude',
#   'hateful',
#   'comment'],
#  ['i',
#   'was',
#   'feeling',
#   'pretty',
#   'cranky',
#   'this',
#   'morning',
#   'and',
#   'stopping',
#   'in',
#   'here',
#   'really',
#   'made',
#   'me',
#   'feel',
#   'a',
#   'lot',
#   'better'],
#  ['i',
#   'feel',
#   'a',
#   'strong',
#   'connection',
#   'with',
#   'another',
#   'human',
#   'being',
#   'and',
#   'i',
#   'want',
#   'to',
#   'spend',
#   'more',
#   'time',
#   'with',
#   'her'],
#  ['i',
#   'think',
#   'you',
#   'said',
#   'beautiful',
#   'things',
#   'to',
#   'them',
#   'and',
#   'i',
#   'think',
#   'you',
#   'meant',
#   'them',
#   'you',
#   'loved',
#   'being',
#   'with',
#   'them',
#   'i',
#   'think',
#   'you',
#   'made',
#   'them',
#   'feel',
#   'terrific'],
#  ['i',
#   'guess',
#   'i',
#   'just',
#   'need',
#   'to',
#   'see',
#   'how',
#   'it',
#   'goes',
#   'so',
#   'while',
#   'im',
#   'feeling',
#   'very',
#   'nervous',
#   'im',
#   'also',
#   'very',
#   'excited'],
#  ['i',
#   'just',
#   'got',
#   'really',
#   'crunk',
#   'about',
#   'a',
#   'situation',
#   'and',
#   'now',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'have',
#   'to',
#   'write',
#   'to',
#   'calm',
#   'down',
#   'lol'],
#  ['i',
#   'am',
#   'grateful',
#   'to',
#   'have',
#   'a',
#   'strong',
#   'support',
#   'system',
#   'both',
#   'internally',
#   'and',
#   'externally',
#   'that',
#   'i',
#   'can',
#   'rely',
#   'on',
#   'when',
#   'i',
#   'am',
#   'feeling',
#   'uncertain',
#   'and',
#   'weak'],
#  ['when',
#   'they',
#   'changed',
#   'my',
#   'office',
#   'to',
#   'another',
#   'room',
#   'without',
#   'my',
#   'agreement'],
#  ['i',
#   'started',
#   'to',
#   'feel',
#   'uncomfortable',
#   'buzzy',
#   'short',
#   'of',
#   'breath',
#   'and',
#   'very',
#   'mildly',
#   'panicky'],
#  ['im',
#   'feeling',
#   'jealous',
#   'just',
#   'thinking',
#   'of',
#   'you',
#   'all',
# ...
#   'just',
#   'leave',
#   'her',
#   'alone',
#   'like',
#   'that',
#   'without',
#   'helping',
#   'her',
#   'enough',
#   'to',
#   'repay',
#   'her',
#   'goodness',
#   'to',
#   'me'],
#  ['i',
#   'feel',
#   'combination',
#   'slightly',
#   'superior',
#   'sitting',
#   'in',
#   'on',
#   'virtual',
#   'event',
#   'you',
#   'll',
#   'feel',
#   'as',
#   'if',
#   'it',
#   's',
#   'another',
#   'day',
#   'office'],
#  ['i',
#   'feel',
#   'reluctant',
#   'to',
#   'share',
#   'because',
#   'my',
#   'experiences',
#   'feel',
#   'incomplete',
#   'especially',
#   'now',
#   'that',
#   'my',
#   'ideas',
#   'are',
#   'making',
#   'a',
#   'shift'],
#  ['i',
#   'feel',
#   'so',
#   'resentful',
#   'about',
#   'having',
#   'to',
#   'take',
#   'care',
#   'of',
#   'us',
#   'and',
#   'not',
#   'getting',
#   'to',
#   'do',
#   'what',
#   'i',
#   'want',
#   'to',
#   'do'],
#  ['im',
#   'feeling',
#   'a',
#   'little',
#   'bit',
#   'apprehensive',
#   'about',
#   'entering',
#   'a',
#   'new',
#   'chapter',
#   'again',
#   'and',
#   'having',
#   'to',
#   'prove',
#   'myself',
#   'all',
#   'over',
#   'again'],
#  ['i',
#   'wanted',
#   'everyone',
#   'no',
#   'matter',
#   'what',
#   'their',
#   'lifestyle',
#   'to',
#   'feel',
#   'a',
#   'little',
#   'bit',
#   'glamorous'],
#  ['i',
#   'cant',
#   'help',
#   'but',
#   'feel',
#   'someones',
#   'going',
#   'to',
#   'end',
#   'up',
#   'pissed',
#   'at',
#   'me'],
#  ['i',
#   'did',
#   'see',
#   'some',
#   'things',
#   'that',
#   'i',
#   'would',
#   'never',
#   'have',
#   'done',
#   'myself',
#   'for',
#   'the',
#   'movie',
#   'adaption',
#   'but',
#   'feel',
#   'that',
#   'if',
#   'i',
#   'did',
#   'not',
#   'read',
#   'the',
#   'book',
#   'it',
#   'would',
#   'not',
#   'have',
#   'bothered',
#   'me'],
#  ['i',
#   'understand',
#   'that',
#   'chronically',
#   'living',
#   'makes',
#   'some',
#   'healthy',
#   'people',
#   'feel',
#   'threatened',
#   'or',
#   'afraid'],
#  ['i',
#   'simply',
#   'can',
#   't',
#   'help',
#   'but',
#   'feel',
#   'dissatisfied',
#   'after',
#   'reading',
#   'glancing',
#   'through',
#   'each'],
#  ['i',
#   'should',
#   'give',
#   'as',
#   'charity',
#   'only',
#   'what',
#   'i',
#   'feel',
#   'is',
#   'valuable',
#   'to',
#   'the',
#   'person',
#   'receiving',
#   'it'],
#  ['im',
#   'feeling',
#   'rather',
#   'impatient',
#   'with',
#   'these',
#   'rainbows',
#   'bursting',
#   'in',
#   'my',
#   'veins'],
#  ['i',
#   'could',
#   'even',
#   'feel',
#   'his',
#   'cold',
#   'breath',
#   'on',
#   'my',
#   'neck',
#   'whispered',
#   'hertha',
#   'as',
#   'she',
#   'ran',
#   'her',
#   'fingers',
#   'across',
#   'the',
#   'side',
#   'of',
#   'neck'],
#  ['i',
#   'really',
#   'want',
#   'to',
#   'write',
#   'and',
#   'still',
#   'feel',
#   'like',
#   'ive',
#   'not',
#   'been',
#   'useful',
#   'that',
#   'day'],
#  ['i', 'feel', 'and', 'look', 'gorgeous', 'beautiful', 'and', 'sexy'],
#  ['i',
#   'feel',
#   'sure',
#   'a',
#   'new',
#   'necklace',
#   'will',
#   'come',
#   'from',
#   'this',
#   'afternoon',
#   'of',
#   'beach',
#   'combing'],
#  ['im', 'feeling', 'abit', 'uncertain', 'now'],
#  ['i',
#   'dont',
#   'really',
#   'connect',
#   'with',
#   'the',
#   'main',
#   'character',
#   'or',
#   'anything',
#   'in',
#   'fact',
#   'i',
#   'feel',
#   'like',
#   'he',
#   'is',
#   'almost',
#   'too',
#   'innocent',
#   'to',
#   'be',
#   'me'],
#  ['i',
#   'feel',
#   'like',
#   'being',
#   'selfish',
#   'and',
#   'keeping',
#   'this',
#   'foodie',
#   'secret',
#   'myself',
#   'but',
#   'why',
#   'would',
#   'i',
#   'deny',
#   'everyone',
#   'else'],
#  ['i',
#   'hate',
#   'asking',
#   'myself',
#   'why',
#   'i',
#   'feel',
#   'so',
#   'reluctant',
#   'when',
#   'he',
#   'tries',
#   'to',
#   'kiss',
#   'me'],
#  ['i',
#   'am',
#   'feeling',
#   'optimistic',
#   'about',
#   'doing',
#   'as',
#   'much',
#   'as',
#   'possible',
#   'in',
#   'the',
#   'next',
#   'to',
#   'hours',
#   'before',
#   'the',
#   'kids',
#   'come',
#   'home'],
#  ['i',
#   'feel',
#   'like',
#   'you',
#   'will',
#   'be',
#   'completely',
#   'satisfied',
#   'with',
#   'the',
#   'results'],
#  ['i',
#   'want',
#   'to',
#   'give',
#   'up',
#   'feel',
#   'distracted',
#   'or',
#   'just',
#   'need',
#   'to',
#   'remind',
#   'myself',
#   'of',
#   'what',
#   'i',
#   'am',
#   'working',
#   'towards'],
#  ['i',
#   'know',
#   'i',
#   'said',
#   'that',
#   'i',
#   'would',
#   'get',
#   'this',
#   'to',
#   'you',
#   'guys',
#   'next',
#   'week',
#   'however',
#   'i',
#   'am',
#   'feeling',
#   'pretty',
#   'generous',
#   'so',
#   'ill',
#   'give',
#   'you',
#   'guys',
#   'the',
#   'scoop',
#   'right',
#   'now'],
#  ['i', 'mention', 'that', 'im', 'feeling', 'cranky'],
#  ['im',
#   'feeling',
#   'agitated',
#   'again',
#   'the',
#   'usual',
#   'evening',
#   'mood',
#   'that',
#   'is',
#   'becoming',
#   'the',
#   'norm'],
#  ['i',
#   'recall',
#   'seeing',
#   'leaves',
#   'falling',
#   'off',
#   'a',
#   'tree',
#   'set',
#   'against',
#   'a',
#   'grey',
#   'sky',
#   'and',
#   'feeling',
#   'absolutely',
#   'terrified'],
#  ['im',
#   'feeling',
#   'agitated',
#   'and',
#   'pour',
#   'more',
#   'brandy',
#   'on',
#   'my',
#   'coffee'],
#  ['i',
#   'feel',
#   'that',
#   'people',
#   'can',
#   'not',
#   'possibly',
#   'appreciate',
#   'me',
#   'that',
#   'any',
#   'compliments',
#   'toward',
#   'me',
#   'can',
#   'not',
#   'possibly',
#   'be',
#   'sincere',
#   'or',
#   'that',
#   'i',
#   'dont',
#   'deserve',
#   'compliments',
#   'in',
#   'the',
#   'first',
#   'place'],
#  ['i',
#   'feel',
#   'rather',
#   'stressed',
#   'for',
#   'the',
#   'preparations',
#   'for',
#   'prom',
#   'night'],
#  ['i', 'feel', 'so', 'because', 'i', 'feel', 'reluctant'],
#  ['i',
#   'feel',
#   'like',
#   'the',
#   'earthquake',
#   'has',
#   'also',
#   'shaken',
#   'the',
#   'foundations',
#   'of',
#   'my',
#   'life',
#   'and',
#   'work'],
#  ['i',
#   'will',
#   'adress',
#   'those',
#   'issues',
#   'and',
#   'attempt',
#   'to',
#   'reason',
#   'with',
#   'them',
#   'so',
#   'they',
#   'may',
#   'feel',
#   'less',
#   'threatened',
#   'and',
#   'more',
#   'supported',
#   'and',
#   'loved'],
#  ['i',
#   'didnt',
#   'feel',
#   'much',
#   'maybe',
#   'just',
#   'a',
#   'sting',
#   'but',
#   'i',
#   'was',
#   'terrified',
#   'because',
#   'i',
#   'didnt',
#   'know',
#   'if',
#   'it',
#   'was',
#   'going',
#   'to',
#   'hurt',
#   'or',
#   'not',
#   'if',
#   'there',
#   'would',
#   'be',
#   'a',
#   'problem',
#   'and',
#   'if',
#   'he',
#   'knew',
#   'what',
#   'he',
#   'was',
#   'doing',
#   'really',
#   'who',
#   'does',
#   'in',
#   'this',
#   'situation'],
#  ['i',
#   'feel',
#   'kind',
#   'of',
#   'uncomfortable',
#   'as',
#   'i',
#   'm',
#   'about',
#   'to',
#   'write',
#   'a',
#   'not',
#   'so',
#   'favorable',
#   'review',
#   'about',
#   'starters'],
#  ['i',
#   'feel',
#   'petty',
#   'moaning',
#   'about',
#   'it',
#   'but',
#   'its',
#   'annoying',
#   'me',
#   'so',
#   'from',
#   'now',
#   'on',
#   'im',
#   'keeping',
#   'my',
#   'stuff',
#   'in',
#   'a',
#   'bag',
#   'in',
#   'my',
#   'room',
#   'if',
#   'they',
#   'ask',
#   'i',
#   'can',
#   'always',
#   'say',
#   'im',
#   'keeping',
#   'it',
#   'there',
#   'to',
#   'stop',
#   'the',
#   'bathroom',
#   'getting',
#   'cluttered'],
#  ['finding',
#   'out',
#   'that',
#   'i',
#   'am',
#   'not',
#   'an',
#   'as',
#   'able',
#   'student',
#   'as',
#   'i',
#   'thought'],
#  ['i',
#   'feel',
#   'nervous',
#   'about',
#   'going',
#   'back',
#   'to',
#   'america',
#   'not',
#   'knowing',
#   'what',
#   'to',
#   'expect',
#   'the',
#   'transition',
#   'to',
#   'be',
#   'like'],
#  ['i',
#   'know',
#   'ive',
#   'talked',
#   'about',
#   'this',
#   'before',
#   'and',
#   'i',
#   'know',
#   'that',
#   'eric',
#   'has',
#   'talked',
#   'about',
#   'how',
#   'the',
#   'same',
#   'thing',
#   'happened',
#   'on',
#   'his',
#   'mission',
#   'just',
#   'how',
#   'like',
#   'sometimes',
#   'you',
#   'feel',
#   'like',
#   'you',
#   'get',
#   'super',
#   'overwhelmed',
#   'by',
#   'all',
#   'the',
#   'stuff',
#   'you',
#   'have',
#   'to',
#   'do',
#   'and',
#   'its',
#   'just',
#   'so',
#   'easy',
#   'to',
#   'be',
#   'really',
#   'hard',
#   'on',
#   'yourself',
#   'the',
#   'mental',
#   'game',
#   'if',
#   'you',
#   'will'],
#  ['i',
#   'know',
#   'it',
#   's',
#   'gross',
#   'to',
#   'think',
#   'that',
#   'you',
#   'are',
#   'putting',
#   'snail',
#   'mucus',
#   'on',
#   'your',
#   'face',
#   'but',
#   'it',
#   's',
#   'a',
#   'small',
#   'price',
#   'for',
#   'beauty',
#   'plus',
#   'the',
#   'texture',
#   'of',
#   'the',
#   'product',
#   'is',
#   'just',
#   'like',
#   'any',
#   'other',
#   'face',
#   'cream',
#   'so',
#   'it',
#   'won',
#   't',
#   'feel',
#   'weird'],
#  ['i', 'feel', 'so', 'weird', 'about', 'it'],
#  ['i',
#   'feel',
#   'ive',
#   'been',
#   'physically',
#   'uncomfortable',
#   'for',
#   'the',
#   'last',
#   'months',
#   'of',
#   'my',
#   'life',
#   'so',
#   'nothing',
#   'new',
#   'there'],
#  ['i',
#   'just',
#   'want',
#   'them',
#   'to',
#   'hug',
#   'and',
#   'drink',
#   'beer',
#   'together',
#   'and',
#   'for',
#   'neither',
#   'of',
#   'them',
#   'to',
#   'feel',
#   'tortured',
#   'at',
#   'the',
#   'same',
#   'time'],
#  ['i',
#   'remember',
#   'feeling',
#   'a',
#   'bit',
#   'confused',
#   'and',
#   'really',
#   'questioned',
#   'her',
#   'saying',
#   'that',
#   'to',
#   'me'],
#  ['i', 'feel', 'a', 'lot', 'of', 'positive', 'intention', 'behind', 'it'],
#  ['i',
#   'feel',
#   'more',
#   'vulnerable',
#   'and',
#   'more',
#   'in',
#   'touch',
#   'with',
#   'my',
#   'heart',
#   'with',
#   'making',
#   'choices',
#   'that',
#   'are',
#   'better',
#   'for',
#   'myself',
#   'and',
#   'my',
#   'family',
#   'and',
#   'less',
#   'worried',
#   'about',
#   'pleasing',
#   'everyone',
#   'else'],
#  ['i',
#   'feel',
#   'like',
#   'a',
#   'paranoid',
#   'annoyance',
#   'when',
#   'in',
#   'reality',
#   'she',
#   'wouldve',
#   'talked',
#   'to',
#   'anyone',
#   'that',
#   'way'],
#  ['i',
#   'feel',
#   'i',
#   'have',
#   'to',
#   'write',
#   'about',
#   'it',
#   'it',
#   'was',
#   'truly',
#   'innocent',
#   'even',
#   'though',
#   'there',
#   'was',
#   'quite',
#   'a',
#   'bit',
#   'of',
#   'feeling',
#   'involved'],
#  ['i',
#   'feel',
#   'so',
#   'invigorated',
#   'so',
#   'focused',
#   'about',
#   'what',
#   'im',
#   'being',
#   'led',
#   'to',
#   'pursue',
#   'right',
#   'now',
#   'and',
#   'in',
#   'the',
#   'future'],
#  ['i',
#   'feel',
#   'like',
#   'i',
#   'm',
#   'on',
#   'a',
#   'roller',
#   'coaster',
#   'of',
#   'craziness',
#   'but',
#   'i',
#   'keep',
#   'in',
#   'mind',
#   'that',
#   'my',
#   'throne',
#   'is',
#   'precious',
#   'to',
#   'my',
#   'lady',
#   'and',
#   'i',
#   'and',
#   'i',
#   'will',
#   'do',
#   'anything',
#   'to',
#   'keep',
#   'it',
#   'the',
#   'way',
#   'it',
#   'is',
#   'even',
#   'if',
#   'that',
#   'means',
#   'killing',
#   'the',
#   'people',
#   'around',
#   'me'],
#  ['i',
#   'feel',
#   'the',
#   'most',
#   'important',
#   'thing',
#   'is',
#   'just',
#   'someone',
#   'makes',
#   'you',
#   'very',
#   'comfortable',
#   'thats',
#   'all'],
#  ['i',
#   'do',
#   'not',
#   'feel',
#   'like',
#   'i',
#   'am',
#   'intelligent',
#   'enough',
#   'to',
#   'be',
#   'a',
#   'teacher'],
#  ['i',
#   'feel',
#   'i',
#   'don',
#   't',
#   'need',
#   'to',
#   'describe',
#   'how',
#   'gorgeous',
#   'the',
#   'dominican',
#   'republic',
#   'was',
#   'i',
#   'll',
#   'let',
#   'the',
#   'film',
#   'speak',
#   'for',
#   'itself'],
#  ['i',
#   'completely',
#   'lose',
#   'ability',
#   'to',
#   'segregate',
#   'my',
#   'feelings',
#   'with',
#   'my',
#   'actions',
#   'is',
#   'when',
#   'they',
#   'are',
#   'rude',
#   'and',
#   'hurtful',
#   'to',
#   'their',
#   'father',
#   'and',
#   'my',
#   'husband',
#   'who',
#   'is',
#   'also',
#   'my',
#   'hero',
#   'and',
#   'best',
#   'friend',
#   'and',
#   'heart'],
#  ['i',
#   'wanted',
#   'other',
#   'women',
#   'to',
#   'feel',
#   'envious',
#   'of',
#   'my',
#   'figure',
#   'and',
#   'say',
#   'oooh',
#   'youd',
#   'never',
#   'guess',
#   'youd',
#   'just',
#   'had',
#   'a',
#   'baby'],
#  ['i',
#   'honestly',
#   'feel',
#   'at',
#   'heart',
#   'we',
#   'should',
#   'be',
#   'faithful',
#   'to',
#   'each',
#   'other',
#   'if',
#   'its',
#   'yo',
#   'girl'],
#  ['i', 'feel', 'and', 'i', 'think', 'that', 'should', 'be', 'respected'],
#  ['i',
#   'use',
#   'emoticons',
#   'because',
#   'it',
#   'would',
#   'be',
#   'awkward',
#   'writing',
#   'i',
#   'am',
#   'feeling',
#   'amused',
#   'by',
#   'what',
#   'you',
#   'are',
#   'writing',
#   'right',
#   'now',
#   'as',
#   'opposed',
#   'to',
#   'xd'],
#  ['i',
#   'thought',
#   'i',
#   'hope',
#   'our',
#   'vanquished',
#   'england',
#   'failures',
#   'are',
#   'watching',
#   'this',
#   'and',
#   'feeling',
#   'very',
#   'envious',
#   'and',
#   'determined',
#   'to',
#   'do',
#   'everything',
#   'to',
#   'improve',
#   'and',
#   'maybe',
#   'one',
#   'day',
#   'do',
#   'something',
#   'similar',
#   'before',
#   'i',
#   'die'],
#  ['i',
#   'feel',
#   'irritated',
#   'that',
#   'he',
#   'either',
#   'interrupts',
#   'my',
#   'quiet',
#   'time',
#   'or',
#   'wakes',
#   'me',
#   'up'],
#  ['i',
#   'quickly',
#   'learned',
#   'just',
#   'by',
#   'moving',
#   'from',
#   'sauna',
#   'to',
#   'ice',
#   'cold',
#   'bath',
#   'to',
#   'steam',
#   'room',
#   'to',
#   'shower',
#   'until',
#   'you',
#   'feel',
#   'like',
#   'a',
#   'tortured',
#   'goldilocks',
#   'who',
#   'wants',
#   'nothing',
#   'more',
#   'than',
#   'to',
#   'find',
#   'the',
#   'middle',
#   'ground',
#   'between',
#   'too',
#   'hot',
#   'and',
#   'too',
#   'cold'],
#  ['i', 'feel', 'so', 'nervous', 'anxious', 'and', 'i', 'dont', 'know', 'why'],
#  ['i',
#   'feel',
#   'this',
#   'strange',
#   'shift',
#   'between',
#   'us',
#   'the',
#   'heat',
#   'between',
#   'us',
#   'intensifying',
#   'and',
#   'i',
#   'get',
#   'excited',
#   'my',
#   'nerves',
#   'bubbling',
#   'up',
#   'inside',
#   'me'],
#  ['i',
#   'dont',
#   'think',
#   'i',
#   'would',
#   'have',
#   'touched',
#   'this',
#   'book',
#   'if',
#   'i',
#   'hadnt',
#   'received',
#   'it',
#   'for',
#   'free',
#   'but',
#   'once',
#   'i',
#   'got',
#   'past',
#   'my',
#   'judgments',
#   'about',
#   'the',
#   'author',
#   'white',
#   'people',
#   'problems',
#   'entitled',
#   'rich',
#   'whining',
#   'and',
#   'self',
#   'delusions',
#   'i',
#   'feel',
#   'like',
#   'i',
#   'got',
#   'something',
#   'valuable',
#   'out',
#   'of',
#   'this',
#   'book'],
#  ['i',
#   'have',
#   'a',
#   'lovely',
#   'nesty',
#   'feeling',
#   'after',
#   'looking',
#   'at',
#   'all',
#   'that',
#   'cute',
#   'teeny',
#   'weeny',
#   'clothing'],
#  ['i',
#   'got',
#   'the',
#   'feeling',
#   'that',
#   'the',
#   'person',
#   'on',
#   'the',
#   'other',
#   'end',
#   'hated',
#   'me'],
#  ['i', 'am', 'just', 'feeling', 'grumpy', 'and', 'sore'],
#  ['i',
#   'was',
#   'able',
#   'to',
#   'maintain',
#   'physical',
#   'and',
#   'mental',
#   'activity',
#   'as',
#   'well',
#   'as',
#   'have',
#   'a',
#   'necessary',
#   'structure',
#   'and',
#   'routine',
#   'without',
#   'feeling',
#   'pressured',
#   'to',
#   'overdo',
#   'it'],
#  ['im', 'feeling', 'more', 'comfortable', 'in', 'the', 'water'],
#  ['im',
#   'feeling',
#   'very',
#   'uncomfortable',
#   'which',
#   'isnt',
#   'helping',
#   'im',
#   'sure'],
#  ['i',
#   'feel',
#   'it',
#   'gives',
#   'even',
#   'more',
#   'period',
#   'feel',
#   'and',
#   'detail',
#   'than',
#   'sharpe',
#   'and',
#   'is',
#   'certainly',
#   'good',
#   'enough',
#   'to',
#   'read',
#   'cover',
#   'to',
#   'cover'],
#  ['i',
#   'know',
#   'a',
#   'lot',
#   'of',
#   'people',
#   'are',
#   'whining',
#   'that',
#   'a',
#   'first',
#   'boot',
#   'cant',
#   'possibly',
#   'be',
#   'a',
#   'favourite',
#   'but',
#   'you',
#   'guys',
#   'know',
#   'how',
#   'i',
#   'feel',
#   'about',
#   'my',
#   'beloved',
#   'a',
#   'href',
#   'http',
#   'winterpaysforsummer'],
#  ['i',
#   'feel',
#   'so',
#   'weird',
#   'that',
#   'it',
#   'feels',
#   'like',
#   'i',
#   'wan',
#   'na',
#   'curse',
#   'everything',
#   'and',
#   'bang',
#   'my',
#   'head',
#   'onto',
#   'the',
#   'wall',
#   'so',
#   'that',
#   'my',
#   'world',
#   'will',
#   'be',
#   'back',
#   'to',
#   'its',
#   'focus'],
#  ['i',
#   'know',
#   'i',
#   'need',
#   'sleep',
#   'feeling',
#   'dissatisfied',
#   'with',
#   'myself',
#   'for',
#   'what',
#   'i',
#   've',
#   'yet',
#   'to',
#   'accomplish',
#   'instead',
#   'of',
#   'glowing',
#   'with',
#   'pride',
#   'at',
#   'all',
#   'i',
#   've',
#   'done'],
#  ['i',
#   'am',
#   'feeling',
#   'generous',
#   'so',
#   'you',
#   'can',
#   'pick',
#   'any',
#   'reason',
#   'you',
#   'like',
#   'but',
#   'make',
#   'sure',
#   'you',
#   'take',
#   'your',
#   'wise',
#   'mothers',
#   'advice',
#   'so',
#   'i',
#   'dont',
#   'feel',
#   'the',
#   'need',
#   'to',
#   'drag',
#   'all',
#   'this',
#   'to',
#   'court'],
#  ['i',
#   'told',
#   'her',
#   'yeah',
#   'they',
#   'feel',
#   'insecure',
#   'and',
#   'they',
#   'bully',
#   'people',
#   'because',
#   'it',
#   'makes',
#   'them',
#   'feel',
#   'powerful',
#   'physically'],
#  ['i', 'feel', 'like', 'offended', 'with', 'such', 'question'],
#  ['im',
#   'slow',
#   'about',
#   'this',
#   'but',
#   'it',
#   'does',
#   'feel',
#   'weird',
#   'returning',
#   'to',
#   'a',
#   'home',
#   'without',
#   'your',
#   'mum',
#   'anymore'],
#  ['i',
#   'was',
#   'feeling',
#   'relatively',
#   'indecisive',
#   'and',
#   'not',
#   'very',
#   'hungry',
#   'until',
#   'we',
#   'walked',
#   'past',
#   'a',
#   'barbeque',
#   'place'],
#  ['i',
#   'feel',
#   'peaceful',
#   'and',
#   'unafraid',
#   'certain',
#   'that',
#   'my',
#   'god',
#   'has',
#   'my',
#   'best',
#   'interests',
#   'at',
#   'heart'],
#  ...]

# %%
len(word_token)
# Out:
# 4749

# %%
# Remove stopwords from each sublist in word_token
filtered_tokens_train = [[word for word in sublist if word not in stop_words] for sublist in word_token]

# Display the first sublist of filtered tokens after removing stopwords
print(filtered_tokens_train[0])
# Out:
# ['fear', 'people', 'ask', 'feelings', 'reluctant', 'talk', 'things']

# %%
print(filtered_tokens_train[1])
# Out:
# ['ive', 'thinking', 'drives', 'fashion', 'pretentious', 'gon', 'na', 'make', 'sound', 'studying', 'fashion', 'design', 'feel', 'kinda', 'vital', 'understand', 'im', 'trying', 'life', 'whole']

# %% [markdown]
# **Vectorization Word2Vec - Skipgram**

# %%
import gensim
from gensim.models import Word2Vec 
model_skipgram = gensim.models.Word2Vec(filtered_tokens_train, min_count = 1,vector_size = 100, window = 3, sg=1)

# %%
vocabulary_skipgram = model_skipgram.wv.index_to_key
word_vec_dict={}
for word in vocabulary_skipgram:
    word_vec_dict[word]=model_skipgram.wv.get_vector(word)
print("The no of key-value pairs : ",len(word_vec_dict)) # should come equal to vocab size
# Out:
# The no of key-value pairs :  7769

# %%
word_vec_dict
# Out:
# {'feel': array([-0.09020506,  0.21579523,  0.10908302,  0.13433829,  0.0090368 ,
#         -0.31923527,  0.19597046,  0.43997312, -0.18532445, -0.28009373,
#          0.0292987 , -0.33271557, -0.01520094,  0.10062836,  0.08899105,
#         -0.1582728 ,  0.12101362, -0.23911166, -0.07025401, -0.49100935,
#          0.15693381,  0.03506279,  0.26180148, -0.05387862, -0.08609644,
#         -0.08325439, -0.13355212, -0.04143945, -0.25806916,  0.02062106,
#          0.15884927,  0.02198538,  0.03363397, -0.38116726, -0.21337089,
#          0.23273526,  0.12432735, -0.19992536, -0.21426883, -0.31394154,
#          0.04396219, -0.23854531, -0.11652745, -0.06884799,  0.28156453,
#         -0.10782237, -0.15000373,  0.01009492,  0.13594715,  0.2142343 ,
#          0.17312214, -0.21432966, -0.14749111, -0.05102328, -0.19565779,
#          0.17793283,  0.11327071, -0.11855095, -0.256775  ,  0.25534105,
#          0.07638612,  0.05286911,  0.04689517, -0.09358364, -0.27271143,
#          0.16877548, -0.0257697 ,  0.23471494, -0.3476886 ,  0.31355786,
#         -0.08724082,  0.14365503,  0.33329582, -0.07130773,  0.19143295,
#          0.0411037 ,  0.11273295,  0.02715918, -0.22219163,  0.08786462,
#         -0.0992377 , -0.11281963, -0.26543495,  0.21084079, -0.04570397,
#         -0.01341784,  0.10438016,  0.14744201,  0.272574  , -0.04617698,
#          0.18860248,  0.15146466, -0.08332122,  0.01237082,  0.28742203,
#          0.22822708,  0.19840002, -0.22298598,  0.17002182, -0.11155002],
#        dtype=float32),
#  'feeling': array([-0.10894168,  0.21944785,  0.10166333,  0.13999927,  0.0498998 ,
#         -0.2968121 ,  0.17541395,  0.4533002 , -0.17627199, -0.2744814 ,
#          0.01380642, -0.33012325, -0.01213045,  0.10972111,  0.08305238,
#         -0.14931843,  0.10930392, -0.23117943, -0.05425328, -0.46835265,
#          0.15575261, -0.00309444,  0.2696182 , -0.07677887, -0.0719991 ,
#         -0.08863863, -0.1293418 , -0.04021063, -0.23542401,  0.04614181,
#          0.19640677,  0.02450982, -0.02526457, -0.3582453 , -0.18629065,
#          0.24872565,  0.14830537, -0.16992027, -0.19935414, -0.28756395,
#          0.10683461, -0.2668588 , -0.12766701, -0.06036838,  0.26039588,
#         -0.08431308, -0.12854409, -0.02273278,  0.12722178,  0.17732157,
#          0.2140286 , -0.24183947, -0.12250619, -0.04668406, -0.21969151,
#         -0.04673974,  0.05362224,  0.14611802, -0.04137237,  0.07771443,
#          0.01725684,  0.04416858,  0.00390024, -0.08538775,  0.05637122,
#         -0.03058872, -0.05091442, -0.11507653,  0.08425699, -0.01749314,
#         -0.0088535 ,  0.03441659,  0.07225635,  0.12802635, -0.03277175,
#          0.08765473,  0.0515859 , -0.03135291,  0.01004801,  0.10826323,
#          0.10159016,  0.09454008, -0.10347533,  0.07109386, -0.04720933],
#        dtype=float32),
#  ...}

# %%
max_sen_len= max_sen # max lenght of word in a sentence
vocab_size =35000  #ideally it should be len(tok.word_index) + 1  or total no of words in data in this case = 4750, but to handle number of data which not appear in train, for example in test, make the size higher
embed_dim=100 # embedding dimension as choosen in word2vec constructor

# %%
from keras.preprocessing.text import one_hot,Tokenizer
tok = Tokenizer()
tok.fit_on_texts(filtered_tokens_train)
vocab_size = vocab_size
encd_rev = tok.texts_to_sequences(filtered_tokens_train)
# Out:
# 2024-02-01 14:49:08.689733: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# now creating the embedding matrix
embed_matrix=np.zeros(shape=(vocab_size,embed_dim))
for word,i in tok.word_index.items():
    embed_vector=word_vec_dict.get(word) #mapping the vector to word in our skipgram dictionary
    if embed_vector is not None:  # word is in the vocabulary learned by the w2v model
        embed_matrix[i]=embed_vector
  # if word is not found then embed_vector corressponding to that vector will stay zero.

# %% [markdown]
# **Preparing the Data for Embedding Layer**

# %%
encd_rev
# Out:
# [[566, 10, 281, 49, 117, 190, 25],
#  [18,
#   178,
#   2211,
#   1209,
#   3386,
#   1056,
#   377,
#   23,
#   713,
#   1388,
#   1209,
#   1210,
#   1,
#   567,
#   602,
#   228,
#   4,
#   82,
#   26,
#   126],
#  [31, 603, 1, 207],
#  [1, 104, 3, 378, 3387, 2212],
#  [20,
#   2213,
#   2214,
#   3388,
#   22,
#   2,
#   155,
#   2213,
#   532,
#   1693,
#   111,
#   456,
#   714,
#   2215,
#   3389],
#  [1, 7, 179, 30],
#  [8, 61, 86, 3390, 764, 1, 3, 512, 1, 765, 165, 1694, 44, 1211, 2216],
#  [2, 69, 21, 1695, 1389],
#  [1, 4, 140, 282],
#  [1, 3, 133, 16, 3391, 3392, 2217, 21, 312, 350, 2218, 2219],
#  [1, 3, 4, 208, 2220, 89, 66, 568],
#  [1,
#   98,
#   16,
#   74,
#   31,
#   16,
#   74,
#   407,
#   434,
#   1696,
#   2221,
#   13,
#   651,
#   192,
#   3393,
#   1697,
#   2222,
#   243,
#   766,
#   6,
#   294,
#   1698,
#   84,
#   341,
#   1390],
#  [2, 58, 90],
#  [8, 1699, 2, 295, 166],
#  [18, 2, 7, 715, 283, 13, 180, 313, 533, 3394],
#  [1, 58, 109, 652, 604, 605, 1700, 314, 379, 4, 2223],
#  [13, 569, 220, 487, 1212, 1, 3, 221, 172, 3395, 1391],
#  [2, 101, 342, 35, 435, 181, 33],
#  [1,
#   767,
#   1701,
#   408,
#   1392,
#   380,
#   3396,
#   134,
#   3397,
#   3398,
#   848,
#   3399,
#   381,
#   2224,
#   3400,
#   2225],
#  [49, 488, 1, 31, 53, 1393, 3401, 716, 3402],
#  [18, 209, 55, 606, 653, 229, 1394, 1395, 946, 40, 29, 3403, 52, 155],
#  [1, 513, 9, 7, 228, 1, 3404, 2226, 62, 144],
#  [7, 2227, 382, 55, 1, 221, 141],
#  [4, 2, 112, 173, 768, 717, 1702, 19, 1703],
#  [1704, 947, 17, 230, 17, 222, 948, 52, 1705, 2, 112, 534, 367, 135],
#  [1, 849, 1706, 1707, 182, 15, 1213, 718, 284, 1396, 15, 436],
#  [1, 3, 1397, 244, 769, 4, 21, 41, 24, 23, 13, 52],
#  [1, 296, 207],
#  [3405, 64, 35, 1, 12, 343, 3406, 1057, 156, 3407],
#  [4, 21, 949, 79, 1398, 41, 25, 3408, 59, 1, 102, 121, 3, 1058, 1399, 33, 74],
#  [1,
#   315,
#   315,
#   197,
#   719,
#   220,
#   607,
#   316,
#   1209,
#   103,
#   102,
#   271,
#   34,
#   297,
#   850,
#   569],
#  [13, 70, 383, 851, 1708, 1400, 113, 1401, 1, 330, 113, 457, 3, 3409, 1709, 5],
#  [145, 852, 74, 458, 770, 24, 4, 2, 12, 272],
#  [5, 4, 58, 122, 79, 1, 3, 20, 11, 853, 66, 24, 109],
#  [1059,
#   1710,
#   193,
#   3410,
#   1,
#   1711,
#   75,
#   41,
#   3411,
#   3412,
#   96,
#   1712,
#   245,
#   84,
#   3413,
#   1713],
#  [4, 89, 4, 1060, 59, 1, 384, 570],
#  [245, 409, 7, 2, 1714, 331, 90, 3414],
#  [40, 273],
#  [19, 13, 771, 608, 1715, 191, 9, 1, 69],
#  [1, 295, 101, 2228, 3415],
#  [2, 210, 69],
#  [180, 96, 1214, 1716, 1717, 180, 27, 141, 1, 221],
#  [608, 211, 654, 2, 3, 150],
#  [1718, 35, 950, 1402, 3416, 13, 1719, 772, 456, 1061, 47, 1, 1062],
#  [298, 2, 183, 1063, 714, 3417, 655, 3418, 3419],
#  [1, 3, 951, 459, 3420, 3421, 1403, 3422],
#  [41,
#   6,
#   854,
#   40,
#   51,
#   535,
#   2229,
#   609,
#   773,
#   952,
#   1720,
#   167,
#   3423,
#   3424,
#   1720,
#   1215,
#   1216,
#   764,
#   1721],
#  [76, 2, 198, 6, 255],
#  [536, 514, 190, 351, 332, 127, 855, 852, 856, 1, 223, 5, 11, 3425, 774, 775],
#  [3426, 127, 857, 3427, 317, 2230],
#  [38,
#   1,
#   38,
#   228,
#   10,
#   385,
#   2231,
#   252,
#   1404,
#   1064,
#   2232,
#   299,
#   11,
#   32,
#   27,
#   3428,
#   368,
#   1405,
#   3429,
#   3430,
#   437,
#   610],
#  [13, 3431, 2233, 1, 184, 30, 656, 197, 12, 3432, 114, 26],
#  [178, 3433, 25, 168, 2, 2234, 67, 136, 1406],
#  [87, 2, 231, 212],
#  [1, 3, 410, 54, 369, 228, 411, 185, 953, 151, 11, 515, 571],
#  [146, 776, 2, 127, 137, 611, 352, 146, 222],
#  [18, 2, 2235, 105],
#  [261, 3434, 2236, 2, 89],
#  [1, 386, 489, 92, 1407],
#  [1, 344, 106, 490],
#  [50, 412, 1, 64, 1740, 413, 2252],
#  [1, 330, 3478, 113, 4, 58, 2, 47, 44, 1224, 16],
#  [83, 850, 3479, 409, 31, 569, 3480, 2253, 540, 249, 45, 2, 120, 9, 92, 2254],
#  [2, 72, 1741, 194, 255],
#  [1, 3, 4, 98, 3, 192, 441],
#  [83, 9, 144, 2, 71],
#  [1, 98, 860, 355, 462, 17, 127],
#  [287,
#   1,
#   39,
#   536,
#   88,
#   3481,
#   3482,
#   378,
#   3483,
#   232,
#   20,
#   129,
#   571,
#   3484,
#   43,
#   1742],
#  [1225,
#   1073,
#   661,
#   1226,
#   781,
#   613,
#   21,
#   168,
#   35,
#   1,
#   12,
#   221,
#   3485,
#   29,
#   41,
#   46,
#   2255,
#   10],
#  [4, 236, 2, 123],
#  [1, 302, 2256, 1743, 2257, 2258, 276, 3486],
#  [1, 198, 107, 45, 2, 77, 235, 1744, 13, 3487, 274],
#  [1, 54, 96, 168, 44, 3488, 26, 767, 321, 356],
#  [4, 3489, 3490, 195, 59, 357, 1, 29, 662, 246, 663, 3491, 3492, 3493, 12],
#  [1, 108, 351, 54, 214, 1745, 342, 568],
#  [60, 1, 50, 1414, 117, 351, 7, 202, 21],
#  [494,
#   224,
#   861,
#   1074,
#   40,
#   288,
#   1227,
#   3494,
#   713,
#   3,
#   3495,
#   3496,
#   158,
#   194,
#   1074,
#   1415,
#   2259],
#  [23, 2260, 1416, 37, 13, 1, 3497, 72, 25],
#  [1, 147, 41, 24],
#  [3498,
#   192,
#   1746,
#   492,
#   441,
#   30,
#   862,
#   193,
#   43,
#   261,
#   207,
#   1,
#   409,
#   1746,
#   97,
#   26,
#   91,
#   2261],
#  [106, 863, 21, 3499, 2262, 1228, 3500, 3501, 266, 230, 23, 1, 104, 256],
#  [137, 299, 49, 137, 1417, 774, 31, 137, 3502, 2263, 127, 7, 3503],
#  [2, 438, 412, 277, 278, 21, 1747],
#  [1, 463, 94, 3504, 1075, 78, 3505, 3506],
#  [20, 5, 1, 101, 3507, 25, 229, 10],
#  [289, 53, 1, 3, 36, 237, 190, 495, 170],
#  [145,
#   87,
#   1058,
#   1,
#   80,
#   1418,
#   782,
#   2264,
#   14,
#   576,
#   319,
#   5,
#   9,
#   73,
#   238,
#   614,
#   3508],
#  [494, 224, 2, 3, 86, 1748, 541, 8, 3509, 297, 1229, 3510],
#  [853,
#   77,
#   180,
#   1,
#   2265,
#   4,
#   123,
#   864,
#   3511,
#   30,
#   1749,
#   3512,
#   1750,
#   610,
#   213,
#   615,
#   46],
#  [8, 211, 2, 127, 2266, 26, 101, 2, 616, 225, 44],
#  [1, 2267, 71, 1719, 724, 3513, 664, 1419],
#  [1, 7, 104, 4, 1751],
#  [36, 1076, 1077, 518, 26, 40, 71, 960],
#  [130, 18, 496, 44, 143, 335, 9, 286, 603, 442, 1, 153],
#  [1, 783, 1752, 1753, 1754, 275],
#  [303, 2, 105, 665, 1755, 1756, 212, 215],
#  [1, 19, 57],
#  [1, 3, 4, 239],
#  [4, 303, 777, 2, 367, 345, 21, 27, 777],
#  [1230, 26, 145, 75, 322, 26, 42, 1, 89, 322],
#  [18, 1, 33, 44, 42, 126, 1420, 617, 126, 28],
#  [4, 295, 56, 1078, 3514, 44, 4, 2, 120, 107, 73, 577, 2268, 1757],
#  [1, 666, 55, 865, 323],
#  [2, 112, 459, 48, 3, 866, 3515],
#  [1,
#   1421,
#   3516,
#   3517,
#   1422,
#   3518,
#   3519,
#   3520,
#   725,
#   1423,
#   1721,
#   667,
#   203,
#   1079],
#  [1758, 1, 1759, 110, 57, 252, 10],
#  [324, 1, 236],
#  [354, 61, 2269, 2270, 346, 3521, 142, 2, 542, 202, 867, 141, 437],
#  [1, 302, 2256, 1743, 2257],
#  [4, 3522, 249, 173, 2271, 59, 1, 3523, 258, 43, 173, 393],
#  [83, 1760, 358, 1761, 59, 1, 726],
#  [1, 39, 102, 961, 142, 1762, 3524, 134, 3525, 21, 727],
#  [2, 101, 248],
#  [1077, 1763, 3526, 1080, 1, 443, 51, 148, 1764, 394, 3527, 2272],
#  [868, 2, 71, 543, 2, 664],
#  [287, 38, 1, 184, 25, 1765, 1766, 359, 3528],
#  [1, 58, 93, 42, 26, 1231, 124, 42, 3529],
#  [1, 302, 158, 962, 3530],
#  [533, 3531, 4, 2, 618, 155],
#  [2, 226, 25, 869, 21, 32, 17, 11, 1424],
#  [18, 2, 360, 283],
#  [197, 49, 47, 167, 963, 393],
#  [8, 2, 10, 13, 4, 360, 1767, 784, 870, 723, 1768, 197, 785],
#  [4,
#   544,
#   30,
#   1,
#   3,
#   36,
#   11,
#   202,
#   6,
#   464,
#   659,
#   463,
#   3532,
#   382,
#   68,
#   3533,
#   23,
#   1,
#   77],
#  [1, 12, 3, 3534, 304, 870, 726, 2],
#  [395, 165, 95, 1, 290, 346, 1769, 497, 668, 9, 86],
#  [96, 2, 65, 1767],
#  [1232, 498, 3535, 860, 1, 109, 2273, 135, 3536, 187, 768, 2274],
#  [3537, 669, 3538, 1, 3539, 964, 3540],
#  [3541, 22, 313, 1081, 4, 2, 257, 273, 46, 1233, 4, 2, 57, 81, 9],
#  [18, 1425, 157, 131, 4, 2, 19, 12, 1767, 125, 20, 5, 131, 1770, 24, 341],
#  [4, 2, 6, 465, 248, 3, 3542, 38, 786, 11, 81, 8, 1082],
#  [1771,
#   361,
#   1083,
#   2275,
#   21,
#   92,
#   27,
#   2,
#   185,
#   22,
#   670,
#   466,
#   48,
#   3,
#   1234,
#   1235,
#   3543],
#  [5, 1, 174, 243, 14, 100, 192, 8, 7, 303, 3544, 8],
#  [305, 1, 70, 204, 25, 45, 2276, 1084, 1731, 240],
#  [31,
#   2277,
#   1085,
#   787,
#   1772,
#   1236,
#   1212,
#   23,
#   1,
#   3545,
#   3546,
#   1734,
#   3547,
#   671,
#   467,
#   444,
#   1426,
#   414,
#   299,
#   393],
#  [1, 188],
#  [5, 1061, 619, 291, 2278, 965, 59, 151, 1, 1086, 14, 277, 3548],
#  [250, 73, 17, 871, 3549, 1427, 91, 2, 850, 27, 110],
#  [1, 152, 3, 68, 95, 137, 165, 3, 43, 111, 187, 3550, 3551],
#  [11, 1, 109, 2279, 1773, 233, 2280, 1237, 1428],
#  [4, 2, 62, 12, 715, 3552, 672, 114],
#  [1, 671, 1429],
#  [106, 1, 36, 106, 59, 6, 256],
#  [3553, 3554, 3555, 2281, 211, 2282, 1430, 445, 1, 499, 415, 468, 241, 28],
#  [88,
#   3556,
#   1431,
#   204,
#   1432,
#   2283,
#   1744,
#   1238,
#   872,
#   1774,
#   3557,
#   1,
#   251,
#   866,
#   42],
#  [2284, 47, 130, 2284, 259, 1, 121, 9, 11, 500, 92, 1775, 728],
#  [543, 1, 302, 2, 1087, 673, 1088],
#  [4,
#   2,
#   36,
#   534,
#   73,
#   24,
#   2285,
#   3558,
#   4,
#   468,
#   2286,
#   18,
#   38,
#   50,
#   32,
#   2287,
#   143,
#   8,
#   3559],
#  [35,
#   31,
#   369,
#   1776,
#   3560,
#   1,
#   3,
#   192,
#   156,
#   1056,
#   377,
#   5,
#   16,
#   10,
#   786,
#   545,
#   25,
#   3,
#   1777],
#  [20, 3, 17, 1, 57],
#  [4, 2, 1433, 97, 469],
#  [354, 85, 16, 28, 1239, 788, 3561, 392, 776, 1413, 1089, 669, 3562, 2288],
#  [1, 140, 3563, 25, 267, 515],
#  [1, 3, 4, 16, 873, 170, 1059, 313, 1090, 170, 10, 313, 306, 33, 193],
#  [268, 251, 3564, 966, 2, 29, 1240, 307, 3565],
#  [4, 2, 201, 3566, 3567, 3568, 324, 144, 441, 32, 967, 968, 416, 578],
#  [1, 150],
#  [1434, 2, 210, 159],
#  [22, 1, 230, 124, 789, 90, 1406],
#  [73, 62, 230, 417, 11, 10, 1, 602, 1435],
#  [1, 3, 4, 221, 2289, 1436, 3569, 318],
#  [130, 2290, 1778, 238, 55, 1, 89, 284],
#  [1, 172],
#  [1, 172, 43, 111, 3570, 12],
#  [216, 620, 1437, 3571, 23, 1, 273, 252, 2291],
#  [4, 2, 6, 413, 3572, 46],
#  [3, 1, 147, 115, 3, 651, 9],
#  [1, 117, 1779, 969],
#  [4,
#   2,
#   147,
#   3573,
#   9,
#   3574,
#   3575,
#   579,
#   1780,
#   3576,
#   5,
#   180,
#   1241,
#   790,
#   2292,
#   86],
#  [729, 202, 665, 26, 621, 1781, 3577, 3578, 2293, 3579, 139, 35, 1, 346],
#  [849,
#   2,
#   47,
#   175,
#   3580,
#   1242,
#   2294,
#   83,
#   319,
#   501,
#   609,
#   519,
#   133,
#   3581,
#   9,
#   208],
#  [674,
#   13,
#   567,
#   2295,
#   3582,
#   1782,
#   55,
#   228,
#   1,
#   25,
#   330,
#   2296,
#   17,
#   3583,
#   3584,
#   1438,
#   229,
#   38,
#   2,
#   874],
#  [4, 2, 446, 3585, 207, 3586],
#  [436, 37, 3587, 396, 1783, 141, 16, 142, 160],
#  [13, 10, 6, 875, 3588, 45, 1, 89, 132, 1784, 622, 580, 8, 1091, 29, 3589],
#  [1785, 2, 6, 120],
#  [4, 2, 290, 446],
#  [4, 2, 128],
#  [205, 35, 96, 12, 2297, 4, 2, 290, 470],
#  [87, 2, 520, 2298, 418, 2299, 397, 250, 1786, 6, 12, 3590],
#  [1, 2300, 179, 258, 3591, 115, 767, 3592, 613, 875, 1092, 623, 411, 3593, 17],
#  [38, 8, 791, 2301, 1407, 1078, 1, 39, 2302, 3594, 730],
#  [124,
#   1,
#   231,
#   2303,
#   3595,
#   16,
#   3596,
#   242,
#   67,
#   3597,
#   3598,
#   718,
#   963,
#   206,
#   502,
#   3599,
#   546,
#   624,
#   1419,
#   20,
#   876,
#   2303,
#   2304,
#   1228,
#   2305],
#  [1, 662, 247, 216, 625],
#  [1, 547],
#  [1, 43, 190, 502, 79, 14, 731, 566, 78, 170, 385, 1243],
#  [2, 39, 157, 224, 3600, 7, 55, 1, 70, 77],
#  [1, 234, 1093, 133, 460, 11, 416, 9],
#  [13, 116, 417, 25, 13, 1414, 345, 13, 55, 1, 662],
#  [130, 36, 37, 675, 4, 2, 90, 4, 35, 136],
#  [50, 7, 3601, 277, 1, 3, 96, 336, 792],
#  [471, 234, 434, 772, 1787, 3602, 1244, 2, 109, 877],
#  [1094, 966, 133, 294, 91, 2306],
#  [88, 1, 118, 3603, 878, 731, 2307, 2308],
#  [4, 2, 184, 178, 1788, 1245, 879, 1246],
#  [95,
#   8,
#   1439,
#   66,
#   468,
#   880,
#   50,
#   419,
#   32,
#   3604,
#   14,
#   238,
#   33,
#   187,
#   362,
#   1,
#   3605,
#   398,
#   330,
#   260],
#  [1, 155, 70],
#  [1, 3, 7, 438, 86, 8, 2309, 1, 3, 81],
#  [106,
#   193,
#   458,
#   2310,
#   357,
#   62,
#   168,
#   793,
#   28,
#   111,
#   264,
#   265,
#   13,
#   84,
#   286,
#   37,
#   970,
#   1,
#   78,
#   676,
#   3606],
#  [38, 13, 179, 1440, 2311, 2, 179, 1789, 3607, 179],
#  [1218, 1, 207, 579, 84],
#  [1, 12, 72, 1790, 417, 971],
#  [1, 118, 130],
#  [1, 16, 308, 464],
#  [1791, 195, 341, 99, 143, 192, 235, 1, 17, 472, 1792],
#  [732, 1, 6, 153, 216, 3608, 3609, 1095, 473, 3610],
#  [1, 120, 175, 258, 16, 1412, 3611, 197, 3612, 3613],
#  [1, 666, 21, 1441, 244, 1442, 17, 2312, 3614, 3615, 3616, 3617, 247],
#  [1, 503],
#  [2, 292, 504, 2313],
#  [1, 7, 72, 91, 3618, 79, 11, 955, 420],
#  [363,
#   237,
#   1,
#   47,
#   44,
#   313,
#   505,
#   240,
#   1793,
#   14,
#   495,
#   48,
#   3,
#   1794,
#   3619,
#   67,
#   1096,
#   333,
#   3620,
#   52,
#   1097,
#   581,
#   2314,
#   303],
#  [1,
#   51,
#   116,
#   1443,
#   1067,
#   794,
#   3621,
#   795,
#   473,
#   677,
#   3622,
#   678,
#   75,
#   127,
#   733,
#   3623,
#   3624,
#   8,
#   337,
#   1072,
#   8,
#   61],
#  [1, 1444, 253],
#  [1445, 1795, 1796, 42, 3625],
#  [1098, 265, 106, 1247, 3626, 1068, 1, 153],
#  [1,
#   463,
#   972,
#   94,
#   3627,
#   1248,
#   3628,
#   1,
#   56,
#   156,
#   92,
#   3629,
#   973,
#   3630,
#   2315,
#   3631],
#  [1, 198, 47, 2316],
#  [3632, 129, 1797, 537, 1, 521, 1797, 279, 371, 238, 3633, 55],
#  [2, 325, 323, 309, 32, 3634, 796, 3635],
#  [1, 102, 260, 1, 3],
#  [11,
#   171,
#   4,
#   2,
#   20,
#   5,
#   124,
#   11,
#   171,
#   66,
#   4,
#   89,
#   1716,
#   797,
#   214,
#   15,
#   24,
#   514,
#   196],
#  [1,
#   326,
#   1798,
#   2317,
#   474,
#   321,
#   491,
#   5,
#   974,
#   652,
#   77,
#   1446,
#   217,
#   652,
#   2318,
#   23,
#   975,
#   3636,
#   1249,
#   3637],
#  [7, 1, 3, 9, 8, 159],
#  [130,
#   15,
#   1,
#   3,
#   3638,
#   3639,
#   472,
#   282,
#   372,
#   1799,
#   516,
#   335,
#   1099,
#   114,
#   11,
#   2319,
#   260,
#   176,
#   59,
#   734],
#  [1, 54, 211, 143, 335, 72, 1447, 881, 735, 14, 1800, 421, 66, 192, 3640],
#  [4, 159, 412, 28, 1, 93],
#  [2320, 3641, 3642, 1, 179, 2321, 3643, 2322, 539, 2323, 252, 1100],
#  [152, 398, 2324, 1, 140],
#  [11, 1, 17, 522, 1093, 399, 1801, 143],
#  [79, 1, 6, 101, 1448, 7],
#  [161, 369, 882, 2325, 142, 8, 32, 2, 112, 272],
#  [18, 58, 373, 261, 126, 26, 1802, 3644, 2, 2326, 305, 108, 1449],
#  [1, 52, 51, 12, 255, 79],
#  [1, 3, 11, 1250, 2327, 241],
#  [4, 2, 29, 475, 254, 1450, 3645],
#  [317, 277, 48, 3646, 3647, 3648],
#  [4, 2, 300, 181, 1101, 5, 400, 381],
#  [4, 2, 883, 1803, 119, 131, 2328, 351],
#  [171, 660, 1, 177, 124, 3649, 2329],
#  [1, 138, 44, 8],
#  [4, 2330, 1, 616, 9],
#  [3650, 83, 2331, 76, 501, 2331, 2, 39, 1804, 1102, 3651],
#  [1, 3652, 520, 126, 495],
#  [2332, 1451, 2, 338, 626, 169, 1223, 21, 92],
#  [7, 1, 240, 98, 2333],
#  [1, 581, 13, 503, 1103, 572],
#  [1, 1452, 1773, 204, 679, 11, 266, 338, 3653, 884, 149],
#  [299, 49, 2334, 533, 715, 1805, 3654, 162],
#  [1, 54, 39, 138, 145, 1806, 16, 2335, 1807],
#  [7, 20, 1, 680, 1808, 259],
#  [1, 3655, 163, 135],
#  [32, 279, 84, 2, 239, 339, 2336, 3656, 1251],
#  [1, 681, 3657, 1104, 227],
#  [1, 183, 1105, 798, 1453, 299, 447, 1733],
#  [799,
#   1106,
#   156,
#   129,
#   736,
#   3658,
#   3659,
#   35,
#   2337,
#   3660,
#   2338,
#   357,
#   40,
#   198,
#   5,
#   3661,
#   401],
#  [19, 2, 102, 28],
#  [5, 2295, 2339, 2, 239, 44, 46, 1454, 2340],
#  [11, 448, 393, 5, 13, 1, 98, 476, 885, 141, 2341],
#  [4, 2, 223, 3662],
#  [4, 2, 1455, 466, 216, 627, 241, 3663],
#  [87, 2, 769],
#  [305, 1, 3664, 1252, 396, 3665, 179],
#  [2, 12, 477, 216, 2342, 3666, 855, 1809, 3667, 50, 3668],
#  [1, 4, 39, 1456, 2343, 4, 2344],
#  [1, 279, 25, 20, 11, 1457, 170],
#  [1253, 1, 886, 1254, 1239, 21, 211, 144],
#  [180, 1103, 1, 208, 469, 83, 209, 63, 193, 3669],
#  [4, 2344, 156, 887, 2, 607, 582, 1458],
#  [124, 2, 57, 36, 67, 111, 976, 4, 7, 2, 515, 26, 2345, 17],
#  [1, 3, 239, 2346, 3670, 3671, 1091, 2347, 460, 1810, 628, 2348, 460, 1810],
#  [1, 17, 3672, 204, 293, 42, 7, 196, 1255, 293, 34, 46],
#  [1,
#   52,
#   541,
#   2349,
#   2350,
#   1058,
#   7,
#   1,
#   52,
#   541,
#   2349,
#   2350,
#   1058,
#   310,
#   203,
#   1079],
#  [189, 8, 3673, 2351, 3674, 224, 664, 99, 74, 189, 664, 888, 233, 2, 6, 201],
#  [2, 1811, 21, 541, 3675, 970, 3676, 521, 30],
#  [1, 63, 138, 2243, 374, 1454, 1459, 3677, 11, 781, 604, 737, 3678, 3679],
#  [67, 2, 302],
#  [1, 1725, 1460, 1461, 657, 1704],
#  [271, 126, 2352, 3680, 677, 1107, 3681, 354, 85, 1, 1256, 487],
#  [180, 311, 2, 6, 123, 800, 94, 162, 3682],
#  [56, 156, 151, 48, 2, 237, 151, 205, 8, 51, 629],
#  [18, 889, 889, 40, 78, 72],
#  [168, 1, 153, 26],
#  [90, 87, 214, 1257, 3683, 2, 121, 162, 738, 1812],
#  [189, 1, 478],
#  [4, 2, 6, 548, 4, 370, 378, 801, 352, 4, 1258],
#  [3684, 1259, 515, 277, 1, 285],
#  [15, 1, 1260, 2353, 1462, 1463, 1813],
#  [2, 256, 46],
#  [35, 38, 1, 6, 93],
#  [1, 422],
#  [977, 1252, 460, 162, 1, 1814, 3685, 291, 20, 977, 3686],
#  [1, 388, 3687],
#  [399, 3688, 280, 78, 3689, 2354, 2, 188, 1219, 2355, 1093, 958],
#  [22, 14, 13, 116, 2220, 47, 86, 1, 3, 4, 98, 11, 978, 420, 1108, 130],
#  [18, 857, 583, 79, 1, 400, 503],
#  [2, 39, 3690, 1815, 347, 1261, 506, 8, 2356, 873],
#  [504, 1262, 979, 3691, 1816, 493, 3692, 663, 1263, 2, 657, 1446, 2357, 3693],
#  [3694, 786, 3695, 802, 3696, 2, 3697, 1109, 715, 1110],
#  [423,
#   628,
#   1464,
#   720,
#   3698,
#   55,
#   1,
#   199,
#   3699,
#   9,
#   1465,
#   3700,
#   14,
#   398,
#   53,
#   7,
#   3],
#  [142, 656, 1264, 2358, 2329, 3701, 1466, 803, 2, 198],
#  [72, 2, 21, 391, 58, 288, 402, 44, 2359, 1817, 258, 2360, 1818, 361],
#  [124, 2, 69],
#  [2,
#   980,
#   477,
#   1111,
#   584,
#   424,
#   1251,
#   1467,
#   477,
#   3702,
#   1217,
#   22,
#   37,
#   3703,
#   3704,
#   424,
#   312,
#   617,
#   584,
#   2361,
#   160,
#   16,
#   3705,
#   1112,
#   3706],
#  [96, 19, 1819, 3707, 2, 4, 56, 180, 3708, 460],
#  [1, 188, 1468, 739, 322, 1469, 190, 194, 127, 393, 1113, 882, 3709, 64],
#  [60, 11, 3710, 1, 147, 199, 3711, 423, 414, 36, 238, 1114, 507, 2362],
#  [18,
#   1265,
#   3712,
#   890,
#   9,
#   18,
#   76,
#   2,
#   3,
#   1815,
#   891,
#   138,
#   74,
#   1255,
#   225,
#   141,
#   873,
#   549],
#  [4,
#   2,
#   256,
#   175,
#   3713,
#   3714,
#   3715,
#   1266,
#   3716,
#   3717,
#   1267,
#   2363,
#   246,
#   515,
#   256,
#   175],
#  [4, 2, 155, 2364, 630],
#  [4, 981, 802, 949, 2, 117, 8, 3718, 34, 682, 63, 1820],
#  [11, 3719, 2, 408],
#  [1796, 85, 2, 499, 403],
#  [449, 40, 479, 3720, 246, 158],
#  [1821,
#   1268,
#   1470,
#   873,
#   1471,
#   66,
#   13,
#   1,
#   1115,
#   580,
#   740,
#   3721,
#   72,
#   2365,
#   1268],
#  [2366, 128, 57, 159, 84, 1, 39, 29, 1822, 150],
#  [1, 346, 8, 27, 2367, 439, 33, 361, 230],
#  [1, 3, 2368, 665, 1, 425, 28, 47],
#  [2, 105, 176, 3722],
#  [50,
#   2,
#   137,
#   15,
#   311,
#   132,
#   5,
#   18,
#   137,
#   62,
#   585,
#   3723,
#   480,
#   62,
#   585,
#   3724,
#   1112,
#   480,
#   3725,
#   804,
#   610,
#   16,
#   3726,
#   741],
#  [261, 135, 1, 2369, 16, 343, 614],
#  [508,
#   2,
#   982,
#   283,
#   18,
#   2370,
#   1092,
#   297,
#   2369,
#   1823,
#   3727,
#   1824,
#   208,
#   892,
#   3728,
#   2371],
#  [60, 1, 57, 60, 1, 201, 48],
#  [2, 3, 3729, 3730, 58, 438],
#  [21, 215, 576, 1825, 191, 742, 335, 30, 1826, 629, 165, 1, 3, 538, 2372],
#  [1,
#   52,
#   631,
#   412,
#   46,
#   13,
#   423,
#   771,
#   2373,
#   1116,
#   9,
#   983,
#   3731,
#   364,
#   344,
#   332,
#   4,
#   3732,
#   9,
#   237],
#  [1, 138, 890, 2374],
#  [2, 1433, 548, 65],
#  [1, 3, 199, 658],
#  [1,
#   470,
#   982,
#   65,
#   32,
#   967,
#   319,
#   34,
#   546,
#   240,
#   75,
#   3733,
#   100,
#   271,
#   168,
#   473,
#   16,
#   28],
#  [60, 1, 17, 50, 156, 138, 610, 1117],
#  [1, 184, 156, 683, 493, 665],
#  [19, 501, 130, 19, 984, 9, 113, 3734, 1472, 317, 1473, 5, 1, 478, 1473],
#  [311,
#   2,
#   218,
#   684,
#   193,
#   35,
#   1416,
#   3735,
#   3736,
#   1474,
#   3737,
#   973,
#   2375,
#   3738,
#   3739],
#  [116, 274, 55, 1, 119, 95, 48],
#  [15, 32, 1118, 212, 112, 3740, 3741, 2, 632, 2, 450, 49],
#  [1, 1827, 985, 1828, 3742],
#  [1, 239, 14, 54, 293, 869, 418, 3743, 293, 3744, 1, 3, 78, 293],
#  [2, 147, 2376, 1067],
#  [311, 2, 343],
#  [4, 2, 101, 25, 1829, 316, 1830, 861, 19],
#  [986, 3745],
#  [1, 71, 2377, 9, 4, 393, 805, 303, 71, 135, 327, 2378],
#  [3746, 1, 150, 299, 5, 10, 523, 20, 37, 37, 20, 228, 29, 3747, 225, 437],
#  [2, 360, 1475],
#  [1, 375, 586],
#  [19, 1, 3, 1119, 451, 1831, 3748, 351, 1476, 33, 361],
#  [1, 251, 34],
#  [139, 3, 1, 346, 3749, 162],
#  [1, 6, 12, 69],
#  [1,
#   204,
#   3750,
#   3751,
#   80,
#   19,
#   771,
#   961,
#   2379,
#   2380,
#   987,
#   1268,
#   126,
#   893,
#   957,
#   2381,
#   2382],
#  [3, 3752, 3753, 23, 1, 1269, 2383, 1832],
#  [21, 1, 166],
#  [1, 105, 2, 1231],
#  [18, 1398, 94, 25, 988, 27, 2384, 539, 2, 155, 550, 107],
#  [139, 355, 331, 551, 1, 207, 266, 603],
#  [130, 22, 41, 3754, 3755, 30, 894, 1, 3, 4, 138],
#  [4, 2, 346, 3756, 3757, 1111, 211, 9, 1100, 3758],
#  [1, 3, 3759, 572, 1120, 1472],
#  [5, 2, 503, 22, 1833, 334, 2385, 633, 989, 1121, 743, 26, 505, 990],
#  [1, 587, 30, 26, 3760, 171, 358, 806, 3761, 538, 2386, 3762, 2387],
#  [1, 443, 90],
#  [1,
#   3,
#   52,
#   64,
#   628,
#   286,
#   167,
#   1122,
#   217,
#   385,
#   1270,
#   62,
#   9,
#   84,
#   14,
#   1834,
#   3763,
#   3764,
#   316],
#  [1, 3, 378, 2388, 97],
#  [18, 1241, 278, 33, 481, 1241, 4, 2, 7, 65, 25, 30, 807, 134, 124, 3765],
#  [78, 1, 226, 247],
#  [1, 114, 52, 185],
#  [1, 634, 107, 202, 3766, 332, 27],
#  [744, 2, 373],
#  [7, 152, 2, 588, 101, 24],
#  [11, 92, 1, 117, 232],
#  [1477, 34, 59, 1, 3, 991, 3767],
#  [3768, 1271, 1478, 100, 1, 36, 8, 12, 314, 3769],
#  [4, 2, 89],
#  [1, 148, 106, 1835],
#  [3770,
#   1123,
#   3771,
#   219,
#   1258,
#   1466,
#   219,
#   28,
#   2389,
#   3772,
#   49,
#   632,
#   84,
#   173,
#   16,
#   151,
#   1124,
#   352],
#  [2, 21, 124, 2390, 3773, 296, 1119, 1836, 3774, 241],
#  [1, 442, 326, 78, 3775, 3776, 895],
#  [482, 1272, 331, 621, 1, 3, 1267, 635, 483, 114, 115, 480, 403, 106],
#  [1,
#   3,
#   53,
#   72,
#   3777,
#   82,
#   797,
#   1234,
#   575,
#   1432,
#   350,
#   1837,
#   178,
#   2391,
#   2392,
#   391,
#   55,
#   66,
#   2393,
#   114,
#   1125],
#  [1265, 246, 519, 1, 7, 177, 281],
#  [4, 552, 685, 3778, 3779, 3780, 289, 2, 120, 12, 3781, 297, 532, 686, 462],
#  [395, 79, 250, 1, 340],
#  [1, 776, 5, 489, 39, 47, 190, 426, 992, 489, 28],
#  [1, 3, 716, 44, 2373, 2394, 3782, 1126, 2395],
#  [1,
#   122,
#   190,
#   165,
#   341,
#   3783,
#   11,
#   13,
#   2396,
#   2397,
#   7,
#   196,
#   228,
#   780,
#   53,
#   103,
#   344,
#   19,
#   1,
#   984],
#  [1, 263, 3784, 896, 893],
#  [298, 2, 148, 412, 3785, 135, 2398, 3786, 2399, 3787, 1838, 3788, 993, 1479],
#  [1, 199, 8, 468, 687],
#  [228, 62, 2400, 24, 636, 2401, 135, 1, 263, 268, 9, 26],
#  [372, 488, 180, 2402, 2403],
#  [3789, 3790, 387, 543, 1, 6, 120],
#  [1127, 2404, 11, 1, 328, 350, 3791],
#  [3792, 26, 10, 1, 58, 348, 252],
#  [11,
#   3793,
#   73,
#   64,
#   59,
#   1,
#   17,
#   13,
#   146,
#   112,
#   404,
#   585,
#   4,
#   688,
#   613,
#   212,
#   1059,
#   24,
#   1480,
#   233,
#   4,
#   308,
#   1,
#   3794],
#  [45, 1, 769, 248, 95, 21, 8, 77],
#  [146, 2, 183, 146, 524, 175, 2405, 146, 128, 61, 2406, 42],
#  [31, 2, 24, 3795, 3796, 2, 636, 334, 636, 53, 24],
#  [88, 2, 348, 1464, 3797],
#  [1, 3, 26, 1839, 100, 169, 403, 448, 577, 9],
#  [4, 7, 136, 1273, 2, 375, 1840],
#  [1, 52, 185, 224],
#  [1128, 142, 309, 2407, 1129, 392, 582, 3798, 3799, 50, 57, 354, 1481, 426],
#  [628, 1, 2263, 188, 31, 10, 994],
#  [1, 185, 353],
#  [4, 2, 234, 745, 1482, 1274, 204, 66],
#  [4, 2, 136, 451],
#  [1, 365, 79],
#  [1213,
#   32,
#   124,
#   1,
#   155,
#   629,
#   166,
#   25,
#   1,
#   867,
#   1841,
#   280,
#   208,
#   3800,
#   83,
#   86,
#   867,
#   420,
#   3801,
#   17,
#   1483],
#  [363, 54, 25, 12, 1275, 1484, 10, 437, 45, 1, 746],
#  [3802,
#   3803,
#   995,
#   3804,
#   213,
#   27,
#   1130,
#   2,
#   7,
#   475,
#   187,
#   620,
#   133,
#   28,
#   2269,
#   3805,
#   3806],
#  [69, 37, 396, 2408, 3807, 76, 2, 108, 1840],
#  [1, 3, 4, 63, 52, 572, 28],
#  [130, 60, 1, 36, 2409, 612, 897, 318, 3808],
#  [4, 2, 12, 52, 69, 4, 67, 247, 103, 620, 956, 267, 654],
#  [1,
#   229,
#   586,
#   154,
#   137,
#   1705,
#   1485,
#   16,
#   3809,
#   464,
#   50,
#   194,
#   3810,
#   14,
#   1276,
#   3811,
#   3812,
#   3813],
#  [1, 522, 474, 3814, 553, 3815, 808, 266],
#  [56, 2, 90, 1836, 554, 2410, 3816],
#  [1, 51, 166, 37, 1, 2411, 1842],
#  [1, 71, 3817],
#  [2412,
#   1,
#   6,
#   883,
#   1486,
#   3818,
#   669,
#   497,
#   3819,
#   1738,
#   1843,
#   546,
#   294,
#   67,
#   2413,
#   381,
#   1487,
#   3820],
#  [1, 290, 159, 467, 41, 21, 809, 7, 1, 3, 1488, 2414],
#  [171,
#   442,
#   474,
#   589,
#   82,
#   316,
#   434,
#   45,
#   1489,
#   1844,
#   1490,
#   1,
#   487,
#   1438,
#   359,
#   2415],
#  [1, 3, 36, 241, 81, 111, 89, 2416],
#  [41, 1, 3, 4, 137],
#  [1, 182, 25, 75, 736, 1845, 161, 1277, 114, 3821, 331, 461],
#  [2, 375, 136, 492, 457, 1131, 63, 1491, 1491, 532, 689],
#  [79, 1, 119, 262],
#  [415, 76, 2, 2417, 3822, 572],
#  [1219, 244, 2, 6, 120, 19, 1846],
#  [370, 1, 450, 810, 961, 6, 42, 28],
#  [508, 2, 886, 175, 149, 146, 24, 349, 1847, 96, 149, 22, 383],
#  [1, 98, 4, 58, 56, 1132, 63, 1278, 811, 111, 1, 84],
#  [7, 33, 466, 42, 2, 985],
#  [509, 356, 1, 3, 4, 98, 3823],
#  [452, 2, 12, 256, 3824, 3825, 165, 341, 2, 17],
#  [216, 453, 864, 4, 2, 996, 449],
#  [4,
#   136,
#   8,
#   85,
#   416,
#   9,
#   156,
#   551,
#   1,
#   207,
#   1848,
#   289,
#   1279,
#   132,
#   5,
#   588,
#   2418,
#   865,
#   888,
#   84],
#  [369, 2, 291],
#  [11, 73, 1849, 1850, 1, 93, 960, 3826, 3827, 525],
#  [468, 448, 1, 333, 812, 3828, 3829, 2419, 997, 294, 30],
#  [2420, 665, 1, 463, 176, 458, 37],
#  [5, 3830, 2, 138, 1851, 384, 130, 1492, 3831, 1493],
#  [76, 396, 2, 236, 237, 463, 688, 850, 78, 3832, 1133, 1069, 998, 2421],
#  [1, 3833, 590, 747, 40, 3, 2422, 2423, 992, 1134, 2424],
#  [1, 169, 500, 70, 129, 131, 898, 9, 245, 22],
#  [355, 26, 245, 45, 94, 10, 555, 1, 454, 197, 17],
#  [20,
#   14,
#   5,
#   622,
#   55,
#   1,
#   240,
#   964,
#   301,
#   254,
#   1251,
#   13,
#   233,
#   405,
#   813,
#   6,
#   24,
#   1852],
#  [1, 637, 1135, 22, 3834, 29, 1135, 22, 35, 1806, 1280],
#  [508, 107, 3835, 319, 143, 492, 2, 7, 157, 3836],
#  [1, 450, 3837, 3838, 1494, 814, 232],
#  [1108,
#   62,
#   28,
#   62,
#   158,
#   16,
#   3839,
#   241,
#   247,
#   510,
#   1,
#   69,
#   236,
#   9,
#   13,
#   5,
#   84,
#   435,
#   259],
#  [4, 468, 493, 6, 318, 332, 9, 378, 951, 2, 6, 120],
#  [1,
#   3,
#   10,
#   325,
#   44,
#   568,
#   811,
#   2425,
#   260,
#   1790,
#   1281,
#   2426,
#   5,
#   42,
#   618,
#   196,
#   724,
#   77],
#  [1, 611, 305, 367],
#  [1, 6, 384],
#  [1495, 2427, 61, 82, 815, 2428, 36, 2310, 7, 1390, 1, 105],
#  [3840, 1282, 899, 24, 59, 1, 57, 14, 168, 605],
#  [2, 373, 107, 8, 27, 638, 865, 9],
#  [276, 2429, 3841, 15, 1250, 2, 6, 348, 2430, 368],
#  [1, 170, 1, 207, 2431, 1496, 191],
#  [4, 2, 12, 108, 2432, 427, 1853, 3842, 3843],
#  [11, 165, 1, 900, 1435, 3844, 3845, 1435],
#  [311, 1, 6, 272, 286, 484, 1238, 47],
#  [15, 1, 179, 3846, 2433],
#  [1, 3, 8, 159, 13, 1854, 24, 242, 7, 3847],
#  [1, 174, 69, 268, 1855, 3848, 580, 1060],
#  [1,
#   3,
#   428,
#   3849,
#   34,
#   743,
#   556,
#   7,
#   526,
#   82,
#   134,
#   25,
#   527,
#   2434,
#   525,
#   3850,
#   73,
#   3851,
#   82,
#   161],
#  [4, 2, 123, 125],
#  [213, 999, 22, 1, 214, 3852, 101, 901, 3853, 3854, 639, 1856, 130],
#  [4, 422, 3855, 24, 10, 282, 14, 44, 2435, 59, 1, 307],
#  [1126, 1, 463, 619, 791],
#  [4,
#   35,
#   2,
#   444,
#   2436,
#   28,
#   254,
#   2437,
#   473,
#   18,
#   2438,
#   2439,
#   3856,
#   1497,
#   3857,
#   535,
#   254,
#   402],
#  [4, 2, 15, 545],
#  [20, 495, 215, 24, 1, 3, 557, 195, 591, 96, 84, 15, 218, 3858, 165, 205, 106],
#  [2, 39, 385, 252, 3859, 2440],
#  [1729, 410, 176, 673, 1, 291, 320, 85],
#  [494, 2, 657],
#  [1, 3, 6, 322, 45, 333, 3860, 77, 5, 816],
#  [1, 109, 161, 605, 2441, 1857, 1479, 21, 30, 902],
#  [4, 2, 231, 145, 87, 817, 1000],
#  [480, 903, 1858, 3861, 903, 2442, 2, 172, 95, 32, 3862, 48, 3, 3863, 1859],
#  [11, 1, 451, 1860, 347, 11, 1, 3, 818],
#  [1, 378, 291, 487, 1283, 481, 2443, 2444],
#  [4, 2, 29, 204, 2445, 502],
#  [4, 415, 2, 6, 690],
#  [276, 233, 36, 9, 13, 18, 2, 360, 25, 283],
#  [18, 222, 29, 331, 1, 3, 4, 123, 737, 361, 154, 16, 339],
#  [1, 3, 3864, 2446, 24, 591],
#  [3865,
#   819,
#   2447,
#   142,
#   370,
#   2448,
#   15,
#   1,
#   3,
#   2449,
#   48,
#   122,
#   19,
#   608,
#   3866,
#   131,
#   2325,
#   91,
#   2450,
#   971,
#   3867],
#  [5, 86, 1, 182],
#  [76, 2, 173, 100, 9, 2451],
#  [3868,
#   3869,
#   952,
#   1263,
#   904,
#   3870,
#   3871,
#   3872,
#   3873,
#   3874,
#   947,
#   3875,
#   3876,
#   2,
#   6,
#   449,
#   323,
#   309],
#  [1, 159, 613],
#  [1, 2452, 54],
#  [1434,
#   661,
#   669,
#   63,
#   901,
#   63,
#   1284,
#   1106,
#   2,
#   1284,
#   148,
#   3877,
#   381,
#   659,
#   3878,
#   3879,
#   3880,
#   1498,
#   36,
#   748,
#   1451,
#   661],
#  [1,
#   39,
#   469,
#   2453,
#   67,
#   50,
#   37,
#   24,
#   3881,
#   116,
#   1122,
#   2454,
#   1136,
#   3882,
#   3883,
#   1861,
#   1001,
#   3884,
#   890,
#   3885,
#   814],
#  [15, 871, 1499, 91, 2, 159],
#  [1, 371, 105],
#  [3886, 1725, 387, 1, 478],
#  [1, 188, 255, 43, 14, 511, 11],
#  [213, 3887, 905, 3888, 1107, 495, 2, 611, 520],
#  [4, 369, 882, 30, 23, 1, 422, 136, 426, 35, 255, 1002, 6, 3889, 528, 1485],
#  [1747, 1, 1500, 173, 62, 614, 62, 1501, 286],
#  [1, 198, 1137, 820, 195, 2455],
#  [5,
#   3,
#   3890,
#   1470,
#   2456,
#   2457,
#   2458,
#   40,
#   6,
#   12,
#   72,
#   37,
#   1452,
#   2459,
#   2457,
#   1003,
#   328,
#   349,
#   1862,
#   2460],
#  [4, 2, 105, 129, 10, 678, 1394, 171, 1502],
#  [429,
#   729,
#   8,
#   1138,
#   2,
#   328,
#   269,
#   66,
#   328,
#   182,
#   42,
#   66,
#   82,
#   207,
#   9,
#   1863,
#   1004,
#   269,
#   26,
#   301,
#   328,
#   1,
#   1503],
#  [1750, 285, 1864, 115, 19, 1, 17, 226, 1504, 183, 109],
#  [11, 3891, 821, 1, 208, 150, 691, 1139, 2461, 55, 3, 3892],
#  [544, 1865, 3893, 134, 822],
#  [1, 376, 307, 1866, 2462, 1867, 3894, 2463, 1471, 2216, 664, 1005],
#  [1, 386, 5],
#  [906,
#   1505,
#   1868,
#   387,
#   48,
#   3,
#   892,
#   821,
#   249,
#   186,
#   458,
#   178,
#   7,
#   36,
#   8,
#   3895,
#   180,
#   1,
#   344,
#   30],
#  [139,
#   1869,
#   151,
#   3896,
#   196,
#   49,
#   355,
#   477,
#   3897,
#   356,
#   437,
#   391,
#   91,
#   1506,
#   1507,
#   1006,
#   66],
#  [261,
#   3898,
#   455,
#   749,
#   3899,
#   3900,
#   3901,
#   750,
#   154,
#   1508,
#   1509,
#   3902,
#   1,
#   174,
#   1007,
#   3903,
#   3904],
#  [1, 148, 574, 196, 9, 13, 3905, 1870, 1008, 1510, 416, 419, 362, 1073, 56],
#  [2464, 3906, 1, 174],
#  [130, 4, 2, 446, 46, 309, 880, 454, 515, 312, 2465, 135],
#  [1, 1871, 228, 1, 121],
#  [2, 58, 24, 4, 56],
#  [1, 2466, 174, 362, 3907, 907, 467, 4, 21, 672, 352, 36, 8, 1140, 277],
#  [1, 31, 430, 1009, 751, 265, 286, 41, 46, 529, 321, 1751, 31],
#  [2, 446, 640, 309, 129, 61, 207, 3908, 310, 203, 3909],
#  [1, 148, 412, 3910, 20, 37, 126, 1141, 2318, 4, 1388, 823, 1285, 244],
#  [1, 558, 71, 672],
#  [1481, 353, 1142, 40, 883, 3911, 3912],
#  [1, 97, 90, 1872, 15, 481, 277],
#  [7, 1873, 1276, 3913, 2, 66, 344],
#  [2, 120, 248, 135],
#  [1, 3, 238, 9, 3914, 737, 45],
#  [1, 558, 214, 752, 19, 1, 1, 29, 368],
#  [1275, 2, 1087, 10, 81, 385],
#  [1,
#   147,
#   238,
#   65,
#   357,
#   196,
#   9,
#   908,
#   10,
#   211,
#   317,
#   753,
#   1847,
#   3915,
#   65,
#   32,
#   376,
#   370,
#   785],
#  [32, 2266, 372, 1863, 1, 231, 69, 394, 400, 874, 1286, 414, 5, 691, 27],
#  [18, 338, 1010, 9, 82, 73, 24, 1, 363],
#  [4, 1425, 715, 47, 67, 1011, 206, 535, 1874, 2467],
#  [674, 92, 61, 2, 150, 537, 1511],
#  [1, 89],
#  [124, 1, 51],
#  [43, 7, 909, 2, 8, 280, 53, 159],
#  [152, 135, 295, 1, 238, 10, 34, 31, 353, 2468],
#  [542,
#   484,
#   357,
#   48,
#   251,
#   44,
#   281,
#   78,
#   3916,
#   3917,
#   74,
#   21,
#   27,
#   250,
#   1143,
#   3918,
#   44,
#   1,
#   285,
#   398],
#  [87, 651, 445, 82, 3919, 2469, 910, 2, 148, 791, 2470, 2471, 3920, 3921, 464],
#  [1, 138],
#  [1,
#   177,
#   1243,
#   11,
#   692,
#   3922,
#   339,
#   804,
#   824,
#   693,
#   211,
#   872,
#   1144,
#   2472,
#   754,
#   248,
#   1004],
#  [43, 261, 2, 89, 2473, 3923, 390, 1287, 3924, 3925, 334, 3926, 3927],
#  [303, 2, 3, 198, 1145, 1012, 1844, 1013, 88, 113, 694],
#  [60, 124, 2, 90, 825, 1014, 60, 1, 29, 90, 93, 2474, 2289, 956, 1868],
#  [2, 177, 30, 21, 306, 82, 1146, 475],
#  [1, 3, 201, 252, 10, 2475, 244, 2475, 244],
#  [5, 339, 72, 181, 9, 442, 1, 911, 1288, 372],
#  [1, 520, 349, 3928, 21, 592, 48, 557, 24, 826],
#  [1, 94, 10, 36, 790, 1731, 474, 260, 9, 636],
#  [130, 327, 261, 455, 1, 101, 1504],
#  [1, 3, 129, 1512, 479],
#  [73, 1875, 2476, 114, 1, 3929, 119, 1456, 332, 68, 1286],
#  [1, 3, 28, 52, 359, 133, 317, 654, 21, 483],
#  [1, 586, 764, 11, 1513, 1129, 568, 89, 229, 212, 1015, 1, 2477, 3930, 525],
#  [1, 367, 1514, 1482],
#  [1, 634, 641, 141],
#  [2478,
#   3931,
#   351,
#   2479,
#   2480,
#   1,
#   338,
#   117,
#   50,
#   264,
#   2479,
#   2480,
#   3932,
#   48,
#   2451,
#   11,
#   107,
#   1016,
#   1289,
#   691,
#   351,
#   8,
#   1853,
#   191,
#   2481,
#   335],
#  [1, 3933, 185, 46, 18, 222, 24, 68, 222, 192, 26],
#  [1017, 3934, 223, 2482, 2483, 2482, 1, 819, 783, 2483, 2484],
#  [23, 2485, 65, 8, 1138, 220, 144, 1, 443, 119, 866, 162],
#  [43,
#   186,
#   106,
#   65,
#   1147,
#   32,
#   211,
#   16,
#   2486,
#   28,
#   8,
#   65,
#   4,
#   3,
#   2487,
#   23,
#   65,
#   31,
#   1230,
#   402,
#   1,
#   184],
#  [171, 9, 400, 7, 2, 7, 503],
#  [7, 1, 367, 7, 1, 3935],
#  [912, 820, 2477, 2488, 1, 382, 635],
#  [1, 548, 1242, 2489, 99, 1107, 192, 2490, 3936, 427, 14, 688],
#  [13,
#   1746,
#   1416,
#   491,
#   556,
#   162,
#   3937,
#   23,
#   10,
#   1,
#   118,
#   260,
#   2491,
#   59,
#   142,
#   1,
#   3,
#   1515,
#   44,
#   434,
#   3938,
#   24,
#   255,
#   1876],
#  [1, 3939, 478, 319, 2492, 3940, 3941],
#  [3942, 2493, 1877, 1, 51, 1018, 313, 19],
#  [1, 170, 149, 3943, 206],
#  [1148, 3944, 3945, 10, 744, 88, 2, 3, 54, 2494, 444, 1516, 17],
#  [1, 3, 1878, 94, 3946, 161, 1290, 1019, 1879],
#  [1, 3, 518, 56],
#  [270,
#   3947,
#   1880,
#   3948,
#   888,
#   1855,
#   717,
#   3949,
#   30,
#   19,
#   3950,
#   913,
#   107,
#   23,
#   1,
#   164],
#  [1, 155, 114, 1020, 755, 361, 180, 1149, 61, 853, 3951, 1512],
#  [31, 1, 174, 34, 6],
#  [130, 1, 121, 69],
#  [5, 555, 1, 97],
#  [1127,
#   1517,
#   3952,
#   3953,
#   193,
#   1518,
#   250,
#   311,
#   41,
#   24,
#   3954,
#   2495,
#   2496,
#   2497,
#   1835,
#   2,
#   176,
#   138,
#   1291],
#  [4, 366, 26, 1, 911],
#  [13, 233, 64, 1292, 1497, 139, 414, 11, 197, 2, 89, 278, 1881],
#  [38,
#   1,
#   147,
#   695,
#   747,
#   456,
#   34,
#   167,
#   453,
#   1150,
#   180,
#   36,
#   482,
#   625,
#   251,
#   456,
#   2246,
#   361],
#  [20,
#   11,
#   2498,
#   1513,
#   84,
#   36,
#   3955,
#   233,
#   8,
#   1138,
#   2499,
#   3956,
#   3957,
#   696,
#   3958,
#   4,
#   2,
#   325],
#  [1, 275, 296, 49, 3959],
#  [178, 317, 64, 186, 219, 72, 1101, 494, 1101, 1, 108, 3960],
#  [22, 271, 1151, 1519, 3961, 2500, 100, 189, 3962, 2458, 794, 914, 91, 2, 199],
#  [1, 108, 93],
#  [1, 3, 2501, 3, 163, 3963, 739],
#  [1293, 160, 495, 88, 2, 123, 1882, 642, 3964, 1520],
#  [1, 3, 4, 308],
#  [23, 16, 1, 458, 23, 333, 1252, 3965, 66],
#  [22, 1, 3966, 254, 88, 8, 418, 183],
#  [1, 384, 1128, 3967, 3968, 786],
#  [1, 2259, 536, 861, 124, 1490, 1521, 1068, 367, 1294, 227],
#  [4, 2, 12, 185, 323],
#  [38, 1, 184],
#  [4, 56, 1811, 2, 58, 536, 915, 3969, 310, 203, 131],
#  [2, 470, 1514, 2502, 100, 9],
#  [1883,
#   1458,
#   190,
#   2478,
#   2503,
#   1458,
#   2,
#   6,
#   183,
#   3970,
#   576,
#   1152,
#   429,
#   1884,
#   827,
#   77],
#  [1, 179, 593, 377, 1088, 53, 165, 947],
#  [4, 2, 6, 69],
#  [1, 3, 314, 85, 305, 1885, 113, 405],
#  [275, 2504, 3971, 14, 154],
#  [50,
#   2,
#   497,
#   247,
#   113,
#   1886,
#   220,
#   142,
#   22,
#   16,
#   1522,
#   330,
#   217,
#   2505,
#   1021,
#   3972,
#   1887,
#   3973,
#   3974,
#   3975,
#   3976,
#   3977,
#   630],
#  [1, 185, 46, 46, 423, 249, 1153, 142, 259],
#  [41, 1, 3, 4, 98],
#  [1, 542, 3978, 271, 2506, 79, 83, 9, 410, 1700, 134, 16, 175, 200, 3979, 540],
#  [543, 1, 52, 69],
#  [32, 812, 2420, 1888, 1523, 1, 1212, 587],
#  [1524, 85, 1, 3, 239, 2507, 3980, 3981, 3982, 1012, 3983, 3984],
#  [1, 69, 790, 1426, 20, 228, 1889, 643],
#  [8, 1890, 2, 123],
#  [35, 1, 72, 3985, 200, 523, 1525, 473, 11, 1778, 26, 1295],
#  [1, 72, 320, 3986],
#  [4, 1, 662],
#  [18, 262, 625, 22, 594, 867, 2508, 18, 1018, 315, 60, 1, 373],
#  [3987,
#   361,
#   3988,
#   3989,
#   3990,
#   1154,
#   3991,
#   1526,
#   73,
#   3992,
#   3993,
#   2,
#   263,
#   412,
#   3994,
#   3995],
#  [2, 136, 35, 90, 1296, 6, 1527, 916, 83, 28, 675, 47],
#  [1, 208, 408, 821, 28, 510, 1891, 86],
#  [1443, 17, 659, 2, 12, 72, 3996, 134, 1528, 1846, 2438, 27],
#  [18, 2, 253, 85, 86, 258, 3997, 220, 85, 17, 100],
#  [19, 1, 12, 105],
#  [1, 272],
#  [2509, 2510, 697, 749, 394, 2, 69, 1529, 268, 104, 148, 6, 3998],
#  [1, 666, 1892, 1530, 416, 24, 213, 1893, 2511, 431, 252, 605, 1857, 780],
#  [80,
#   827,
#   3999,
#   4000,
#   214,
#   59,
#   1,
#   253,
#   1297,
#   4001,
#   397,
#   5,
#   47,
#   49,
#   4002,
#   9,
#   640],
#  [4, 2, 4003, 475, 902, 2512, 2513],
#  [1, 542, 107, 289, 142, 202, 4004],
#  [11, 32, 2, 451, 92, 4005, 4006, 2514, 720, 1894, 2, 237, 18, 55, 422],
#  [309, 132, 2, 4007, 2515, 4008, 321, 1155],
#  [2, 450, 4009, 1298],
#  [4010, 896, 778, 26, 101, 160, 26, 21, 2, 12, 201, 176],
#  [1, 1819, 148, 1895, 293, 2516, 4011, 511, 227],
#  [407, 32, 4012, 2, 746],
#  [4,
#   2,
#   169,
#   2517,
#   1156,
#   4013,
#   49,
#   105,
#   29,
#   36,
#   507,
#   8,
#   206,
#   27,
#   507,
#   100,
#   175,
#   816,
#   505,
#   1531],
#  [41,
#   2304,
#   4014,
#   917,
#   255,
#   777,
#   1,
#   3,
#   558,
#   672,
#   969,
#   4,
#   39,
#   136,
#   1131,
#   83,
#   9,
#   5,
#   35,
#   416,
#   144,
#   133,
#   644],
#  [1, 362, 150, 180, 1299, 4015, 2518, 4016],
#  [22, 858, 2519, 355, 390, 4017, 2, 110],
#  [1, 389, 4018, 2520, 58, 12, 349, 1896, 895],
#  [5,
#   70,
#   4019,
#   1,
#   2521,
#   184,
#   1018,
#   502,
#   550,
#   57,
#   126,
#   1214,
#   828,
#   580,
#   2522,
#   126,
#   4020,
#   79,
#   4021,
#   824,
#   797,
#   595],
#  [4, 19, 2, 12, 438],
#  [88, 1, 7, 172],
#  [2, 449, 30, 1022, 4022, 1104, 596, 1532, 28, 310, 203],
#  [149, 136, 4, 247, 42, 4, 2, 117, 95],
#  [1, 326],
#  [1, 291, 234],
#  [2, 226],
#  [15, 11, 2523, 85, 219, 2, 4023, 174, 4024, 4025, 559],
#  [1, 4026, 117, 4027, 4028, 187, 4029, 2524, 1533, 4030, 2524],
#  [1, 1023, 11, 1250, 192, 200],
#  [1, 3, 138, 2525, 4031, 4032, 829, 879, 1129, 4033, 1300],
#  [1, 3, 4, 237, 4, 2, 147, 96, 20, 11],
#  [209, 2, 184, 54],
#  [19, 275],
#  [87, 2, 123],
#  [1, 4034, 542, 2526, 670],
#  [1, 117, 1024, 244, 663, 4035],
#  [597, 1, 90, 280, 100, 190, 4036, 14, 16, 9, 34, 53, 337, 49, 94, 1774, 2527],
#  [803, 544, 2528, 1831, 1301, 2, 336, 415, 468, 92],
#  [1, 105, 4, 1063],
#  [4037, 84, 1, 4038, 3, 4039],
#  [1, 123, 62, 9, 2529, 829, 882, 1860, 808, 4, 73, 115, 133, 127, 1534],
#  [2, 78, 177, 462, 4040, 21, 865, 158, 1897, 1898],
#  [1, 118, 34, 10, 1899],
#  [1, 66, 34, 163, 156, 34, 1302, 918],
#  [4, 2, 1900, 1901, 12, 112, 179, 919, 252, 4041, 4042, 4043, 4044, 1303],
#  [87, 2, 97, 275],
#  [2, 47, 438, 698, 180, 79, 4045, 387, 1838, 4046, 1403, 6, 775, 787],
#  [35,
#   1,
#   10,
#   2530,
#   536,
#   36,
#   4047,
#   2531,
#   54,
#   1775,
#   320,
#   1123,
#   19,
#   4048,
#   132,
#   2532],
#  [1535, 49, 819, 122, 293, 2533, 432, 1508, 22, 15, 75, 282, 240, 426],
#  [363, 1025, 345, 464, 345, 464, 142, 810, 2, 122, 611, 4049, 10, 27, 85, 41],
#  [38, 2, 1772, 1148, 1284, 148, 1019, 4050, 230, 1304, 4051],
#  [3, 1098, 2534, 660, 4, 2, 169, 93],
#  [18,
#   4052,
#   2535,
#   691,
#   4,
#   2,
#   218,
#   52,
#   256,
#   766,
#   1510,
#   41,
#   4053,
#   1902,
#   1245,
#   161,
#   25,
#   1536],
#  [249,
#   8,
#   186,
#   2,
#   58,
#   104,
#   253,
#   62,
#   9,
#   4054,
#   186,
#   4055,
#   15,
#   1222,
#   241,
#   2536,
#   34,
#   2537],
#  [35, 2, 7, 513, 309, 47, 4056, 4057, 1157, 32, 378, 645],
#  [22, 45, 2, 4058, 1414, 170, 830, 54, 342, 58, 2538],
#  [13, 14, 1903, 410, 4059, 1537, 877, 1, 198],
#  [4, 21, 949, 1, 6, 150],
#  [1, 1904, 210, 138],
#  [4, 177, 23, 1538, 1, 1539, 15, 503],
#  [1, 509, 13, 24, 2539, 21, 483, 248, 4060, 37, 19, 4061, 178, 204, 74],
#  [13, 30, 1, 150],
#  [4, 2, 12, 746, 180, 482, 243],
#  [50, 2, 129, 50, 2, 8, 61, 2540, 1905, 138, 1540, 4062, 1906],
#  [1, 166, 278],
#  [355, 1305, 31, 603, 1147, 551, 1, 89],
#  [60, 1, 3, 269, 185, 756],
#  [1, 3, 396, 138, 1247],
#  [1,
#   3,
#   497,
#   197,
#   396,
#   240,
#   387,
#   23,
#   56,
#   2541,
#   4063,
#   1441,
#   889,
#   237,
#   495,
#   197,
#   1480,
#   2542,
#   158],
#  [908, 32, 4064, 252, 165, 1, 188],
#  [45, 2, 184],
#  [2, 29, 1087, 2543, 528, 26, 3, 1541, 399, 4065, 1158, 93, 162],
#  [270, 661, 74, 48, 33, 8, 692, 24, 4066, 151, 4, 19, 7, 2, 479, 2544],
#  [322, 10, 1, 188, 145, 235, 1124, 10, 43, 23, 65],
#  [125, 2, 231],
#  [11,
#   4067,
#   4068,
#   1264,
#   856,
#   315,
#   1,
#   1062,
#   11,
#   584,
#   4069,
#   1907,
#   2545,
#   1542,
#   11,
#   11,
#   11,
#   36,
#   1396,
#   111,
#   21,
#   4070,
#   4071,
#   687],
#  [48, 89, 2546, 668, 685, 141, 4072, 999],
#  [2, 39, 560],
#  [4, 2, 534, 432, 46],
#  [4, 2, 69, 4, 7, 82, 1543, 2547, 1306],
#  [1796, 85, 4073, 2, 328, 101],
#  [124,
#   1,
#   3,
#   4074,
#   301,
#   4,
#   56,
#   18,
#   55,
#   804,
#   115,
#   215,
#   4075,
#   2548,
#   4076,
#   270,
#   255,
#   3,
#   9],
#  [674, 111, 906, 2, 169],
#  [1, 1307, 4077],
#  [45, 1, 346, 4078, 4079, 4080, 2549, 782, 914],
#  [1, 136, 24, 4081, 1308],
#  [1, 288, 29, 77, 2550, 492, 441],
#  [4082, 422, 639, 4083, 2286, 2, 218, 548],
#  [1, 58, 159],
#  [38, 828, 2551, 324, 63, 1534, 4084, 38, 596, 61, 920, 2, 338, 153],
#  [1, 39, 102, 1026, 2552, 4, 12, 2552, 2553, 73, 7, 196, 73, 33, 16],
#  [2, 6, 109, 552, 286, 1222, 921, 4085, 689, 2554, 2230],
#  [261, 1309, 367, 194, 301, 29, 1, 4086, 602, 460, 4087],
#  [1, 9, 378, 173],
#  [543, 1, 201, 252],
#  [1159, 646, 2, 105, 180, 311, 12, 4088],
#  [8, 113, 4089, 318, 267, 1027, 1908, 596, 61, 424, 4090, 2, 164, 4091, 172],
#  [1, 509, 107, 266],
#  [1,
#   641,
#   1544,
#   4092,
#   1545,
#   1028,
#   1028,
#   17,
#   521,
#   1160,
#   673,
#   659,
#   260,
#   922,
#   2326,
#   211],
#  [4,
#   65,
#   10,
#   81,
#   4093,
#   717,
#   1479,
#   923,
#   1,
#   329,
#   23,
#   718,
#   4094,
#   1909,
#   1910,
#   20,
#   529,
#   2555],
#  [1, 51, 141, 1726, 415, 739, 161, 580, 1310],
#  [1, 506, 4095, 1546, 7, 129, 24, 422],
#  [18, 2556, 4096, 7, 15, 3, 482, 1253, 1, 3, 18, 415, 776, 637, 65, 160],
#  [2, 7, 314, 82, 134, 25],
#  [1, 3, 4, 517, 827, 4097],
#  [245, 25, 1, 72, 160],
#  [1, 78, 365, 30, 792, 4098],
#  [1, 6, 72, 1911, 154, 4, 699, 1700, 126],
#  [992, 246, 515, 4099, 1793, 1, 36, 4100, 485, 554, 4101],
#  [270, 15, 1, 4102, 50, 2323, 2346, 409, 296],
#  [4, 924, 82, 4103, 694, 26, 125, 1, 359, 1291, 167],
#  [1, 3, 140, 64, 2450, 143, 10],
#  [5, 43, 4104, 1138, 49, 488, 20, 37, 426, 538, 1417, 581, 523],
#  [42, 1, 499],
#  [209, 2, 183, 1105, 4105, 141, 625, 1057, 22, 532, 63, 1074, 2214],
#  [7,
#   2,
#   343,
#   2386,
#   283,
#   4106,
#   4107,
#   21,
#   4108,
#   427,
#   106,
#   193,
#   1311,
#   10,
#   269,
#   2557,
#   54,
#   4109,
#   1161,
#   504],
#  [5, 53, 491, 1, 425, 341, 233, 455, 2558, 518, 1912, 925, 518, 121, 316],
#  [1, 560, 2559, 269, 1913, 1914, 5, 10, 504, 1913, 1915, 318, 2378],
#  [1, 3, 913, 14, 173],
#  [1, 109, 777, 720, 279, 43, 831, 331],
#  [1, 2560, 485, 4110, 1248, 2561, 679, 143, 2560],
#  [60, 1, 71, 2562, 62, 158],
#  [4, 171, 869, 306, 1, 119],
#  [247, 1, 12, 150, 1800],
#  [149,
#   146,
#   190,
#   46,
#   63,
#   71,
#   832,
#   4,
#   56,
#   62,
#   4111,
#   5,
#   2,
#   2563,
#   24,
#   4112,
#   128,
#   151,
#   124,
#   1434,
#   43,
#   259,
#   43,
#   4113,
#   53,
#   3],
#  [1, 138, 4114, 1547, 615, 986, 4115, 2564],
#  [139, 205, 604, 4116, 240, 4117, 68, 566, 866, 4118, 10, 1, 285],
#  [1, 150, 414, 14, 925, 44, 132, 5, 518, 254, 4119, 21, 387],
#  [36, 351, 142, 1, 188],
#  [1, 611, 513, 592, 1916, 1259, 1312, 4120, 2565, 4121, 305, 2357],
#  [43,
#   132,
#   2,
#   16,
#   4122,
#   4,
#   558,
#   64,
#   3,
#   129,
#   70,
#   284,
#   129,
#   70,
#   284,
#   92,
#   284,
#   1472,
#   129,
#   70,
#   284,
#   73,
#   2566,
#   3,
#   821],
#  [1, 274, 374, 2, 140, 686, 919, 274, 76, 481],
#  [178, 4123, 2567, 192, 1515, 4124, 434, 113, 1, 321, 113, 1, 3, 561],
#  [1, 119, 254, 4125, 562, 1121],
#  [68, 222, 84, 23, 448, 11, 448, 677, 335, 1, 6, 72, 68, 926, 432],
#  [4126, 4127, 2, 4128, 164, 460, 437],
#  [1,
#   98,
#   64,
#   16,
#   81,
#   14,
#   13,
#   4,
#   774,
#   245,
#   774,
#   1495,
#   4129,
#   9,
#   54,
#   421,
#   774,
#   98],
#  [125, 2, 39, 90, 2568, 4130, 366, 4131, 738, 16],
#  [1, 3, 357, 425, 114, 1029, 55, 30, 639, 116],
#  [18, 4132, 2, 96, 171, 2569, 23, 1, 48, 177, 566, 1162],
#  [1, 119, 4, 306, 1, 2570, 2571, 35, 22, 32, 2274, 212],
#  [4, 7, 96, 613, 873, 11, 106, 171, 4, 809, 364, 2572, 1313, 4133, 1, 207],
#  [374,
#   20,
#   11,
#   59,
#   159,
#   11,
#   107,
#   202,
#   25,
#   1,
#   3,
#   891,
#   257,
#   1548,
#   59,
#   159,
#   59,
#   1018,
#   32],
#  [1, 2473, 2573, 146, 188],
#  [1, 201, 37, 268],
#  [1, 465, 235, 129, 32, 191, 175, 659, 4134, 884, 2574, 910],
#  [1, 302, 4135],
#  [506,
#   482,
#   625,
#   745,
#   17,
#   42,
#   1549,
#   220,
#   77,
#   127,
#   568,
#   1917,
#   1,
#   1813,
#   10,
#   8,
#   186],
#  [457, 494, 62, 28, 1163, 2, 2235, 104, 43, 58, 42],
#  [1, 29, 251, 4, 82, 1264, 317, 17, 784, 7],
#  [115,
#   776,
#   1439,
#   2575,
#   2576,
#   4136,
#   4137,
#   2575,
#   727,
#   4138,
#   4139,
#   55,
#   1,
#   58,
#   169],
#  [598, 246, 10, 2, 80, 4140, 153],
#  [20, 5, 1, 4141, 4, 93, 4, 21, 447],
#  [4142, 592, 1525, 2, 548, 1144],
#  [1550,
#   764,
#   399,
#   802,
#   60,
#   1,
#   292,
#   1291,
#   4143,
#   2577,
#   1164,
#   4144,
#   22,
#   1918,
#   135],
#  [1, 446, 645, 146, 3, 202, 2578, 4145, 1155, 45, 1919, 82, 23, 2578],
#  [22, 1, 750, 547, 175, 1920, 279, 33, 4146, 950, 1275, 2, 4147],
#  [5, 368, 426, 1, 1023, 275, 1314, 179],
#  [1821, 1, 413, 94, 1921, 26],
#  [1, 185, 270, 984],
#  [1, 254, 4, 506, 37],
#  [1, 754, 1551, 350, 25, 2579, 4148, 4149],
#  [1552, 364, 83, 357, 448, 1002, 8, 1, 7, 676, 439, 364, 623, 160],
#  [1, 7, 386, 136, 598],
#  [22, 313, 445, 200, 142, 2580, 1, 3, 4150, 444],
#  [519, 2, 1922, 90, 58, 877, 1013, 833, 643, 402, 1923, 4151, 643],
#  [35, 799, 4152, 79, 11, 1, 1924, 5],
#  [87,
#   40,
#   446,
#   160,
#   4153,
#   4154,
#   2581,
#   2582,
#   242,
#   99,
#   4155,
#   9,
#   4,
#   865,
#   2583,
#   1925,
#   1908,
#   4156],
#  [14,
#   8,
#   184,
#   1926,
#   4157,
#   235,
#   127,
#   278,
#   35,
#   127,
#   530,
#   533,
#   228,
#   4158,
#   410,
#   252,
#   1926,
#   1229,
#   2,
#   184],
#  [43, 7, 228, 2, 570, 2470, 201, 2584, 16, 14, 20, 8],
#  [1, 542, 4159, 721, 365],
#  [48, 184, 1, 121],
#  [2459,
#   100,
#   196,
#   194,
#   679,
#   583,
#   913,
#   401,
#   24,
#   1,
#   120,
#   209,
#   10,
#   345,
#   4160,
#   1502],
#  [1477, 461, 4, 14, 187, 130, 4, 757, 1, 4, 122, 5],
#  [4161, 1693, 4162, 497, 1893, 975, 2, 631, 4163, 77, 2585, 149, 1750, 227],
#  [1017,
#   16,
#   75,
#   544,
#   2586,
#   8,
#   418,
#   1,
#   557,
#   70,
#   4164,
#   1315,
#   51,
#   12,
#   1316,
#   6,
#   903,
#   314,
#   1553,
#   381,
#   2587,
#   2217],
#  [1, 440],
#  [2, 39, 97, 366, 90, 394],
#  [4, 2, 449, 323],
#  [13, 2, 119, 532, 1493, 401, 134, 2588, 1927, 4165],
#  [87, 144, 441, 430, 2, 101, 93, 248, 850],
#  [1, 3, 36, 23, 670, 4166, 15, 911, 149, 20, 447, 84],
#  [2, 6, 3, 71, 254],
#  [1, 3, 561, 206, 68, 637],
#  [1, 105],
#  [2, 325, 376, 78, 3, 214, 1928, 4, 1302, 31, 9],
#  [700, 21, 92, 61, 2, 6, 184, 58],
#  [271, 61, 2, 164, 3, 1550, 1402, 579, 8, 4167],
#  [354,
#   1929,
#   2,
#   7,
#   499,
#   42,
#   4,
#   27,
#   219,
#   2589,
#   1929,
#   848,
#   456,
#   47,
#   269,
#   282,
#   33,
#   42],
#  [1, 57, 263],
#  [527, 1930, 1931, 49, 897, 2590, 112, 515, 3, 1932],
#  [834, 460, 4168, 1, 947, 236],
#  [1, 12, 373, 2591, 444, 1869, 1235, 347, 4169, 2592, 1163, 4170, 2593, 4171],
#  [2,
#   72,
#   1933,
#   210,
#   422,
#   469,
#   610,
#   454,
#   248,
#   4172,
#   1934,
#   502,
#   358,
#   4173,
#   4174,
#   4175],
#  [4, 35, 2, 470, 107, 161, 21, 77, 141, 28],
#  [1, 148, 79, 4176, 2594, 106, 1935, 351, 1936, 4177],
#  [415, 4178, 1317, 2, 57, 1937, 19, 366, 733],
#  [13, 2, 164, 26],
#  [1, 288, 32, 81, 42, 401, 462, 32, 271],
#  [133, 232, 2595, 4179, 1, 117, 1524, 1300],
#  [8, 6, 4180, 4181, 1, 231, 293],
#  [4, 2, 300, 46],
#  [13, 154, 4, 4182, 695, 4183, 4184, 669, 78, 1, 835, 900, 1895, 43, 14],
#  [5, 212, 4, 247, 1, 300, 1472, 55],
#  [1, 54, 4185, 108, 4, 19, 1131, 554],
#  [8, 148, 5, 25, 178, 2, 239, 145, 2596, 1080, 327, 4186],
#  [75, 4187, 4188, 7, 212, 633, 2, 259, 8, 211, 2597, 1318, 89, 4189],
#  [127, 55, 4190, 1, 321],
#  [4, 2, 182, 674, 2598, 265, 775, 29, 555],
#  [4, 4191, 4192, 701, 5, 752, 4, 2, 4193, 120],
#  [1554, 1, 3, 658, 20, 8, 163],
#  [180, 1, 14, 147],
#  [130, 857, 44, 10, 529, 1, 223, 851, 162, 83, 9],
#  [2, 970, 21, 726],
#  [15, 1, 1555, 389, 4194, 1292, 4195, 4196, 244],
#  [4, 76, 46, 2, 69, 255, 574],
#  [1165, 2599, 2600],
#  [1, 3, 123, 1145, 772, 566, 24, 4197, 4198],
#  [311, 38, 1, 120, 507, 1938, 4, 456],
#  [5, 1556, 28, 28, 4199, 2601, 4200, 114, 219, 2, 104, 1939, 91, 332],
#  [38,
#   5,
#   2,
#   459,
#   96,
#   630,
#   459,
#   466,
#   4201,
#   1513,
#   1940,
#   2602,
#   1082,
#   2602,
#   459,
#   2,
#   764,
#   3,
#   4202,
#   910,
#   2603,
#   4,
#   128],
#  [923, 1941, 213, 4203, 430, 2, 348, 252],
#  [2, 58, 548],
#  [1,
#   54,
#   237,
#   1557,
#   523,
#   300,
#   4204,
#   1558,
#   4205,
#   372,
#   1211,
#   4206,
#   4207,
#   435,
#   1942,
#   64],
#  [96,
#   24,
#   267,
#   436,
#   3,
#   383,
#   663,
#   2604,
#   114,
#   96,
#   171,
#   4,
#   2,
#   333,
#   559,
#   4208,
#   1559,
#   1166],
#  [13, 4, 364, 2, 90],
#  [4209, 1, 119],
#  [38, 1925, 267, 1880, 4210, 266, 351, 4211, 4212, 1, 273, 4213, 2605],
#  [1, 599, 126, 277],
#  [8, 264, 2, 3, 1030, 439, 405, 1943, 419, 4214, 314, 17],
#  [1, 618, 51, 1555],
#  [8, 2, 4215, 730, 105, 80, 94, 489],
#  [15, 4216, 1560, 49, 14, 16, 80, 188, 15, 1944, 33, 23, 127],
#  [5,
#   4217,
#   824,
#   35,
#   5,
#   92,
#   975,
#   693,
#   99,
#   573,
#   192,
#   26,
#   1,
#   110,
#   2606,
#   1,
#   1694,
#   44,
#   4218,
#   2607,
#   297,
#   1082,
#   1945,
#   727],
#  [8, 69, 2, 1, 4219, 402, 2280, 418, 74, 125, 36, 1839],
#  [2366, 2, 433, 4220, 1296, 260],
#  [213, 37, 4221, 215, 781, 2608, 76, 2, 465, 475],
#  [1, 117, 266, 306, 3, 91, 656, 44, 4222, 2609],
#  [1, 1433, 218, 783, 452, 2610, 654, 1, 133, 28, 966],
#  [1, 117, 202, 872, 1, 4223, 229, 899, 113, 1420],
#  [1, 110, 75, 282, 151, 63, 11],
#  [4, 2, 6, 12, 120, 2611, 134, 4224, 4225],
#  [189, 156, 561, 1946, 1, 6, 12, 671],
#  [43, 45, 1, 1854, 21, 219, 128],
#  [37, 25, 15, 68, 222, 396, 4226, 1, 106, 193, 15, 173],
#  [228, 4227, 379, 59, 745, 10, 1, 174, 89],
#  [374, 45, 1, 164, 331, 2612],
#  [129, 2613, 1, 359, 64, 2546],
#  [4, 2, 112, 292, 2614, 4228, 2615],
#  [22, 14, 1, 71, 731, 1319, 4229, 4230, 1031, 1109, 836, 432, 1319],
#  [7, 11, 96, 19, 1, 3, 18, 485, 28],
#  [1, 103, 444, 417, 1828],
#  [1, 56, 134, 4231, 92, 1227, 1100, 4232],
#  [4, 2, 2616, 109],
#  [20, 7, 2519, 794, 989, 84, 301, 1, 3, 208, 296],
#  [1, 3, 122, 1092, 4233, 2617, 15, 1511, 156, 341],
#  [152, 619, 1, 117, 4234, 947],
#  [2, 475, 29, 555, 191, 445, 240, 92, 85],
#  [1, 3, 295, 440, 702],
#  [11, 129, 1, 182, 36, 1077, 431, 252],
#  [5, 116, 15, 8, 362, 191, 175, 397, 2, 39, 446, 180, 129, 362, 4235, 30],
#  [1320, 4, 2, 157],
#  [4, 2, 51, 802, 645, 466, 1488, 2618],
#  [4236, 369, 951, 1302, 864, 519, 4237, 1947, 2, 371, 97],
#  [4, 2, 51, 2619, 4238, 888],
#  [1, 10, 617, 1032, 1766, 696, 617, 503, 20, 724, 1766, 83, 160],
#  [1, 112, 169, 4239, 2620, 158],
#  [1, 1, 117],
#  [1, 3, 4240, 35, 108, 2621, 26, 42],
#  [4241, 923, 796, 232, 80, 1, 52, 174, 1948, 345],
#  [60, 1, 29, 233, 2622, 97, 60, 5, 21, 299, 15, 875, 409, 7, 277],
#  [1, 78, 118, 96, 4242, 679, 4243],
#  [1,
#   239,
#   2623,
#   1561,
#   4,
#   1092,
#   361,
#   1167,
#   294,
#   281,
#   38,
#   41,
#   4,
#   1092,
#   111,
#   1858,
#   63,
#   4244],
#  [779, 107, 1033, 149],
#  [1, 90, 21, 27, 1783, 332, 1283, 2624, 3],
#  [5,
#   18,
#   857,
#   5,
#   2625,
#   857,
#   74,
#   436,
#   4245,
#   3,
#   79,
#   1,
#   3,
#   8,
#   375,
#   105,
#   361,
#   514,
#   7,
#   196,
#   717,
#   627],
#  [5,
#   4246,
#   13,
#   439,
#   2626,
#   4247,
#   241,
#   334,
#   1248,
#   1494,
#   972,
#   4248,
#   1452,
#   3,
#   241,
#   1235,
#   1,
#   102],
#  [1, 102],
#  [1, 18, 1261, 118, 99, 335, 26, 195, 134],
#  [11, 1562, 1034, 4249, 419, 953, 1, 98, 9],
#  [87, 2, 12, 172, 7, 1949, 279],
#  [1, 70, 204, 1563, 381],
#  [1, 119, 876, 214, 113, 1321, 77, 167, 52, 563, 4250, 156, 341],
#  [1, 3, 123, 4251, 727, 2627, 857, 165, 17],
#  [1, 96, 305, 296, 14, 54, 58, 12, 2, 824],
#  [1, 499, 1277, 4, 2628, 1564, 30, 248],
#  [1,
#   3,
#   4252,
#   4253,
#   4254,
#   161,
#   227,
#   4255,
#   636,
#   921,
#   84,
#   161,
#   17,
#   14,
#   435,
#   1565,
#   10,
#   34],
#  [1, 225, 74, 53, 59, 251, 242],
#  [1, 3, 572, 44, 730],
#  [1, 36, 1950, 444, 4256, 4257, 132, 647, 568],
#  [295, 482, 927, 4258, 49, 1161, 170, 1805, 830, 505, 35, 1951, 235, 127, 214],
#  [189, 411, 1, 272, 976, 41, 4259, 1952, 68, 130, 1952, 559],
#  [442, 1, 214, 716, 4260, 278],
#  [1, 13, 425],
#  [217, 4261, 15, 1125, 181, 2, 520, 181, 30, 2629, 1533],
#  [149,
#   139,
#   4262,
#   4263,
#   4264,
#   497,
#   2,
#   272,
#   506,
#   66,
#   957,
#   233,
#   16,
#   28,
#   24,
#   1409,
#   806],
#  [1, 155, 393, 4265, 734, 9, 2630],
#  [1035,
#   693,
#   582,
#   4266,
#   1234,
#   71,
#   1419,
#   2631,
#   294,
#   1262,
#   1,
#   3,
#   98,
#   4267,
#   556,
#   195,
#   73,
#   678,
#   728,
#   664,
#   71],
#  [1, 90, 69, 20, 5],
#  [1, 72, 1420, 151, 1160, 151, 4268, 8, 136, 1953, 4269, 280],
#  [20,
#   13,
#   15,
#   2429,
#   193,
#   849,
#   1765,
#   207,
#   50,
#   211,
#   4270,
#   1142,
#   1954,
#   10,
#   643,
#   4271,
#   340,
#   2632,
#   260,
#   4272,
#   1,
#   3,
#   50,
#   24,
#   359,
#   193],
#  [1022, 4273, 2, 187, 329, 4274, 4275, 1955],
#  [50, 2, 64, 219, 137],
#  [2, 256, 1415],
#  [107, 1884, 768, 717, 1566, 47, 1322, 1268, 1323, 91, 2, 147, 4276],
#  [4, 2, 251, 837],
#  [4, 2, 118, 784, 656, 4, 56],
#  [1, 1292, 14, 1324, 1, 2633, 4277, 965, 33, 44, 106, 1168, 1168],
#  [5, 70, 10, 2632, 83, 4278, 43, 617, 1891, 362, 5, 1, 838, 310, 203, 4279],
#  [1, 102, 40, 3, 593, 377, 2634, 66, 4280, 297, 829, 782, 81, 27, 928],
#  [5, 36, 186, 2, 164, 115, 1956, 390, 4281, 1169, 222],
#  [2, 446, 758, 232, 3, 23, 56, 75, 1957, 1325, 929, 20, 1, 36, 2635, 4282],
#  [276, 1150, 1, 121, 2408, 10, 59, 1, 1170, 1261],
#  [1, 3, 153, 668],
#  [4, 1151, 1, 102, 4283, 85, 91, 1894, 259],
#  [2, 2315, 360, 805, 596, 211, 4284, 160],
#  [1, 599, 4285, 317, 176, 235, 1845, 214],
#  ...]

# %%
vocab_size
# Out:
# 35000

# %%
from keras.preprocessing.sequence import pad_sequences
# now padding to have a maximum length of 64
pad_rev= pad_sequences(encd_rev, maxlen=max_sen_len, padding='post')
pad_rev.shape   # note that we had 4749 data and we have padded each review to have  a lenght of 64 words.
# Out:
# (4749, 64)

# %%
pad_rev
# Out:
# array([[ 566,   10,  281, ...,    0,    0,    0],
#        [  18,  178, 2211, ...,    0,    0,    0],
#        [  31,  603,    1, ...,    0,    0,    0],
#        ...,
#        [ 693,  640,  151, ...,    0,    0,    0],
#        [   1,    3, 7767, ...,    0,    0,    0],
#        [  18,    2,  198, ...,    0,    0,    0]], dtype=int32)

# %% [markdown]
# **Classification**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.initializers import Constant
from tensorflow.keras.layers import Dense, Embedding, Activation, Flatten

# %%
model = keras.Sequential()
model.add(Embedding(input_dim=vocab_size,output_dim=embed_dim,input_length=max_sen_len,embeddings_initializer=Constant(embed_matrix)))
model.add(layers.LSTM(64, input_shape=(None, 28)))
model.add(layers.BatchNormalization())
model.add(layers.Dense(3))
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = keras.Sequential()
#       2 model.add(Embedding(input_dim=vocab_size,output_dim=embed_dim,input_length=max_sen_len,embeddings_initializer=Constant(embed_matrix)))
#       3 model.add(layers.LSTM(64, input_shape=(None, 28)))
#
# NameError: name 'keras' is not defined

# %%
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer="sgd",
    metrics=["accuracy"],
)

# %%
model.fit(pad_rev, y_train, batch_size=2, epochs=2)
# Out:
# Epoch 1/2
# 2375/2375 [==============================] - 89s 36ms/step - loss: 1.1019 - accuracy: 0.3325
# Epoch 2/2
# 2375/2375 [==============================] - 116s 49ms/step - loss: 1.1009 - accuracy: 0.3293

# %%
4749/2
# Out:
# 2374.5

# %% [markdown]
# **Testing**

# %% [markdown]
# **Preparing  Test Data for Embedding Layer**

# %%
# Tokenize the words in the testing text data
word_token_test =[word_tokenize(i) for i in x_test]

# %%
word_token_test[0]
# Out:
# ['i',
#  'sometimes',
#  'feel',
#  'shy',
#  'about',
#  'my',
#  'musical',
#  'taste',
#  'because',
#  'some',
#  'of',
#  'it',
#  'wanders',
#  'towards',
#  'what',
#  'some',
#  'might',
#  'call',
#  'techno',
#  'slander']

# %%
# Remove stopwords from each sublist in word_token_test
filtered_tokens_test = [[word for word in sublist if word not in stop_words] for sublist in word_token_test]
# Display the first sublist of filtered tokens after removing stopwords
print(filtered_tokens_test[0])
# Out:
# ['sometimes', 'feel', 'shy', 'musical', 'taste', 'wanders', 'towards', 'might', 'call', 'techno', 'slander']

# %%
tok.fit_on_texts(filtered_tokens_test)
encd_rev_test = tok.texts_to_sequences(filtered_tokens_test)

# %%
encd_rev_test
# Out:
# [[75, 1, 191, 2594, 1372, 7846, 229, 141, 289, 7847, 7848],
#  [7849,
#   3383,
#   781,
#   205,
#   594,
#   7850,
#   1394,
#   90,
#   68,
#   8,
#   94,
#   1680,
#   26,
#   1100,
#   7851,
#   140,
#   299,
#   1717,
#   2008,
#   41,
#   5,
#   593],
#  [58, 1, 3, 1383, 266, 425, 150, 1175, 15, 2086, 3810],
#  [2, 227, 659, 505, 91, 7852],
#  [333, 2, 548, 336, 2548, 7853, 89, 2373, 7854, 2558, 7855, 3828, 1, 296],
#  [6, 2545, 7856, 105, 8, 1, 192, 279, 2463, 419, 626],
#  [893, 1655, 1, 607, 367, 434, 7857, 585, 7858, 1655],
#  [311, 1, 714],
#  [1, 37, 38, 1191, 54, 141, 882, 1, 217, 1488, 706, 49, 477, 835],
#  [573, 2, 5, 511, 44, 884],
#  [18, 2, 157, 108, 7859, 1802, 18, 1608, 33],
#  [1, 1059, 1644, 283, 179],
#  [1, 631, 353, 883, 214],
#  [1, 134],
#  [393, 1256, 273, 70, 2, 60, 104],
#  [7860, 7861, 221, 25, 63, 1648, 1346, 7862, 53, 71, 1798, 1648, 1, 153],
#  [1, 13, 210, 141, 2, 132, 1789, 27],
#  [4, 432, 7863, 7864, 1, 4, 7865, 23, 303, 40],
#  [1, 1015, 507, 1837, 681],
#  [2, 520, 832],
#  [4, 64, 1162, 2, 108],
#  [2,
#   293,
#   108,
#   172,
#   7866,
#   47,
#   1,
#   1367,
#   2229,
#   193,
#   1695,
#   1393,
#   1113,
#   188,
#   190,
#   700,
#   1041,
#   22,
#   465],
#  [7867, 3803, 2786, 863, 2637, 302, 1370, 2367, 24, 1, 60, 86, 2434],
#  [244, 122, 1, 3, 331, 7868, 377, 580, 346, 50, 1903, 744, 3829, 511, 1983],
#  [4, 2, 201, 229, 188],
#  [55, 1, 95],
#  [163, 49, 916],
#  [608, 1, 173],
#  [75, 1, 3, 438, 7869],
#  [14, 29, 1, 3, 18, 554, 64, 8, 374, 32, 7870, 106, 4, 20, 4],
#  [1,
#   3,
#   248,
#   2485,
#   550,
#   777,
#   3728,
#   1744,
#   1806,
#   848,
#   77,
#   1103,
#   1409,
#   2616,
#   54,
#   590],
#  [4, 63, 1, 121, 1290, 83, 197, 323, 3740, 164, 190, 187, 2952, 185],
#  [70,
#   2,
#   60,
#   173,
#   127,
#   84,
#   1941,
#   7871,
#   1979,
#   2578,
#   110,
#   1197,
#   1822,
#   2054,
#   141,
#   2521,
#   2587,
#   527],
#  [540, 7872, 1942, 135, 1056, 638, 509, 141, 16, 2974],
#  [58,
#   7873,
#   1585,
#   3103,
#   996,
#   38,
#   1,
#   366,
#   339,
#   25,
#   267,
#   576,
#   842,
#   3625,
#   168,
#   81,
#   7874],
#  [2563, 348, 7875, 2, 7876, 111, 2468, 674],
#  [1, 1937, 336, 109, 94, 35, 7877],
#  [334, 1, 104, 77],
#  [79, 2, 314, 765, 28],
#  [6, 1, 125, 1012, 695, 41, 3, 3811, 422, 2111, 7878, 849],
#  [1,
#   134,
#   8,
#   102,
#   1581,
#   85,
#   312,
#   2,
#   658,
#   8,
#   82,
#   56,
#   132,
#   2404,
#   312,
#   43,
#   1052,
#   1162],
#  [55, 15, 8, 1, 184, 946, 7879, 1013, 203, 292, 209, 7880],
#  [14,
#   805,
#   2408,
#   7881,
#   7882,
#   466,
#   15,
#   3410,
#   3795,
#   21,
#   565,
#   35,
#   913,
#   9,
#   1063,
#   432,
#   190,
#   1783,
#   2,
#   181,
#   728],
#  [239, 2, 72],
#  [43, 47, 1, 285, 127, 84],
#  [1398, 1, 22, 125],
#  [93, 1, 316, 198, 1036, 76],
#  [1, 1154, 157, 9, 3087, 43, 1393, 347, 15, 1064],
#  [1, 628, 562, 1106, 58, 193, 2802],
#  [1, 3, 11, 14, 4, 120, 7883, 56, 257],
#  [119, 4, 2, 5, 223],
#  [1, 5, 46, 210],
#  [33, 446, 228, 3192, 216, 15, 1, 59],
#  [1, 7884, 128],
#  [1, 153, 122, 236, 1126, 122, 334, 2381, 1126, 121],
#  [1, 150, 4, 719, 2174],
#  [7885, 57, 496, 23, 1, 52],
#  [7, 244, 1, 157, 476],
#  [1, 260, 1119, 7886],
#  [1, 3, 953, 39, 212],
#  [383, 755, 127, 166, 2, 445, 309],
#  [138, 267, 30, 1404, 148, 756, 7887, 399, 319, 41, 316, 77, 1628],
#  [1, 69, 7888],
#  [278, 24, 47, 89, 306, 3117, 1254, 247, 2, 314, 449, 2577, 214, 264],
#  [4,
#   65,
#   1482,
#   4,
#   2,
#   208,
#   88,
#   572,
#   3289,
#   7889,
#   284,
#   1438,
#   3021,
#   379,
#   1559,
#   3732,
#   410,
#   67,
#   7890],
#  [3, 496, 105, 995, 8, 2, 176],
#  [14, 2, 2237, 86, 2592, 98, 422, 88],
#  [1, 429, 387, 1888, 26, 33, 109],
#  [4,
#   2,
#   39,
#   144,
#   90,
#   1081,
#   1959,
#   1889,
#   3830,
#   786,
#   45,
#   3,
#   21,
#   899,
#   3,
#   545,
#   7891,
#   21],
#  [1, 60, 115],
#  [4,
#   63,
#   341,
#   90,
#   7892,
#   577,
#   2389,
#   3025,
#   7893,
#   1645,
#   571,
#   216,
#   110,
#   2,
#   298,
#   1142,
#   1465,
#   1,
#   6,
#   290,
#   112],
#  [7894,
#   289,
#   307,
#   160,
#   1354,
#   616,
#   1954,
#   1496,
#   3375,
#   49,
#   1221,
#   796,
#   244,
#   7895,
#   112,
#   1229,
#   422,
#   1747,
#   558,
#   529,
#   30,
#   1943,
#   2203],
#  [1, 574, 150, 44],
#  [4, 316, 7896, 3042, 1354, 2, 5, 249],
#  [1, 3, 55, 6, 261, 7897, 142, 15, 563],
#  [14, 7898, 435, 7899, 635, 180, 2732, 7900, 1672, 1, 52],
#  [767, 1576, 7901, 1, 548, 65, 4],
#  [31, 686, 1, 226, 237, 16],
#  [68, 97, 22, 19, 536, 288, 92, 1, 52],
#  [1, 59, 1886, 767, 1541, 934],
#  [1, 3, 128, 662, 7902, 7903, 3546],
#  [7904, 341, 1, 7905, 79, 2, 83, 177, 218, 1814, 82],
#  [24,
#   1631,
#   29,
#   1,
#   3,
#   50,
#   128,
#   495,
#   2454,
#   7906,
#   689,
#   34,
#   1428,
#   189,
#   689,
#   50,
#   1444],
#  [626, 16, 3822, 1748, 7907, 682, 2, 7908, 2539, 87, 38],
#  [20,
#   819,
#   909,
#   188,
#   2021,
#   7909,
#   1061,
#   58,
#   30,
#   86,
#   2967,
#   2173,
#   2278,
#   1334,
#   2,
#   147,
#   59,
#   2012],
#  [1, 3, 99, 1027, 160],
#  [167, 22, 1, 216, 2, 6, 195, 1402, 437, 111],
#  [3513, 789, 2, 72, 280, 40, 45, 454, 196],
#  [295, 397, 1159, 225, 2, 250, 1968],
#  [1, 217, 43, 3290, 991, 238, 203, 237],
#  [1, 3, 7910, 2244, 586, 7911, 87],
#  [2545, 753, 822, 2, 120, 260, 3831, 444, 8, 85],
#  [2, 133, 446, 553, 3072, 545, 1258, 983, 7912],
#  [1, 249, 75, 1, 322, 188, 595, 8, 7913, 193],
#  [4, 242, 14, 101, 33, 195, 282, 1100, 529, 563, 219, 12, 1397, 2, 179],
#  [37, 24, 1, 54, 123, 140, 30],
#  [138, 3, 46, 78, 42, 6, 1, 46, 78, 1698],
#  [7, 1, 7914, 181, 1527, 7915],
#  [1, 3, 488, 417, 1905, 10],
#  [70,
#   1821,
#   2,
#   6,
#   3643,
#   1407,
#   3785,
#   7916,
#   35,
#   331,
#   359,
#   280,
#   1682,
#   648,
#   1264,
#   1100,
#   1528,
#   2400],
#  [1, 57, 52, 21, 7917, 2, 1070, 20, 79, 1018],
#  [1316,
#   1397,
#   1,
#   85,
#   121,
#   285,
#   837,
#   2358,
#   244,
#   3776,
#   3193,
#   7918,
#   48,
#   7919,
#   7920,
#   7921,
#   2358,
#   1345],
#  [1, 191, 11, 348, 203, 2513, 1973, 12, 37, 351, 26, 931],
#  [1, 330, 7922, 3789, 51, 211, 67, 494, 565, 464, 83, 7923, 76, 7924, 200, 3],
#  [1, 428, 1, 3, 841, 21],
#  [1, 3, 3417, 321, 208, 6, 33],
#  [1, 24, 367, 1522, 3588, 129, 3169, 499, 286, 7925],
#  [113, 1, 248, 142, 7926],
#  [12, 1, 175, 2, 192, 115, 3717],
#  [4, 2, 1423, 232, 136, 1078],
#  [57, 1483, 947, 707, 57, 671, 670, 2537, 2, 712],
#  [599,
#   14,
#   643,
#   7927,
#   7928,
#   7929,
#   7930,
#   935,
#   599,
#   1,
#   13,
#   130,
#   80,
#   2378,
#   98,
#   673],
#  [9,
#   213,
#   863,
#   2,
#   251,
#   69,
#   257,
#   7931,
#   3,
#   2,
#   9,
#   34,
#   1497,
#   925,
#   2202,
#   283,
#   16,
#   166,
#   590,
#   7932,
#   70,
#   225],
#  [1,
#   366,
#   7933,
#   7934,
#   278,
#   7935,
#   243,
#   7936,
#   3622,
#   909,
#   525,
#   7937,
#   2349,
#   3832,
#   262,
#   7938,
#   739,
#   1414,
#   932,
#   7939,
#   932,
#   1244,
#   170,
#   7940,
#   3833,
#   7941,
#   7942,
#   7943,
#   2583,
#   2583,
#   2615,
#   1244,
#   1108],
#  [246, 2, 342, 201, 1156, 280, 712, 28],
#  [2, 74, 1290, 382, 3145],
#  [291, 7944, 17, 1, 111, 1868],
#  [870, 62, 93, 1, 2453, 3744, 666, 251, 7945, 57, 52],
#  [6, 110, 898, 2, 7946, 162, 1192],
#  [1, 3, 24, 692, 133, 230],
#  [1, 179, 897, 2055, 451, 458, 119, 1407],
#  [43, 395, 22, 190, 90, 7947, 7948, 49, 56, 100, 7949],
#  [24, 3380, 1242, 1887, 58, 1074, 266, 91, 219, 1, 264, 18, 1505],
#  [199, 1, 128, 2226, 10, 27],
#  [24, 1, 315, 287, 2836, 7950, 390, 7951, 139, 169],
#  [4, 2, 5, 2334, 191],
#  [391, 1, 64, 3827, 373, 98, 166],
#  [1, 128, 7952, 2417, 7953, 2533, 7954],
#  [414, 14, 820, 1409, 25, 1, 694, 18, 134, 1623, 729, 7955, 4, 792],
#  [1, 108, 176],
#  [1, 95],
#  [601, 1356, 1714, 672, 49, 257, 903, 7956, 62, 593, 8],
#  [1, 732, 229, 11, 75, 19, 97, 56, 10, 279],
#  [7, 1107, 350, 570, 3548, 1974, 727, 2, 352, 896, 7957, 11],
#  [1194,
#   7958,
#   97,
#   7959,
#   7960,
#   7961,
#   36,
#   1431,
#   463,
#   7962,
#   7963,
#   7964,
#   1973,
#   7965,
#   969,
#   2590,
#   7966,
#   2019,
#   7967,
#   755,
#   1233,
#   784],
#  [902, 374, 84, 931, 3, 3823, 1135, 704, 7968, 256, 2, 490, 44],
#  [230, 396, 183, 1, 625, 42, 501, 120, 42, 501, 86],
#  [243, 41, 152],
#  [14, 1931, 721, 1, 330],
#  [2, 460, 416, 26, 552, 11, 188, 195],
#  [1, 13, 111, 51],
#  [1, 171, 1697, 3814],
#  [10, 885, 62, 2, 36, 1375, 3497],
#  [1, 59, 296, 2465, 7969],
#  [163, 2, 134, 8],
#  [1, 487, 1936, 675, 1798, 607, 7970],
#  [1, 145, 446, 2050, 1585, 7971],
#  [1, 8, 16, 981, 557, 2595, 7972, 2498, 7973, 325, 3156],
#  [2, 223, 113, 190, 377, 599, 36, 139, 113],
#  [1621, 666, 1621, 29, 17, 1083, 2372, 221, 1, 77, 7974, 54, 21, 208],
#  [67,
#   110,
#   12,
#   1,
#   125,
#   126,
#   7975,
#   379,
#   7976,
#   452,
#   60,
#   13,
#   8,
#   411,
#   55,
#   1,
#   27,
#   85],
#  [1, 99, 200, 3834, 3757, 165, 20, 925, 884, 1377],
#  [4, 2, 118, 436, 380],
#  [322, 240, 2, 416, 698],
#  [79, 28, 616, 7977, 7978, 563, 1350, 2, 291, 65],
#  [1, 157, 1005, 11, 91],
#  [63,
#   7979,
#   358,
#   362,
#   568,
#   1539,
#   7980,
#   701,
#   1275,
#   136,
#   2,
#   1569,
#   2982,
#   3835,
#   7981,
#   1944],
#  [2, 83, 146, 126, 3836],
#  [70, 160, 2, 74, 571, 3088, 311, 257, 288, 116, 7982, 27, 8, 1075, 20, 29],
#  [1, 695, 629],
#  [1, 128, 7983, 759, 12, 10, 160, 7984, 243, 137, 141, 65],
#  [1, 614, 1199, 590, 7985, 3, 2589, 610, 763, 1328, 2262, 3755, 7986, 2979],
#  [1, 132],
#  [2, 13, 223, 44],
#  [17, 131, 1535, 15, 2, 100, 7987, 750, 8],
#  [4, 2, 46, 143],
#  [1, 227, 541, 3634, 789, 1002, 533, 148, 47, 505],
#  [1, 1584, 225],
#  [2, 223, 158, 573],
#  [1, 3, 4, 922, 418, 128, 1793, 31, 27],
#  [1, 142, 143, 44],
#  [1, 3, 8, 168, 557, 1403, 157, 664, 1217, 23, 15, 6, 131],
#  [1, 3, 319, 1119, 151, 26, 3837],
#  [9, 2, 983, 57, 134],
#  [75, 1, 3, 4, 69, 73],
#  [4, 2, 107],
#  [112,
#   7988,
#   1,
#   351,
#   8,
#   1226,
#   434,
#   7989,
#   12,
#   369,
#   778,
#   3318,
#   126,
#   40,
#   88,
#   3207,
#   479,
#   1421],
#  [4, 275, 643, 174, 26, 1, 232, 68, 1048, 7990, 3838, 355, 976, 299],
#  [1, 72, 169, 874, 1, 118, 3, 2174, 7991, 335, 3839],
#  [3252, 1593, 1015, 7992, 1, 69, 44, 2648, 7993],
#  [3840,
#   7994,
#   7995,
#   7996,
#   7997,
#   14,
#   855,
#   1,
#   1016,
#   2641,
#   150,
#   945,
#   170,
#   3653,
#   1304],
#  [245, 2585, 91, 187, 2, 508, 410, 76, 29],
#  [31, 56, 1, 128],
#  [2, 165, 15, 57, 52, 238],
#  [45, 293, 7998, 1, 191, 231],
#  [1, 123, 253],
#  [1, 274, 505],
#  [1, 111, 4, 502, 22, 1155],
#  [199, 1, 183, 968, 489, 42, 67, 22, 20, 39, 48],
#  [35, 1, 1452, 248, 484, 7999],
#  [180,
#   374,
#   2570,
#   1762,
#   1827,
#   1,
#   316,
#   788,
#   1158,
#   8000,
#   242,
#   279,
#   35,
#   728,
#   3357],
#  [295,
#   2,
#   439,
#   100,
#   1,
#   1084,
#   28,
#   3551,
#   8001,
#   326,
#   109,
#   214,
#   222,
#   685,
#   8002,
#   211,
#   2582,
#   17,
#   8003,
#   2304],
#  [1, 472],
#  [10,
#   8004,
#   4,
#   2,
#   459,
#   195,
#   8005,
#   8006,
#   532,
#   34,
#   8007,
#   50,
#   1410,
#   8008,
#   50,
#   1410,
#   8009,
#   50,
#   1410,
#   1417,
#   50,
#   8010],
#  [2, 317],
#  [12, 8011, 455, 8012, 1, 484, 455, 1064, 8013, 1, 484, 2225, 1, 484],
#  [8014,
#   1901,
#   27,
#   1959,
#   70,
#   2379,
#   458,
#   3841,
#   17,
#   1925,
#   1397,
#   204,
#   187,
#   913,
#   1,
#   132,
#   95],
#  [93, 2, 469, 5, 918, 135],
#  [1, 191, 102, 160],
#  [3, 14, 1052, 64, 1, 3, 1645, 8015, 9, 100],
#  [31, 8016, 1104, 96, 11, 1, 78, 837],
#  [1, 3842, 3427, 283, 131, 1883, 47, 297, 8017],
#  [1, 130, 8],
#  [242, 1, 74, 8018, 2357, 1009, 1509, 8019, 8020, 8021],
#  [1, 521],
#  [1,
#   327,
#   3841,
#   516,
#   1932,
#   3843,
#   733,
#   3727,
#   791,
#   8022,
#   3843,
#   11,
#   3844,
#   8023,
#   2499,
#   8024,
#   481,
#   344,
#   1127,
#   1465,
#   182,
#   671,
#   8025,
#   8026,
#   3106,
#   870,
#   338,
#   179,
#   8027,
#   83],
#  [10, 1, 191, 10, 389],
#  [770, 771, 97, 287, 708, 1, 2009, 613, 322],
#  [1, 329, 400, 24, 881, 8028, 655, 81, 196],
#  [1, 1091, 11, 1, 1045],
#  [79, 2, 150, 217, 3696, 8029, 1391, 8030, 8031],
#  [375,
#   189,
#   334,
#   3844,
#   346,
#   2464,
#   2264,
#   8032,
#   358,
#   1500,
#   35,
#   2,
#   1584,
#   2353,
#   3680,
#   26,
#   525],
#  [295, 44, 2, 177],
#  [1,
#   13,
#   78,
#   994,
#   994,
#   12,
#   3,
#   7,
#   3845,
#   2763,
#   8033,
#   451,
#   46,
#   2375,
#   1025,
#   8034,
#   3715,
#   17,
#   672,
#   1332,
#   567,
#   318,
#   190,
#   8035,
#   994,
#   6,
#   671,
#   994],
#  [55, 1, 3, 496, 32, 22, 20, 316],
#  [141, 1746, 240, 791, 2, 519],
#  [1, 69, 8036, 405, 8037, 504, 5, 2178],
#  [334,
#   1,
#   87,
#   51,
#   2493,
#   1178,
#   253,
#   139,
#   823,
#   708,
#   8038,
#   8039,
#   1589,
#   1854,
#   1897,
#   259,
#   8040],
#  [1, 146, 38, 440, 815, 81, 1797],
#  [1, 104],
#  [8041, 41, 330, 8042, 8043],
#  [7, 1502, 8044, 495, 172, 349, 25, 1, 291, 291, 197, 8045, 3, 289],
#  [2, 118, 201, 118, 2902, 2474, 3202, 1302, 160, 805, 16],
#  [79, 471, 170, 302, 8046, 461, 477, 3569, 129, 2554, 96, 161, 378, 2, 175],
#  [4,
#   409,
#   56,
#   126,
#   447,
#   66,
#   41,
#   424,
#   8047,
#   216,
#   3478,
#   26,
#   514,
#   1363,
#   81,
#   8048,
#   205,
#   116,
#   41,
#   3,
#   8049,
#   3019,
#   260,
#   2021,
#   660],
#  [182, 324, 4, 202, 75, 1, 8, 657, 4, 57, 202, 1003, 224, 228, 673, 978],
#  [1911, 71, 604, 20, 85, 576, 2, 72, 203],
#  [1, 336, 1963, 821, 306, 45],
#  [4, 2, 487, 61, 28, 463, 11, 18, 81, 603, 148, 2126, 45],
#  [1,
#   3,
#   33,
#   3723,
#   8050,
#   8051,
#   1018,
#   771,
#   1630,
#   37,
#   204,
#   8,
#   1,
#   217,
#   8052,
#   773,
#   449,
#   1175],
#  [1, 107, 2940, 1651, 611],
#  [4, 17, 2, 381, 4, 8053, 1835, 1701],
#  [1, 297, 4, 670, 623],
#  [7, 1095, 49, 818, 818, 51, 239, 347, 2, 347, 8054, 1236, 8055, 391, 42],
#  [2, 469, 44, 15, 20, 195, 798, 401, 938, 2206, 187, 8056, 8057, 8058, 982],
#  [7, 68, 240, 188, 585, 4, 2, 5, 117, 82, 169],
#  [10, 1, 264, 48, 216, 216, 474, 326, 715, 1, 487, 1132, 76, 581],
#  [1, 3, 8059, 162, 615, 8060],
#  [2,
#   5,
#   285,
#   12,
#   3545,
#   8,
#   288,
#   2529,
#   280,
#   741,
#   2523,
#   258,
#   618,
#   8061,
#   8062,
#   8063,
#   1931,
#   8064,
#   494,
#   1085,
#   8065,
#   4,
#   772],
#  [1, 69, 257, 3709, 26, 73, 2279, 1722, 166],
#  [1306, 16, 422, 161, 378, 56, 1, 5, 652],
#  [19, 8066, 8067, 764, 3846],
#  [1, 467, 317, 8],
#  [774, 474, 21, 494, 56, 1, 329],
#  [37, 1, 183, 284],
#  [4, 276, 1636, 2, 438, 3321, 2444, 62, 2314, 532, 28, 2501],
#  [392, 71, 224, 62, 246, 1197, 70, 721, 1773],
#  [946, 1, 3, 226, 8, 91],
#  [1, 491, 86],
#  [4, 2, 223, 1207, 223],
#  [2535, 27, 1, 3847, 8068, 59, 619, 32, 1958, 8069, 25, 478],
#  [2442,
#   3288,
#   798,
#   299,
#   1641,
#   3848,
#   2546,
#   961,
#   1,
#   217,
#   8070,
#   8071,
#   779,
#   78,
#   3848,
#   8072,
#   961,
#   509,
#   199,
#   1068,
#   1927],
#  [3066, 2138, 54, 313, 58, 1, 46, 369, 911, 1386, 246, 355, 35, 246, 8073],
#  [2, 133, 20, 29],
#  [80, 28, 2320, 2113, 217, 797, 1842, 953, 66, 919, 949, 1079, 62, 518],
#  [110, 36, 346, 595, 8, 8074, 2, 74, 108, 35, 595, 675, 25, 1947, 45, 3801],
#  [30, 1332, 1, 3, 4, 3, 8075, 8076, 8077, 3698, 8078, 328],
#  [2, 194],
#  [678,
#   1181,
#   2815,
#   999,
#   3821,
#   1001,
#   16,
#   695,
#   351,
#   8079,
#   321,
#   358,
#   28,
#   28,
#   9,
#   8080,
#   1,
#   115,
#   103,
#   847,
#   1297,
#   16,
#   948],
#  [4, 2, 315, 8081, 1384, 1121],
#  [109,
#   27,
#   3837,
#   3786,
#   3835,
#   2393,
#   1,
#   3849,
#   593,
#   276,
#   136,
#   158,
#   222,
#   1261,
#   3420,
#   1,
#   333,
#   29,
#   1640,
#   750,
#   8],
#  [1, 3, 4, 364, 71, 75],
#  [2,
#   33,
#   8082,
#   605,
#   29,
#   2572,
#   1089,
#   159,
#   2268,
#   472,
#   8083,
#   26,
#   1835,
#   350,
#   8084,
#   38,
#   76,
#   776,
#   1690],
#  [2329, 58, 1, 64, 92],
#  [2, 1627, 521, 8085, 2957, 1600, 50, 40, 644],
#  [1, 3, 3429, 3759, 111, 17, 502, 3742, 1155],
#  [116, 1, 3, 4, 99],
#  [3850, 161, 1, 3850, 8086, 48, 58, 640, 8087],
#  [94, 169, 1, 86, 2277],
#  [1, 3, 4, 69, 139, 26, 16, 89, 261, 16, 2557],
#  [14, 6, 255, 1008, 1, 8088, 171, 1203, 139, 174, 8089, 37, 872],
#  [76,
#   29,
#   8090,
#   448,
#   611,
#   1373,
#   155,
#   611,
#   8091,
#   16,
#   93,
#   1720,
#   2216,
#   3476,
#   202,
#   1983,
#   889,
#   1328,
#   1696,
#   1699],
#  [23, 14, 866, 64, 22, 24, 311, 180, 2, 285, 305, 22, 8092, 1713],
#  [1, 3, 175, 8093, 1951, 8094, 8095, 114, 10, 337, 1185],
#  [4, 2, 508, 2596, 600],
#  [6, 2, 249],
#  [1, 3, 8096, 24, 25, 39, 338, 404, 2344],
#  [4,
#   1963,
#   63,
#   21,
#   1605,
#   737,
#   247,
#   294,
#   481,
#   1,
#   658,
#   738,
#   1301,
#   1481,
#   3851,
#   962,
#   73],
#  [45, 8097, 3658],
#  [1, 117, 857, 264],
#  [1250, 185, 393, 1459, 139, 8098, 41, 3, 4, 264, 1313, 8099],
#  [79, 471, 262, 67, 2, 415, 559, 312, 1701],
#  [1, 336, 65, 1336, 44],
#  [2, 115, 1096, 1099, 1099, 3852, 1784, 235, 8100, 3738, 8101, 915, 3852, 782],
#  [131, 426, 8102, 12, 212, 1075, 1, 6, 1020],
#  [66, 8103, 624, 61, 8, 131, 3710, 1, 217],
#  [30, 198, 1, 466, 593, 8, 21, 313, 26],
#  [1, 11, 95, 552],
#  [1, 2060, 202, 58, 8104],
#  [1, 285],
#  [38, 1, 145, 8105, 9, 1870, 1011, 2506, 3484, 8106, 1375, 2542, 807],
#  [1, 3, 30, 1920, 59],
#  [45, 251, 85, 1701, 2768, 1383, 1248, 2, 100, 98, 1821, 85],
#  [16, 286, 122, 275, 55, 3, 19, 430, 11, 23, 7],
#  [703,
#   61,
#   8107,
#   28,
#   8108,
#   149,
#   46,
#   5,
#   22,
#   703,
#   56,
#   1,
#   46,
#   630,
#   1157,
#   46,
#   1255,
#   8109,
#   2863,
#   8110,
#   48],
#  [116, 1, 8111, 8112, 98, 135, 513, 8113, 8114, 8115, 560, 3],
#  [2, 33, 303],
#  [43, 860, 4, 1685, 1, 2240, 1020, 8116, 1575, 739, 443, 8117, 48, 886, 360],
#  [30, 1035, 96, 114, 98, 1811, 83, 50, 272, 2, 630, 630, 2, 83, 224, 62],
#  [10, 1, 340, 240],
#  [1395, 8118, 3719],
#  [1, 117],
#  [119, 143, 8119, 3499, 41, 162, 8120, 793, 244, 371, 8121, 31, 2658],
#  [7, 388, 141, 17, 1, 351, 1, 178, 585, 20, 1352, 8, 401],
#  [2, 330, 2096, 643, 1298, 8122],
#  [1, 3853, 1142, 52],
#  [1, 15, 125, 125, 677, 267, 15, 154],
#  [38, 1925, 2589, 24, 174, 313, 1, 3, 484, 597, 367, 71],
#  [17, 8123, 8124, 1, 1136, 84, 351, 111, 8125, 98, 8126],
#  [17, 2, 343, 157, 119, 264, 3233, 887, 626, 298],
#  [8127,
#   2917,
#   98,
#   1086,
#   749,
#   2597,
#   3854,
#   8128,
#   8129,
#   1318,
#   256,
#   2,
#   39,
#   1985,
#   22],
#  [452, 80, 422, 88, 2, 13, 250, 499, 946, 1310, 8130, 527],
#  [9, 401, 2598, 8131, 2, 2420, 234, 8132, 24, 9, 19, 625, 676],
#  [55,
#   919,
#   27,
#   8133,
#   8134,
#   18,
#   797,
#   2611,
#   2237,
#   2,
#   100,
#   132,
#   20,
#   147,
#   2432,
#   2171,
#   1581,
#   8135,
#   1138,
#   2107,
#   923,
#   517,
#   61,
#   166],
#  [8136, 80, 1, 8137, 56, 681, 1032],
#  [1, 87, 270],
#  [182,
#   25,
#   1646,
#   122,
#   30,
#   2423,
#   7,
#   280,
#   386,
#   15,
#   77,
#   1115,
#   437,
#   534,
#   989,
#   1172,
#   1196,
#   279,
#   49,
#   67,
#   289,
#   475,
#   1333,
#   8138,
#   368,
#   776,
#   19],
#  [1, 3, 3782, 338, 1355, 12, 21, 2429, 1370, 8139],
#  [1, 142, 82],
#  [116, 2, 3, 46, 597],
#  [1,
#   3,
#   3855,
#   3855,
#   59,
#   1495,
#   922,
#   418,
#   817,
#   8140,
#   2231,
#   8141,
#   8142,
#   292,
#   209,
#   3401],
#  [8143, 1, 104, 306, 535, 824],
#  [1, 327, 1679],
#  [2579, 426, 3666, 8144, 4, 2, 191, 259, 2384, 8145, 523],
#  [1, 344, 416, 508],
#  [9, 8146, 48, 1115, 1602, 25, 1, 3, 125, 22, 1369],
#  [639, 41, 213, 69, 242, 94, 8147, 333, 8148, 1710, 502, 3591],
#  [1963, 241, 1054, 2380, 8149, 66, 50, 16, 1, 8150, 1763, 8151],
#  [1, 3, 1504, 12, 59, 234, 67, 14, 24, 66, 397, 1108],
#  [108, 487, 1264, 3743, 1113, 8152, 388, 885, 80, 135, 8153],
#  [50, 74, 2, 612, 191, 447, 3, 1140, 833, 127, 456],
#  [24, 1, 57, 194, 2],
#  [7, 2, 249, 437, 339, 699, 507, 502, 881],
#  [1, 3, 316, 816, 887, 626, 470, 575, 2193, 7, 384, 3474, 2335, 2289, 1351],
#  [275, 2, 175, 253, 1838],
#  [1, 83, 130, 3788, 29, 8154],
#  [6,
#   76,
#   2363,
#   3856,
#   126,
#   496,
#   42,
#   400,
#   19,
#   466,
#   907,
#   1,
#   321,
#   33,
#   1,
#   147,
#   132,
#   365,
#   121,
#   17,
#   960,
#   411,
#   1150,
#   695],
#  [1, 104, 121, 3342, 3650],
#  [1, 107, 3708, 11, 451],
#  [422, 22, 70, 25, 113, 8155, 196, 2, 588],
#  [1, 3, 136, 577, 132],
#  [43, 60, 241, 1, 684, 755, 8156, 225, 2282],
#  [1, 3, 1979, 856, 355, 3790, 8157, 107],
#  [8158, 296, 56, 1, 191, 8159, 8160, 581, 1064, 486, 8161],
#  [154, 141, 410, 2, 106, 8162],
#  [295, 2, 263, 290, 1163, 2077, 478, 22],
#  [1, 491],
#  [4, 196, 440, 901, 8163, 1, 171, 661, 2487, 290, 661, 2199, 149],
#  [1, 359, 2528, 7, 94, 44, 17, 592],
#  [22, 1627, 1309, 888, 985, 5, 8164, 1262, 4, 2, 5, 106, 21],
#  [810, 286, 112, 2599, 663, 8165, 8166, 1, 179, 1837, 2599],
#  [1, 227, 184, 8167, 931, 8168, 8169, 8170, 8171],
#  [500,
#   692,
#   121,
#   17,
#   2535,
#   1576,
#   3206,
#   8172,
#   246,
#   887,
#   367,
#   126,
#   2556,
#   1653,
#   161,
#   1,
#   18,
#   99,
#   53],
#  [143, 1039, 28, 8173, 8174, 8175, 3518, 1273, 2652, 1803],
#  [70, 1, 175, 85],
#  [833, 92, 1711, 8176, 1, 336, 786, 21, 311],
#  [131, 25, 168, 1, 152],
#  [944],
#  [18, 2, 217, 1093],
#  [2265, 2307, 1657, 1139, 451, 1, 207, 180, 341, 763],
#  [2, 539, 9, 3589, 1500, 1580, 552, 243, 1059, 226, 8177, 226, 8178],
#  [1, 99, 257, 311],
#  [590, 67, 1193, 2148, 35, 3432, 2, 173],
#  [70, 736, 2, 175, 1890, 3164, 606, 1889, 11, 794],
#  [1844, 1254, 31, 27, 1, 416, 68, 170, 1844, 96, 384, 1705],
#  [1, 3, 4, 103, 815, 43, 125, 238],
#  [1, 192],
#  [3, 2, 104, 3093, 2194, 8179, 572, 45, 33, 770, 411, 207, 16],
#  [1, 475, 275, 51],
#  [68, 8180, 1471, 1480, 119, 1, 622, 107, 1346],
#  [4, 988, 372, 4, 2, 197, 51, 4, 573, 1040, 8181, 8182],
#  [9, 69, 2, 15, 11, 4, 480, 4, 331, 3857, 1951, 57, 118, 1193],
#  [1, 99],
#  [1, 449, 2680, 19, 1, 231],
#  [4, 2, 213, 157],
#  [1, 3, 223, 135, 206, 3756, 8183, 3817, 2561, 2943, 1053],
#  [1, 108, 193, 8184, 220, 20, 1570, 425, 2506, 37, 1410],
#  [2,
#   123,
#   127,
#   28,
#   44,
#   84,
#   1,
#   3,
#   8185,
#   1063,
#   8186,
#   701,
#   193,
#   193,
#   1651,
#   8187,
#   1971,
#   551,
#   165],
#  [677, 769, 3858, 12, 298, 90, 215, 8188, 677],
#  [4, 2, 223, 33, 21, 3633, 8189, 252],
#  [1, 1367, 46, 210],
#  [163, 2, 4, 21, 9, 95, 199, 441, 32, 253, 62],
#  [8190, 1350, 2, 60, 104, 165, 112, 165],
#  [1324, 1907, 1501, 355, 582],
#  [3, 4, 2, 597, 15, 51, 75, 8191, 8, 2280, 1622],
#  [18, 2, 5, 254, 996, 693, 411, 1051, 830],
#  [3614,
#   1182,
#   902,
#   12,
#   36,
#   8192,
#   781,
#   8193,
#   26,
#   2,
#   330,
#   27,
#   3367,
#   3800,
#   15,
#   75,
#   216,
#   574,
#   64,
#   330,
#   193,
#   304,
#   647],
#  [2, 60, 72],
#  [2, 2336],
#  [2, 429],
#  [1269, 141, 1, 231, 554, 8, 70, 299],
#  [2, 177],
#  [1, 69, 107, 945, 1356, 16, 8194, 83, 3753],
#  [18,
#   2,
#   5,
#   13,
#   72,
#   752,
#   256,
#   8195,
#   591,
#   8196,
#   2518,
#   8197,
#   30,
#   4,
#   151,
#   102,
#   8198,
#   1955,
#   37,
#   76,
#   585,
#   3859,
#   47],
#  [1408, 487, 762, 1, 664, 99],
#  [15, 1, 186],
#  [67, 1, 274, 1225, 149, 2564, 1, 39, 65, 873, 847],
#  [45, 944, 8199, 606, 1, 531, 192, 54, 8200],
#  [12, 1, 111, 1563, 219, 853, 13],
#  [1, 8201, 381],
#  [7, 1, 153],
#  [12, 965, 8, 545, 1, 6, 145, 23, 10],
#  [1, 367, 8202, 2868, 2793, 8203, 8204],
#  [1, 306, 394, 99, 8205, 24, 648, 239],
#  [375, 8206, 8207, 60, 3582, 2, 352, 320, 1198, 8208, 165, 27, 872, 859],
#  [1648, 2, 330],
#  [665, 634, 1, 8209, 336, 2, 830, 657, 62, 1, 1093, 820],
#  [1, 3, 234, 39, 208, 84, 1472],
#  [1, 3, 84, 289, 438, 3762, 6, 3860, 8210, 8211, 3799],
#  [1, 115, 37, 19, 1397],
#  [1, 249, 335, 305, 906],
#  [7, 1779, 2, 6, 125, 112],
#  [2, 732, 889, 587, 279, 259],
#  [4, 2, 613, 108, 3296, 1643],
#  [7,
#   1,
#   44,
#   136,
#   409,
#   103,
#   27,
#   764,
#   67,
#   8212,
#   3630,
#   1983,
#   3836,
#   8213,
#   8214,
#   57,
#   1895,
#   66,
#   80,
#   139],
#  [1, 844, 249, 8215, 729],
#  [138, 1, 3, 475, 746, 55, 265, 3737],
#  [4, 2, 74],
#  [1, 143, 4, 78, 386, 102, 455, 48, 3],
#  [1, 2595, 152, 8216, 3482, 8217, 8218, 1054, 3861, 218, 1008, 18, 996],
#  [61, 8, 537, 305, 1516, 2469],
#  [8219, 2776, 2044, 8220, 8221, 1, 614],
#  [1, 490, 251, 135],
#  [685, 8222, 103, 1, 15, 104, 8223],
#  [1, 3, 301, 383, 4, 120, 16, 15, 51, 542, 103, 1377, 7, 43],
#  [12,
#   571,
#   21,
#   41,
#   107,
#   20,
#   1813,
#   635,
#   276,
#   1013,
#   1546,
#   22,
#   11,
#   267,
#   837,
#   8224],
#  [2128, 21, 584, 1, 306, 650, 7, 2587, 8225, 141, 3819, 7, 178],
#  [261,
#   27,
#   720,
#   3044,
#   8226,
#   8227,
#   2550,
#   8228,
#   2190,
#   640,
#   1135,
#   442,
#   1,
#   128,
#   367],
#  [4, 78, 116, 1, 213, 139, 8229, 42, 137, 125, 721, 301, 22, 20, 3604],
#  [1, 3862, 3863, 3862, 3863, 337, 128, 11, 261, 1654, 26, 1327],
#  [89, 97, 131, 9, 272, 2, 803, 314],
#  [10, 160, 2435, 8, 616, 873, 8230, 1, 181, 897],
#  [1, 6, 366, 24, 434, 8231, 1203, 3864, 737, 300],
#  [1, 155, 150, 8232, 251, 1550, 21, 57, 730, 3305, 8233],
#  [14,
#   1611,
#   8234,
#   917,
#   1393,
#   8235,
#   1233,
#   3256,
#   591,
#   2562,
#   155,
#   71,
#   8236,
#   2,
#   1873,
#   1233],
#  [2, 123, 1406, 15, 795, 2552, 8237, 2531, 309],
#  [2, 439],
#  [1,
#   916,
#   3840,
#   2633,
#   1006,
#   26,
#   12,
#   5,
#   13,
#   1881,
#   1992,
#   1044,
#   954,
#   1060,
#   40,
#   3542,
#   135,
#   12,
#   355,
#   918,
#   895,
#   12,
#   8238],
#  [4,
#   866,
#   42,
#   136,
#   41,
#   99,
#   51,
#   136,
#   737,
#   1477,
#   26,
#   16,
#   2588,
#   564,
#   8239,
#   11,
#   19,
#   3865,
#   8240,
#   1922,
#   8241,
#   33],
#  [141, 102, 8242, 2, 9, 29, 86, 3866, 8243, 592, 166],
#  [1, 18, 1354, 655, 371, 39, 522, 136],
#  [110, 386, 1799, 501, 154, 2, 208, 332, 8244],
#  [1, 1065, 562, 1647, 639, 1647, 639, 2, 1545],
#  [2, 263, 195],
#  [1, 271, 125, 238],
#  [38, 41, 506, 401, 605, 1158, 8245, 3685, 141, 73, 1, 91],
#  [277,
#   1140,
#   122,
#   105,
#   8,
#   22,
#   129,
#   34,
#   41,
#   3,
#   81,
#   10,
#   1613,
#   287,
#   82,
#   42,
#   167,
#   544,
#   501],
#  [442, 1, 78, 3807, 3867, 1006, 3866, 1449],
#  [31, 19, 1651, 75, 1, 191, 300],
#  [1, 3, 39, 597, 88, 604, 3209, 643, 29, 154, 753],
#  [1, 310, 207, 410, 1103, 8246],
#  [1, 605, 73, 586, 3567, 8247],
#  [102, 1, 145, 160, 582, 19, 92, 161, 3868, 214],
#  [13, 3322, 283, 1, 56, 26, 46, 317],
#  [4, 2, 254, 121, 377, 20, 25, 198, 3772],
#  [1,
#   8248,
#   1976,
#   157,
#   8249,
#   158,
#   1,
#   1220,
#   3687,
#   8250,
#   264,
#   1344,
#   3760,
#   880,
#   3,
#   372,
#   23,
#   25,
#   257,
#   4,
#   504,
#   8251,
#   3869,
#   8252],
#  [158, 1, 355, 3, 1305, 2462, 8253, 158, 8254, 8255, 8256],
#  [1, 3, 8257, 424],
#  [4, 2, 6, 6, 70, 343, 173, 82],
#  [1, 208, 275, 371, 134, 8258, 443, 9, 1059],
#  [18, 323, 619, 113, 1, 147, 8259, 2532, 2540, 68, 351, 2010],
#  [435,
#   665,
#   2596,
#   8260,
#   241,
#   66,
#   321,
#   68,
#   75,
#   200,
#   149,
#   962,
#   257,
#   2,
#   743,
#   2,
#   788,
#   1552],
#  [2228, 8261, 898, 27],
#  [119, 2580, 33, 30, 207, 9, 10, 1, 865],
#  [1, 266, 208, 8262, 90, 634, 14, 1, 233, 456],
#  [12, 42, 113, 1, 6, 157, 3510, 3851, 82],
#  [1, 424, 8263, 228, 8264, 8265, 2517],
#  [1, 3, 10, 223, 2511, 196, 627, 1169],
#  [1, 132, 705, 8266, 25, 1644],
#  [1,
#   3,
#   4,
#   17,
#   1362,
#   3870,
#   577,
#   358,
#   1662,
#   550,
#   26,
#   77,
#   67,
#   85,
#   1922,
#   350,
#   1803,
#   3248,
#   193],
#  [1,
#   3681,
#   8267,
#   3100,
#   54,
#   3,
#   1918,
#   12,
#   256,
#   462,
#   335,
#   8268,
#   1875,
#   8269,
#   384,
#   688],
#  [1, 156, 37, 168, 670, 8270, 8271, 8272, 8273],
#  [6, 1, 142],
#  [276, 1860, 8274, 284, 8275, 1979, 411, 1, 513, 53, 536, 73],
#  [1, 433],
#  [1, 314, 10, 279, 168],
#  [1, 493, 3, 492, 375, 154, 2],
#  [50, 870, 427, 1019, 54, 2, 130],
#  [43, 9, 8276, 113, 2, 99, 8, 137, 8277, 1574],
#  [2, 133, 1552, 12, 504, 1203, 8278, 127, 19],
#  [1, 364, 75],
#  [4, 2, 223],
#  [4,
#   1650,
#   8279,
#   2837,
#   920,
#   3092,
#   8280,
#   891,
#   212,
#   8281,
#   377,
#   3871,
#   3872,
#   3871,
#   8282,
#   49,
#   176,
#   8283,
#   8284],
#  [9, 731, 8285, 1, 400, 75],
#  [1, 8286, 3150, 7, 3562, 134, 1, 734, 1, 3, 134, 24],
#  [2168, 228, 8287, 393, 54, 3778, 529, 949, 2567, 959, 1850],
#  [1, 376, 34],
#  [1, 3, 12, 25, 818, 71, 882, 14, 12, 430, 8288, 1059],
#  [1, 475, 34],
#  [2, 330, 28],
#  [2, 5, 74, 72, 66, 561, 2078, 505],
#  [1, 3, 400, 370, 461, 269, 1396, 1511, 1330, 60, 534, 1308, 3, 269],
#  [1, 69, 257, 3261, 8289, 61, 8290, 8291, 8292, 8293, 8294],
#  [19,
#   757,
#   2726,
#   8295,
#   8296,
#   1935,
#   387,
#   516,
#   309,
#   126,
#   2,
#   342,
#   445,
#   8297,
#   1610],
#  [2, 39, 48, 3133, 1665],
#  [2, 3519, 123, 30, 214, 592, 15, 51, 1848, 3431, 39, 36],
#  [587, 2541, 1237, 8298, 2437, 2255, 137, 8299, 353, 1, 480, 723],
#  [15, 1, 521, 8300],
#  [212, 3845, 8301, 1, 484],
#  [1,
#   3,
#   2359,
#   320,
#   51,
#   1,
#   951,
#   207,
#   51,
#   1,
#   3,
#   2159,
#   1218,
#   51,
#   1,
#   1861,
#   350,
#   450,
#   8302,
#   8303],
#  [1, 133, 1847, 757],
#  [1, 4, 150, 42, 4, 20, 858, 1612],
#  [1, 46, 171, 73],
#  [18,
#   1048,
#   510,
#   4,
#   17,
#   2,
#   8304,
#   500,
#   125,
#   1787,
#   474,
#   205,
#   1468,
#   458,
#   1787,
#   1177,
#   7],
#  [1, 3585, 629, 8305, 8306, 1505, 8307, 73, 701],
#  [1, 134, 88],
#  [148, 408, 1, 153],
#  [14, 27, 333, 796, 1346, 692, 458, 1138, 2, 33, 25, 19, 32, 174, 179],
#  [1, 399, 416, 449, 3859, 1814],
#  [1, 186, 34],
#  [6, 3, 2598, 11, 1, 6, 122, 2598, 424, 20, 620, 1, 6, 308],
#  [1, 156, 1076, 8308, 8309, 8310, 875, 8311, 1, 156, 292, 209, 8312],
#  [442, 1, 111, 1222, 12, 66, 8313],
#  [9, 129, 161, 3820, 56, 1, 223, 8314],
#  [25, 620, 1, 69, 1440, 1936, 3724],
#  [112, 2, 5, 194, 8315, 1524, 8316, 3121, 363],
#  [8317,
#   58,
#   478,
#   16,
#   96,
#   114,
#   89,
#   8318,
#   2444,
#   76,
#   32,
#   2,
#   173,
#   3586,
#   26,
#   77,
#   27,
#   560,
#   1538],
#  [4, 103, 8319, 154, 46, 1650, 2, 72],
#  [1200, 193, 949, 854],
#  [502, 1578, 76, 8320, 507, 752, 110, 21, 783, 388],
#  [281, 8321, 2457, 1, 8322, 709, 568],
#  [1, 3, 1797, 190, 150, 1209],
#  [1, 5, 8323, 4, 100, 249],
#  [18, 2, 123, 8324, 8325, 8326, 283],
#  [8327, 1, 23, 1, 85, 297, 17, 570, 8328, 619, 1391, 21],
#  [2, 100, 263, 44, 368, 91, 1184, 495, 1858],
#  [1, 366, 465, 320, 11, 8329, 185, 397, 677, 644],
#  [1, 100, 1, 2052, 81],
#  [1, 468, 81],
#  [33, 27, 2121, 939, 22, 3, 17, 38, 1, 5, 123, 634, 651],
#  [1, 2372, 508, 1507],
#  [35, 1, 144, 174, 583, 616, 987, 696],
#  [572, 2, 8330, 87],
#  [1, 306, 622],
#  [758, 1210, 80, 8, 1, 1599, 480, 1540, 1041, 161],
#  [4, 1879, 488, 2, 186, 225],
#  [1, 652, 5, 8331, 2715, 853, 8332, 8333, 8334],
#  [2, 74, 63, 3, 168, 313, 12, 1206],
#  [224, 3834, 8335],
#  [2, 5, 157, 8336, 2873, 1649, 34, 23, 10, 30],
#  [93, 1, 83, 285],
#  [3, 27, 1, 3, 334, 3783, 1326, 325, 270],
#  [678, 110, 36, 230, 395, 1, 1561, 217, 1348, 8337, 262, 11, 261, 160],
#  [4, 3873, 2, 395, 227, 480, 926, 774, 8338],
#  [70, 736, 2, 5, 181, 288],
#  [908, 1, 39],
#  [9, 766, 2438, 36, 8339, 3479, 10, 1, 78, 589, 305, 1514],
#  [7, 775, 195, 1, 3, 6, 550, 8340, 3874, 170],
#  [4, 17, 2, 143, 51],
#  [1, 260, 336, 8341, 9, 77, 393, 16, 2799, 3540, 3808, 393, 1813, 2431],
#  [17, 1, 759, 986, 73, 4, 78, 76, 286, 139, 2048, 808, 509, 868, 3875],
#  [1, 184, 7, 30, 390],
#  [444, 8342, 1478, 2, 72],
#  [1, 359, 2823, 3876, 3876, 73],
#  [1, 303, 221, 1261, 8343, 129, 154, 240],
#  [346, 9, 8344, 306, 1, 132],
#  [79, 2, 117, 42, 48, 3877, 90, 1198, 575, 187, 3877],
#  [37,
#   1,
#   375,
#   24,
#   9,
#   59,
#   440,
#   1026,
#   1638,
#   10,
#   1280,
#   54,
#   259,
#   61,
#   627,
#   8,
#   195,
#   1026,
#   1638,
#   7,
#   247,
#   180,
#   20],
#  [1, 361],
#  [131, 1, 176, 788, 149, 946],
#  [18, 81, 678, 1, 718, 40, 357, 1165],
#  [93, 2, 157, 110],
#  [1, 353, 22, 97, 709],
#  [272, 1, 115, 8],
#  [9, 91, 8345, 32, 8346, 2, 439],
#  [1,
#   8347,
#   75,
#   474,
#   165,
#   236,
#   126,
#   4,
#   6,
#   539,
#   1076,
#   963,
#   238,
#   516,
#   13,
#   1784,
#   2423,
#   474,
#   50,
#   26],
#  [8348, 1645, 958, 1, 74, 107],
#  [1, 92, 199, 8349, 1135],
#  [1,
#   115,
#   1488,
#   88,
#   79,
#   3182,
#   974,
#   722,
#   8350,
#   8351,
#   220,
#   1135,
#   1512,
#   164,
#   256,
#   92,
#   1818,
#   105,
#   337],
#  [97, 1, 217, 143, 991],
#  [2, 191],
#  [1, 256, 197, 67, 94, 85, 1757],
#  [109,
#   129,
#   8352,
#   2972,
#   112,
#   86,
#   312,
#   8353,
#   8354,
#   245,
#   2,
#   1102,
#   95,
#   312,
#   299,
#   694],
#  [1, 52, 3396, 402, 402, 402],
#  [1, 64, 12, 462, 632, 332, 189],
#  [4, 8355, 1, 376],
#  [1, 445, 161],
#  [43, 829, 980, 693, 1, 343, 417],
#  [24, 1556, 245, 211, 2, 64, 3878, 162, 591, 266, 26, 174, 313, 375, 496],
#  [1, 369, 292, 209, 8356],
#  [1, 506, 437, 148, 1090, 1987],
#  [47, 1, 400, 465, 1712],
#  [102, 215, 3616, 1, 3335, 142],
#  [257, 8357, 140, 2, 106],
#  [1, 318, 23, 7, 51],
#  [94, 159, 10, 20, 21, 1, 145, 10, 92, 486],
#  [17, 1, 194, 1160, 584, 1655, 2189, 8358, 665],
#  [17, 1, 104, 279, 8359],
#  [4,
#   329,
#   3676,
#   443,
#   1,
#   171,
#   1134,
#   1304,
#   1151,
#   8360,
#   8361,
#   199,
#   8362,
#   1380,
#   1092,
#   8363,
#   8364,
#   292,
#   209,
#   8365],
#  [1, 3, 13, 544, 890, 690],
#  [1, 3, 5, 314, 175, 71, 483, 119, 3, 454],
#  [442, 840, 767, 93, 3712, 304, 1, 330],
#  [1, 13, 120],
#  [24, 360, 524, 1082, 620, 1, 472, 77, 15, 90],
#  [23, 8366, 377, 767, 601, 788, 5, 578, 1, 3847, 150, 2253, 65],
#  [1, 52, 4, 20, 245, 40, 8367],
#  [31, 245, 1216, 2, 183, 213, 3766],
#  [6, 31, 2, 95],
#  [1, 416, 307],
#  [79, 2, 249, 15, 1365, 3, 114],
#  [1, 46, 46, 2, 509, 78, 95],
#  [2, 52, 109, 742, 253],
#  [1, 3, 8368, 57, 132, 290, 3879, 89, 23, 10, 3879, 1, 3645],
#  [17, 1, 3, 334, 16, 170, 1149, 1277, 192, 2183, 984, 8369, 44],
#  [2, 468, 55, 89, 105, 113, 8370, 2394, 309],
#  [1905, 699, 1, 298, 479, 3864, 585, 8371, 2740, 2256],
#  [2, 176, 108, 258, 211, 859, 8372, 2346, 505, 103, 1179, 9, 308, 8373],
#  [2, 1977, 2874, 468, 50, 15, 5, 1794, 780, 20, 37, 61, 2509, 50, 715, 9, 546],
#  [6, 79, 2, 320, 8374, 1425],
#  [606, 1862, 1, 322, 1834, 511, 967, 525],
#  [17, 2, 508, 482, 762, 165, 165, 165, 124],
#  [1, 3, 8375, 298, 8376, 255, 96, 8377],
#  [2, 487, 920, 8378, 8379, 31, 45, 659, 334],
#  [587, 85, 311, 244, 2908, 2, 291, 156, 2, 1316],
#  [572,
#   1,
#   437,
#   364,
#   1044,
#   319,
#   272,
#   337,
#   8380,
#   8381,
#   8382,
#   14,
#   17,
#   103,
#   663,
#   403,
#   277],
#  [58,
#   28,
#   46,
#   3239,
#   1,
#   8383,
#   26,
#   228,
#   161,
#   1069,
#   343,
#   231,
#   323,
#   9,
#   5,
#   2084,
#   624],
#  [1, 3, 199, 409, 20, 3781],
#  [587, 98, 1455, 3867, 20, 8384, 127, 84, 247, 324, 2, 5, 157],
#  [131, 195, 688, 20, 1, 8385, 1396, 201, 589],
#  [10,
#   8386,
#   8387,
#   15,
#   51,
#   12,
#   243,
#   1151,
#   372,
#   1,
#   8388,
#   71,
#   156,
#   12,
#   25,
#   1,
#   3,
#   8389],
#  [131, 758, 1, 115, 758, 382, 653],
#  [1229, 234, 783, 2, 1183, 19, 124, 216, 234, 28, 4, 78, 1183],
#  [574, 3, 587, 8390, 8391, 126, 1916, 3212, 1, 3, 475, 71],
#  [1, 3, 8392, 2446, 8393, 1202, 364, 1635, 8394, 8395, 1687],
#  [1, 547, 1155, 105, 1230],
#  [161,
#   206,
#   16,
#   8,
#   363,
#   934,
#   246,
#   251,
#   91,
#   1160,
#   2,
#   81,
#   45,
#   18,
#   162,
#   126,
#   386,
#   81,
#   294],
#  [1, 3, 476],
#  [1, 3, 3797, 8396, 21, 838, 498],
#  [587, 165, 8397, 302, 1275, 1700, 14, 4, 242, 1, 264, 76],
#  [377, 1, 250],
#  [1, 201, 8398, 781],
#  [235, 2, 973, 8399, 60, 64],
#  [1967, 96, 8400, 1, 408, 3564, 27, 498, 8401, 1591, 2547, 2082, 8402, 1546],
#  [643,
#   2099,
#   25,
#   600,
#   103,
#   790,
#   13,
#   176,
#   1302,
#   25,
#   241,
#   176,
#   2,
#   67,
#   254,
#   2,
#   857,
#   8403,
#   2527],
#  [1186, 2, 13, 74, 51, 373, 11, 582],
#  [93,
#   3868,
#   214,
#   525,
#   61,
#   166,
#   12,
#   414,
#   526,
#   198,
#   110,
#   214,
#   204,
#   28,
#   246,
#   753,
#   49,
#   1322,
#   43,
#   125,
#   214],
#  [4, 2, 6, 52, 230, 14, 1343, 4, 183],
#  [1, 1591, 3880, 8404, 8405, 8406, 3660],
#  [18, 45, 15, 3831, 436, 1239, 22, 20, 1239, 2, 916],
#  [573,
#   41,
#   1222,
#   13,
#   285,
#   306,
#   98,
#   349,
#   371,
#   8407,
#   8408,
#   8409,
#   228,
#   51,
#   66,
#   2914,
#   1823],
#  [66, 821, 253, 1567, 1034, 1259, 2, 468, 89, 3404, 970],
#  [31, 374, 1, 207, 1201, 354, 266],
#  [1, 659, 326, 206, 344, 290, 65],
#  [4, 2, 6, 473, 216, 1826],
#  [321, 1, 19, 345, 168, 2287, 1164],
#  [621, 2, 142, 189, 9, 312, 1299, 862],
#  [368, 1114, 3445, 1853, 515, 47, 2, 210, 2600],
#  [1, 731, 341, 1, 249, 100],
#  [722, 16, 2829, 1775, 1, 171],
#  [1437, 1686, 137, 2, 229, 155, 428, 137],
#  [2, 415, 1503],
#  [1, 1464, 389, 38, 1635, 346, 421, 427, 2996, 27, 3601, 1060],
#  [427, 140, 221, 577, 113, 1, 250, 9, 653, 1586],
#  [1, 541, 122],
#  [79,
#   2,
#   6,
#   87,
#   8410,
#   848,
#   20,
#   3846,
#   1610,
#   8411,
#   332,
#   1610,
#   748,
#   282,
#   2316,
#   812,
#   20,
#   528],
#  [1, 184],
#  [1, 2074, 506],
#  [1, 976, 361, 433, 53, 1674, 12, 113, 851, 8412, 639, 80, 16, 740],
#  [2279, 1, 1102, 175],
#  [813, 2, 175, 3, 169, 1311, 558, 1426],
#  [2,
#   5,
#   263,
#   154,
#   82,
#   483,
#   9,
#   196,
#   8413,
#   32,
#   19,
#   48,
#   410,
#   1613,
#   3430,
#   94,
#   2566,
#   9,
#   40],
#  [1,
#   144,
#   8414,
#   9,
#   1048,
#   8415,
#   71,
#   160,
#   1,
#   1017,
#   1252,
#   760,
#   32,
#   8416,
#   8417,
#   2445,
#   71,
#   81,
#   603,
#   23,
#   14,
#   81,
#   68,
#   168,
#   255,
#   26],
#  [1, 3, 500, 111, 284],
#  [247, 1, 916],
#  [500, 678, 44, 1, 3, 4, 20, 1, 18, 132, 40, 26, 187, 218],
#  [1, 3, 134, 2595, 102, 1103, 8418],
#  [1, 17, 190, 74, 2394, 8419, 1051, 32, 710],
#  [7, 899, 2536, 19, 43, 47, 1, 779, 208, 8420, 19, 4, 2536, 536],
#  [1,
#   15,
#   51,
#   1232,
#   325,
#   567,
#   16,
#   8421,
#   1997,
#   726,
#   11,
#   184,
#   1135,
#   8422,
#   840,
#   1622,
#   600,
#   8423,
#   3825,
#   8424,
#   8425],
#  [138, 1, 614, 21],
#  [14, 8426, 2117, 1, 3, 1219, 1219],
#  [10, 43, 47, 2, 128],
#  [8427, 2580, 40, 8428, 2272, 1, 361],
#  [109,
#   461,
#   680,
#   8429,
#   56,
#   257,
#   1065,
#   1,
#   153,
#   768,
#   874,
#   58,
#   680,
#   272,
#   806,
#   2337,
#   351,
#   26,
#   8430],
#  [4, 792, 2421, 8431, 64, 390, 390, 1, 33, 42, 21, 179, 4, 20, 651],
#  [4, 2, 183, 182, 180, 8432],
#  [2, 8433, 263, 1335, 8434],
#  [1693, 1, 318],
#  [1, 46, 484, 461],
#  [1, 369],
#  [3, 274, 406, 1906, 913, 604, 114, 352, 33, 385, 422, 423, 1, 176],
#  [119, 234, 1306, 957, 2131, 8435, 793, 2, 223],
#  [1,
#   2889,
#   29,
#   876,
#   2573,
#   1283,
#   61,
#   8,
#   362,
#   529,
#   61,
#   8,
#   215,
#   29,
#   29,
#   3491,
#   31,
#   501,
#   78],
#  [10, 1, 115, 238],
#  [189, 1, 409, 291, 235, 139, 73, 77, 296, 939, 222, 93, 685, 453, 2433, 409],
#  [2, 317, 8436, 3793, 299, 8437, 725],
#  [267,
#   30,
#   29,
#   2192,
#   3185,
#   532,
#   219,
#   604,
#   3512,
#   419,
#   10,
#   694,
#   8438,
#   7,
#   1,
#   17,
#   293,
#   409],
#  [1, 3, 1140, 358, 107, 8, 8439, 3, 3473],
#  [8440, 442, 1, 227, 143],
#  [24, 1, 20, 470, 190, 17, 818],
#  [141, 1555, 401, 4, 2, 328],
#  [1, 184, 8441, 189, 83, 31, 581, 1037, 172, 3425, 189],
#  [93, 2, 74, 154, 138, 1652, 1943, 3022, 8442],
#  [8443],
#  [35, 1, 59, 147, 201, 168],
#  [180, 2, 217],
#  [353, 1, 65, 2151, 48],
#  [1, 366, 858, 3208],
#  [1, 260, 467, 33, 8444, 3102, 1650, 48, 54, 313],
#  [212,
#   190,
#   1596,
#   2221,
#   35,
#   599,
#   1571,
#   3838,
#   619,
#   1,
#   33,
#   864,
#   8445,
#   1408,
#   327,
#   8446],
#  [1, 6, 104, 167, 27, 4, 866, 163],
#  [1, 175, 1601, 11, 8447],
#  [1, 3, 18, 1366, 107, 1007, 6, 465],
#  [1557, 41, 8448, 69],
#  [1, 488, 524, 945, 270],
#  [3881, 1, 649],
#  [239, 2, 117, 2526, 1558],
#  [79, 2, 27, 306, 183, 95, 409, 24],
#  [116, 1, 3, 134, 51, 23, 406, 451, 225],
#  [94, 1, 13, 72],
#  [30,
#   8449,
#   160,
#   3031,
#   3706,
#   8450,
#   527,
#   533,
#   326,
#   605,
#   2435,
#   2522,
#   665,
#   1252,
#   8451,
#   434,
#   365,
#   283,
#   49,
#   1978,
#   2046,
#   232],
#  [1, 3777, 442, 708, 436, 8452],
#  [4,
#   20,
#   30,
#   2413,
#   908,
#   2494,
#   1,
#   415,
#   126,
#   182,
#   8453,
#   8454,
#   141,
#   15,
#   8455,
#   1396,
#   8456],
#  [24, 1, 254, 33, 33, 25],
#  [854, 2, 157, 200, 8457, 119, 435, 722, 68, 34, 1265, 2290, 900, 1532],
#  [1, 153, 1083, 167, 398, 1, 1320, 398, 122, 12, 10, 195, 124, 2270],
#  [66, 109, 981, 66, 12, 452, 632, 735, 341, 3577, 304, 1, 142],
#  [1, 3, 120, 6, 350, 26],
#  [163, 2, 103, 1637, 100],
#  [1, 60, 210, 270, 114, 396, 388, 15, 21, 437, 8458, 8459],
#  [18, 678, 1632, 121, 68, 16, 1021, 2, 336, 19, 18, 452, 155, 28, 66, 9, 29],
#  [119, 1047, 6, 7, 63, 1, 219, 5, 13, 46, 120, 126, 1126],
#  [14,
#   36,
#   1,
#   1406,
#   2,
#   131,
#   47,
#   16,
#   84,
#   26,
#   10,
#   234,
#   241,
#   241,
#   207,
#   53,
#   36,
#   22,
#   470,
#   2192,
#   112],
#  [158,
#   565,
#   1359,
#   8460,
#   8461,
#   38,
#   1,
#   743,
#   149,
#   105,
#   397,
#   6,
#   1246,
#   3792,
#   2599,
#   8462,
#   2913,
#   51,
#   3,
#   282,
#   8463],
#  [2,
#   60,
#   133,
#   3882,
#   45,
#   246,
#   404,
#   138,
#   1689,
#   12,
#   321,
#   138,
#   571,
#   2284,
#   8464,
#   397,
#   105,
#   412],
#  [1, 156, 153, 279],
#  [18, 2, 3678, 448, 681, 8465, 1984, 1058, 3576, 32, 908, 941, 8466],
#  [1, 118, 157, 3469, 1414, 2571, 781],
#  [436, 8467, 3246, 2471, 40, 56, 815, 3707, 1873, 507, 1, 506],
#  [4,
#   35,
#   2,
#   194,
#   1098,
#   1153,
#   8,
#   1,
#   3,
#   4,
#   1078,
#   2596,
#   64,
#   35,
#   1078,
#   64,
#   1338,
#   73,
#   32],
#  [2505, 129, 8468, 1104, 80, 8469, 620, 21, 8470, 294, 8471, 527],
#  [396, 12, 1, 54, 2447, 275, 1277, 179, 22, 387, 29, 826],
#  [17, 1, 143, 1269, 8472, 38, 478, 21, 277, 38],
#  [14, 3747, 5, 27, 309, 266, 9, 2, 424, 16],
#  [834, 19, 924, 412, 1, 3, 285],
#  [1, 115, 43, 167],
#  [1, 940],
#  [1, 556, 281, 1614, 3236],
#  [1, 39, 415, 9, 196, 389, 585, 2543],
#  [189, 30, 301, 8473, 2, 181, 8474, 282, 1240],
#  [2, 417, 189, 30, 389],
#  [244, 8475, 2, 150, 246, 36, 543],
#  [1, 541, 248, 3119, 159, 8476, 357, 647, 3883, 8477],
#  [759, 8478, 761, 1, 8479, 1884, 39, 373, 797, 298, 794, 8480],
#  [8481,
#   210,
#   2,
#   368,
#   813,
#   1640,
#   765,
#   3151,
#   481,
#   32,
#   6,
#   95,
#   12,
#   301,
#   655,
#   935,
#   972,
#   3414],
#  [1, 916, 943, 3307, 15, 75, 68, 3849, 196, 282, 8482, 17, 302, 3884],
#  [353, 1, 612, 130, 637],
#  [1, 3, 208, 553],
#  [8483, 3794, 2, 8484, 1139, 641, 48, 8485],
#  [189, 8486, 54, 1, 192, 8487, 3691],
#  [18, 90, 167, 8488, 66, 476],
#  [1, 310, 8489, 1658],
#  [14, 68, 17, 3885, 304, 8490, 2, 291, 217],
#  [1, 865, 3809, 3884],
#  [42, 466, 338, 5, 2, 134],
#  [4,
#   606,
#   383,
#   684,
#   302,
#   8491,
#   1,
#   684,
#   302,
#   372,
#   8492,
#   864,
#   323,
#   446,
#   1919,
#   8493,
#   8494],
#  [4, 17, 1576, 660, 1, 197],
#  [1617, 985, 890, 8495, 2, 213, 223, 558, 1805, 2],
#  [18, 540, 96, 114, 116, 4, 116, 2, 285, 365, 42],
#  [1266, 462, 936, 1, 87, 446, 455, 1141, 198, 3598],
#  [3, 950, 1659, 26, 915, 1393, 1013, 1, 3, 15, 232, 532],
#  [35, 1, 227, 416, 8496, 717, 170],
#  [2, 236, 684],
#  [1, 173],
#  [4, 2, 459, 34],
#  [217, 19, 848, 8497, 1806, 206, 379, 8498, 8499, 372, 24, 983, 8500, 2591],
#  [4, 2, 87, 266, 73, 3885, 2782, 286, 8501, 3467, 300, 1846],
#  [38, 14, 42, 1, 5, 181, 38, 14, 42, 1, 5, 181, 1617, 101, 1587, 8502],
#  [391, 2, 156, 1224],
#  [83, 1912, 75, 35, 277, 3153, 272, 212, 8503, 347, 1, 142],
#  [1504,
#   3861,
#   1562,
#   1568,
#   496,
#   332,
#   332,
#   405,
#   248,
#   815,
#   198,
#   39,
#   8504,
#   152,
#   781,
#   604,
#   27,
#   92,
#   3220,
#   8505,
#   114,
#   1,
#   3,
#   24,
#   66,
#   445],
#  [1, 293, 52],
#  [10, 37, 41, 21, 1, 544],
#  [1, 336, 2247, 1084, 129, 214, 1, 1206, 767, 8506, 2272],
#  [246, 2, 3, 20, 3796, 1235, 23, 15, 7, 219, 148, 88, 597],
#  [2, 39, 250, 34, 1224],
#  [43, 15, 9, 8507, 700, 27, 46, 37, 1172, 875, 3285, 1, 8508, 99, 32],
#  [119, 558, 32, 2, 186, 147],
#  [531, 785, 25, 11, 1, 144, 407, 548],
#  [1,
#   147,
#   268,
#   3596,
#   21,
#   3880,
#   1520,
#   1136,
#   21,
#   2124,
#   486,
#   188,
#   8509,
#   1015,
#   148,
#   180,
#   496,
#   560],
#  [45, 36, 280, 224, 8510, 621, 807, 826, 807, 70, 2, 15, 445, 594],
#  [1, 186, 143, 23],
#  [406, 1, 625, 147, 252, 24, 8511, 19, 147, 127, 187, 61, 747, 452, 965],
#  [3532, 8512, 1, 3, 12, 1307, 50, 516, 8513, 1702, 11, 1987, 3097, 984],
#  [1, 712, 68, 8514, 257, 888, 8515],
#  [2, 157, 40],
#  [1, 8516, 52, 346],
#  [1, 144, 154, 200, 921, 2, 8517, 3824],
#  [326, 11, 14, 1, 357, 3471, 2489],
#  [45, 5, 13, 2612, 49, 2, 485, 125],
#  [1,
#   779,
#   3,
#   8518,
#   3171,
#   8519,
#   8520,
#   94,
#   681,
#   3501,
#   3079,
#   8521,
#   1033,
#   507,
#   3018,
#   8522],
#  [138, 1382, 1640, 2, 3, 21, 506],
#  [728, 8523, 710, 8524, 193, 8525, 1, 210],
#  [23,
#   7,
#   893,
#   48,
#   3,
#   3679,
#   8526,
#   788,
#   8527,
#   3263,
#   1007,
#   25,
#   1560,
#   21,
#   9,
#   151,
#   65,
#   1,
#   336,
#   3,
#   18,
#   3477,
#   297,
#   1761,
#   365,
#   18,
#   2721],
#  [102, 1, 213, 46, 544, 363, 611, 8528, 220],
#  [2,
#   779,
#   513,
#   44,
#   471,
#   405,
#   200,
#   921,
#   497,
#   2430,
#   1236,
#   1050,
#   1182,
#   546,
#   921,
#   583,
#   8529,
#   8530,
#   348,
#   309],
#  [138, 67, 2, 46, 345, 229, 3833, 64, 3391, 504, 8531, 284],
#  [281, 8532, 25, 2, 1118, 1217, 1427, 5, 69, 33],
#  [38, 1, 78, 40, 579, 8533, 1391, 8534],
#  [493, 151, 1, 399],
#  [1, 3, 3828, 8535, 4, 95, 8536, 389, 296, 138, 346],
#  [244, 2, 72, 789, 2041],
#  [1, 3, 8537, 155, 607, 136, 26, 358],
#  [1, 19, 8538, 248, 100],
#  [18, 1972, 769, 2180, 165, 388, 606, 21, 388, 616, 12, 1, 134],
#  [1499,
#   682,
#   167,
#   7,
#   371,
#   20,
#   528,
#   31,
#   1616,
#   635,
#   11,
#   66,
#   76,
#   29,
#   474,
#   139,
#   432,
#   221,
#   2747,
#   1029,
#   478,
#   2,
#   710,
#   87,
#   6,
#   386,
#   76,
#   29],
#  [1, 134],
#  [1, 192, 73],
#  [24, 97, 8539, 3886, 4, 2, 473, 1090, 68, 8540, 3555],
#  [9, 5, 3853, 1, 3, 54, 1601, 1481, 240, 196, 190],
#  [2, 473, 495, 1919],
#  [329, 7, 230, 1304, 3818, 2365, 17, 1, 3, 10, 30, 150, 8541, 1958, 3874],
#  [3736, 2415, 8542, 47, 3516, 551, 1, 264, 1758],
#  [8543, 1654, 27, 1260, 64, 8544, 1, 476, 426, 3, 5, 338, 5, 8545],
#  [1, 876, 3887],
#  [93, 1, 142, 2],
#  [1264, 80, 135, 638, 80, 135, 766, 64, 40, 436, 50, 638],
#  [754, 127, 8546, 510, 1274, 8547, 44, 2, 118, 194],
#  [2, 115, 290, 44],
#  [290, 1, 134],
#  [290, 1106, 3775, 8548, 297, 49, 424],
#  [2522, 2, 104, 2, 174, 1971, 8549, 61, 5, 8550, 8551, 8552, 1630],
#  [102, 304, 2454, 54, 190, 1633, 1443, 1, 171],
#  [305, 137, 769, 900, 1494, 150, 19, 2492, 230, 101, 151, 21],
#  [1, 6, 431, 136, 880, 3, 1946, 480, 8553, 582, 2389],
#  [12, 3, 7, 3748, 1876, 8554, 1, 550, 8555, 8556, 8557, 683, 477, 8558],
#  [158,
#   1,
#   3,
#   269,
#   455,
#   1293,
#   3,
#   269,
#   548,
#   253,
#   32,
#   1515,
#   183,
#   3,
#   269,
#   269,
#   3,
#   1003,
#   3070,
#   962,
#   1590,
#   1117,
#   2613,
#   3675],
#  [18, 2, 513, 676],
#  [349, 2938, 1, 712],
#  [4, 63, 38, 1, 123, 94, 2307, 970, 981, 323, 88],
#  [1, 226, 609, 2271, 241, 118, 1114, 8559, 578],
#  [33, 167, 54, 1, 463],
#  [1579,
#   293,
#   132,
#   2,
#   87,
#   311,
#   84,
#   8560,
#   8561,
#   19,
#   8562,
#   3334,
#   1190,
#   170,
#   3579,
#   3888],
#  [1, 157, 30, 8, 509, 470],
#  [1, 285],
#  [452, 44, 355, 8563, 1, 491],
#  [116, 112, 16, 96, 2, 171, 2600, 1055, 1323, 44, 97, 546, 326, 26],
#  [239, 2, 1394, 106, 8564, 106, 1094, 812, 965, 423, 423, 26, 103, 2565, 2249],
#  [35, 68, 3771, 2371, 477, 1261, 36, 3664, 2153, 245, 1216, 2, 1933, 176],
#  [4,
#   2,
#   5,
#   13,
#   233,
#   22,
#   60,
#   220,
#   80,
#   8565,
#   1967,
#   830,
#   8566,
#   55,
#   10,
#   248,
#   1969,
#   835,
#   1140,
#   76,
#   190,
#   4,
#   2,
#   2259,
#   340,
#   22,
#   76],
#  [1, 230, 1531, 149, 456, 4, 47, 248, 21, 900, 1218, 367, 65],
#  [2, 70, 420, 53, 6, 2428],
#  [3, 1987, 3449, 1533, 8, 8, 4, 2, 340],
#  [10, 102, 245, 211, 77, 2, 87, 4, 20, 40, 61, 28],
#  [4, 2, 3223, 250],
#  [334, 1, 376, 1594],
#  [1, 330, 16, 546, 3, 8567, 388, 21],
#  [1, 1964],
#  [14, 517, 61, 28, 2, 87, 19, 1, 354, 8568, 2367, 22, 38, 95],
#  [8569, 195, 1950, 827, 215, 4, 2, 2334, 191],
#  [1, 366, 156],
#  [1, 475, 2, 1070, 241, 31, 238],
#  [1, 556, 129, 1046, 8570],
#  [1, 417, 8571],
#  [460, 322, 1955, 1583, 8572, 236, 2, 335, 395, 300, 357, 1374, 372, 1313],
#  [1, 3, 303, 1212, 33, 8573, 303, 8574, 9, 340],
#  [2, 473, 811, 2594],
#  [1, 3, 197, 8575],
#  [196, 2570, 646, 2, 133],
#  [10, 1801, 236, 2, 511, 8576],
#  [102,
#   42,
#   1203,
#   8577,
#   2399,
#   764,
#   3856,
#   70,
#   8578,
#   1,
#   436,
#   102,
#   609,
#   3492,
#   8579,
#   434,
#   1085,
#   581,
#   8580,
#   1533],
#  [1, 318, 385, 221, 8581, 8582, 8583],
#  [66, 110, 24, 1, 322, 783, 84, 103, 2186, 15, 425, 557, 2502],
#  [23,
#   109,
#   8584,
#   31,
#   27,
#   1724,
#   3812,
#   529,
#   23,
#   1,
#   153,
#   3,
#   90,
#   2398,
#   1237,
#   482,
#   73,
#   43,
#   362],
#  [4, 2, 3024, 250, 8585],
#  [1,
#   3,
#   141,
#   3403,
#   345,
#   1008,
#   277,
#   3889,
#   8586,
#   3839,
#   2180,
#   8587,
#   8588,
#   1539,
#   482,
#   8589,
#   8590,
#   1070],
#  [1286, 1, 69, 3599, 45, 21],
#  [1, 716],
#  [321, 167, 279, 8591, 1, 320, 1497],
#  [1, 6, 1234, 244, 121, 6, 783, 2, 8592],
#  [1, 541, 8593, 793, 488, 3493, 16, 17, 97],
#  [6, 242, 25, 1, 6, 376, 407, 8],
#  [2, 433],
#  [633, 64, 5, 1075, 501, 81, 2, 157, 3890, 1075, 30],
#  [889, 8594, 422, 485, 378, 45, 2285, 2, 115, 8595],
#  [14, 35, 2, 250],
#  [844, 301, 799, 1, 231, 8596, 1574, 2053, 230],
#  [4, 17, 502, 129, 3362, 2561, 8597, 271, 829, 9, 798, 25, 211, 1, 5, 469],
#  [8598, 3464, 2, 263, 781],
#  [241, 65, 671, 1003, 1255, 1, 27, 1564, 340, 8599, 1157, 970, 2495],
#  [1, 751, 88],
#  [1, 254],
#  [295, 895, 2, 5, 2259, 539, 9, 2257, 554, 28, 894, 8600, 260, 1561],
#  [2, 207, 410],
#  [1, 173, 533, 120, 27, 25, 895, 66, 53],
#  [18, 38, 74, 21, 3, 1, 3, 6, 373, 1405, 21, 3346, 3883],
#  [1, 13, 612, 504, 159, 7, 8601, 15, 665, 2288, 102, 109],
#  [764, 8, 1398, 11, 430, 22, 77, 2, 395, 156, 3, 2331],
#  [2, 74, 730, 45, 194, 193, 8602],
#  [1, 108, 132, 145, 300, 21, 2155, 910, 89, 1513, 30, 253, 1649, 1131],
#  [55, 1, 716, 8603, 2, 1252, 2170],
#  [248,
#   626,
#   2,
#   249,
#   154,
#   22,
#   20,
#   1570,
#   53,
#   1083,
#   294,
#   154,
#   1028,
#   188,
#   1814,
#   258],
#  [24,
#   1732,
#   240,
#   12,
#   1299,
#   312,
#   3043,
#   2356,
#   163,
#   2356,
#   163,
#   1235,
#   278,
#   12,
#   30,
#   62,
#   1,
#   74,
#   1,
#   268,
#   3875,
#   170,
#   122],
#  [1395, 2, 364, 229, 720],
#  [247, 2, 344],
#  [1, 428],
#  [55, 1, 27, 3, 234, 3406, 629],
#  [1, 460, 1284, 11, 26, 1341, 357, 2951, 22],
#  [10, 17, 1, 940, 22],
#  [140, 961, 1975, 776, 1553, 193, 8604, 1, 87, 605, 256],
#  [112, 77, 1920, 2, 1986, 210, 658, 8605, 1553],
#  [2069, 848, 8606, 1, 69, 272, 8607],
#  [2, 192, 8608],
#  [7,
#   1,
#   1,
#   352,
#   87,
#   108,
#   653,
#   3,
#   414,
#   1080,
#   2231,
#   8609,
#   216,
#   68,
#   19,
#   25,
#   1716,
#   40,
#   567,
#   110,
#   636],
#  [1698, 1, 3, 586, 759, 630, 8610, 535, 75, 581],
#  [1, 481, 1521, 345, 229, 1486, 3729, 3, 482, 871],
#  [4, 2, 1244, 480],
#  [1, 3, 231, 5, 269, 168, 24, 81, 7],
#  [1, 117, 1253, 1254, 1286, 2067, 8611, 185, 8612, 2309, 2582, 394, 721, 149],
#  [1, 132, 1196, 1174, 266, 49],
#  [63, 12, 25, 1, 359, 85],
#  [164, 114, 1, 205, 1809, 16, 43, 125],
#  [1980, 93, 2, 142, 143, 8, 16, 273, 1694, 3891],
#  [4, 2, 775, 834, 810, 623, 1926, 7, 277],
#  [31, 8613, 198, 1858, 8, 28, 2, 176, 2301],
#  [1, 913, 609, 344, 2969, 803, 8614, 2537],
#  [2, 118, 260, 336, 2198, 1169, 955, 122],
#  [5, 702, 478, 91, 110, 12, 817],
#  [1, 896, 37, 8615, 8616, 8617, 8618, 8619, 8620, 98, 187],
#  [990, 1, 3, 760, 219, 215, 259, 40, 8621, 9, 330, 8622, 478, 28, 1235],
#  [396, 2, 916, 917, 3860],
#  [4, 2, 473, 3313, 8623],
#  [1, 26, 171, 1908, 526, 221],
#  [702,
#   2512,
#   1200,
#   545,
#   58,
#   59,
#   370,
#   12,
#   941,
#   8624,
#   729,
#   16,
#   28,
#   702,
#   8625,
#   222,
#   137,
#   77,
#   563,
#   370,
#   370,
#   1718,
#   941,
#   15,
#   171,
#   1502,
#   8626],
#  [454, 2, 128],
#  [8627, 24, 47, 1, 184],
#  [2, 5, 13, 345, 229, 1429, 44],
#  [4, 2, 6, 132, 40, 903, 3791, 27, 309, 759, 303, 309, 2520, 25],
#  [1, 3, 25, 147, 407, 160],
#  [2, 145, 765, 783, 25, 589, 3882, 744, 3829, 97, 688],
#  [804, 1, 550, 842, 687, 1, 1972, 576, 1333, 8628, 1744, 11],
#  [69, 450, 98, 166, 295, 44, 2, 13, 111],
#  [224,
#   757,
#   8629,
#   1497,
#   398,
#   339,
#   30,
#   3124,
#   3536,
#   375,
#   2625,
#   769,
#   40,
#   22,
#   59,
#   2,
#   310],
#  [1105,
#   814,
#   349,
#   378,
#   113,
#   2,
#   146,
#   637,
#   723,
#   8630,
#   2597,
#   1196,
#   518,
#   2597,
#   1344],
#  [151, 148, 576, 185, 386, 1, 3, 176],
#  [1, 3, 11, 1603, 906, 1144, 122, 759, 364, 277, 48],
#  [3561,
#   332,
#   3535,
#   387,
#   2181,
#   1,
#   223,
#   8631,
#   1947,
#   8632,
#   1849,
#   1547,
#   531,
#   4,
#   16,
#   266],
#  [4, 2, 352, 87, 306, 2574, 116, 8633, 252],
#  [119, 1253, 8634, 141, 1, 588, 92, 54, 313],
#  [1, 191, 78, 950, 205, 1042],
#  [1, 130, 32, 11, 8635, 11, 8636],
#  [110, 8637, 103, 215, 1, 117, 73],
#  [19, 387, 40, 8638, 1379, 1, 115],
#  [110,
#   2,
#   498,
#   3878,
#   1,
#   8639,
#   3888,
#   8640,
#   2374,
#   655,
#   1929,
#   655,
#   3886,
#   368,
#   221,
#   80,
#   3865,
#   8641,
#   1778,
#   1694,
#   8642,
#   432,
#   274,
#   1640,
#   1363,
#   719,
#   8643,
#   1275,
#   2436],
#  [18, 8644, 5, 8645, 88, 4, 2, 328, 23, 10, 2132, 258],
#  [110, 826, 2, 72, 553],
#  [224, 2, 5, 345, 45, 3, 55, 6, 261],
#  [199, 1, 157, 806, 1825],
#  [3815, 3787, 112, 8646, 1834, 56, 1, 156],
#  [55, 1, 521, 80, 1366, 8647, 830, 1125, 70, 2, 65],
#  [1, 904, 596, 167, 436],
#  [236, 1171, 1106, 283, 1208, 109, 586, 390, 1, 428, 1215],
#  [4, 2, 74, 126, 246, 1420, 803, 1794, 212, 1965, 45, 467, 165, 12, 1101],
#  [6, 3, 297, 8648, 6, 1, 297, 1329],
#  [7, 1231, 802, 8649, 1645, 3754, 2524, 1, 226, 8650, 13],
#  [43, 47, 2, 130],
#  [835, 98, 244, 392, 595, 3372, 840],
#  [112, 1304, 3739, 172, 1747, 204, 8651, 1991, 44, 1, 329, 2538, 80, 16],
#  [1, 199, 59, 2590, 3, 3637, 3870, 96, 161],
#  [4, 2, 679, 4, 65, 23, 238, 8652, 4, 8653, 956, 187],
#  [7, 2586, 1, 868, 64, 513, 312, 420, 3752, 1625, 1162, 3333, 8654, 62],
#  [1, 1964, 658, 332],
#  [1, 18, 50, 1158, 529, 712, 73, 558, 374, 8655, 8656, 3522],
#  [8657, 36, 199, 69, 1, 417],
#  [334, 1, 181],
#  [1390, 172, 954, 332, 332, 16, 1371, 79, 2, 356, 28],
#  [4, 63, 182, 35, 1, 13, 74],
#  [4, 2, 100, 478],
#  [375, 2, 106, 312, 95, 140, 8658, 595, 49, 595],
#  [6, 1, 192, 1392],
#  [810,
#   8659,
#   8660,
#   1683,
#   8661,
#   1596,
#   3891,
#   1830,
#   412,
#   116,
#   3872,
#   1756,
#   8662,
#   1448,
#   90,
#   1,
#   1123,
#   1741],
#  [1, 249, 124, 252, 466, 233, 1389],
#  [17, 355, 822, 2, 120, 260, 8663, 77, 3780, 247, 2593, 897, 975],
#  [1, 3, 5, 1046, 1619, 307, 400, 2127, 3700, 1428, 711],
#  [1, 8664, 267, 8665, 64, 3890, 687, 385, 309, 138, 30, 8666, 630, 8667],
#  [1, 144, 4, 6, 922, 418, 643, 423, 8668, 670, 1560, 1268],
#  [1, 115, 268],
#  [131, 1, 4, 1487, 287, 37, 107, 8669, 1629, 1681, 27],
#  [241, 8670, 8671, 3575, 404, 589, 412, 2, 5, 315, 975, 3704, 8672, 76],
#  [1, 213, 52],
#  [1, 115, 249],
#  [4, 2, 191, 4, 2, 147, 4, 2, 268],
#  [10, 54, 11, 929, 1, 462, 1487, 1, 11, 1, 1487],
#  [8673, 431, 40, 220, 1, 257, 115, 2326, 8674],
#  [1, 550, 1389, 114, 878, 3503, 3163],
#  [1, 366, 289, 8675, 8676, 137],
#  [1, 74, 90, 21, 129, 1436, 2509, 8677, 21],
#  [1078, 2, 106, 49, 12, 281, 8678, 765, 362],
#  [23, 7, 1, 152, 623, 11, 8679, 888, 8680],
#  [1, 3, 522, 2775],
#  [4, 20, 866, 1, 376],
#  [1, 153, 501, 153, 19, 1322, 760, 30, 8681, 11, 19],
#  [1, 72, 60, 8, 280],
#  [79, 2, 201, 271, 1382, 8682, 1072, 8683],
#  [324, 1, 5, 181, 8684, 385, 1076, 1434],
#  [1, 175, 43, 1889, 170, 8685],
#  [1, 27, 261, 8686, 261, 1569, 1818, 448, 1377, 592],
#  [1, 548, 173, 308],
#  [4, 2, 59, 14, 8687, 8688, 568, 8689, 1206, 8690, 695],
#  [30, 877, 1808, 2456, 1, 3, 4, 162, 7, 4, 16],
#  ...]

# %%
from keras.preprocessing.sequence import pad_sequences
# now padding to have a maximum length of 64
pad_rev_test= pad_sequences(encd_rev_test, maxlen=max_sen_len, padding='post')
pad_rev_test.shape   # note that we had 10 testing data and we have padded each review to have  a lenght of 64 words.
# Out:
# (1188, 64)

# %%
pad_rev_test
# Out:
# array([[  75,    1,  191, ...,    0,    0,    0],
#        [7849, 3383,  781, ...,    0,    0,    0],
#        [  58,    1,    3, ...,    0,    0,    0],
#        ...,
#        [   1, 2485,   72, ...,    0,    0,    0],
#        [   1,    3,  232, ...,    0,    0,    0],
#        [  43,   47,    2, ...,    0,    0,    0]], dtype=int32)

# %%
test_predict=model.predict(pad_rev_test)
classe_test=np.argmax(test_predict,axis=1)
# Out:
# 38/38 [==============================] - 1s 15ms/step

# %%
classe_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print('\nClassification Report\n')
print(classification_report(y_test, classe_test))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.34      1.00      0.50       400
#            1       0.00      0.00      0.00       400
#            2       0.00      0.00      0.00       388
#
#     accuracy                           0.34      1188
#    macro avg       0.11      0.33      0.17      1188
# weighted avg       0.11      0.34      0.17      1188
